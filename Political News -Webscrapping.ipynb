# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
link1 = "https://thebridge.in" 
link2 = "https://www.bbc.com/sport"  
link3 = "https://indianexpress.com/section/sports/" 
link4 = "https://www.timesnownews.com/sports"

# %%
def getHTMLdocument(url):
    response = requests.get(url)
    return response.text

# %%
page1 = getHTMLdocument(link1)
page2 = getHTMLdocument(link2)
page3 = getHTMLdocument(link3)
page4 = getHTMLdocument(link4)

# %%
soup1 = bs(page1,'html.parser')
soup2 = bs(page2,'html.parser')
soup3 = bs(page3,'html.parser')
soup4 = bs(page4,'html.parser')

# %%
print(soup1.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Indian Sports Home - Latest News, Results, Stories | The Bridge
#   </title>
#   <link href="/images/ico/favicon.ico?v=1" rel="icon" type="image/x-icon"/>
#   <link href="/images/ico/favicon.ico?v=1" rel="shortcut icon" type="image/x-icon"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0,user-scalable=no" name="viewport"/>
#   <meta content="Indian Sports Home - Latest News, Results, Stories | The Bridge" name="description"/>
#   <meta content="The Bridge - Home of Indian Sports" name="application-name"/>
#   <meta content="Indian Sports Home - Latest News, Results, Stories | The Bridge" name="keywords"/>
#   <meta content="en" name="language"/>
#   <meta content="notranslate" name="google"/>
#   <meta content="thebridge" name="author"/>
#   <meta content="The Bridge - Home of Indian Sports" name="copyright"/>
#   <meta content="follow, index" name="robots"/>
#   <meta content="max-image-preview:large" name="robots"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="https://thebridge.in/" property="og:url"/>
#   <meta content="https://thebridge.in/" name="twitter:url"/>
#   <meta content="Indian Sports Home - Latest News, Results, Stories | The Bridge" name="title"/>
#   <meta content="https://thebridge.in/images/logo.png" name="image"/>
#   <link href="//cdn.syndication.twimg.com" rel="dns-prefetch"/>
#   <link href="//www.facebook.com" rel="dns-prefetch"/>
#   <link href="//connect.facebook.net" rel="dns-prefetch"/>
#   <link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/>
#   <link href="//www.youtube.com" rel="dns-prefetch"/>
#   <link href="//platform.twitter.com" rel="dns-prefetch"/>
#   <link href="//gstatic.com" rel="dns-prefetch"/>
#   <link href="//www.google.com" rel="dns-prefetch"/>
#   <link href="//s.ytimg.com" rel="dns-prefetch"/>
#   <link href="//hocalwire.com" rel="dns-prefetch"/>
#   <link href="//www.hocalwire.com" rel="dns-prefetch"/>
#   <link href="//adservice.google.co.in" rel="dns-prefetch"/>
#   <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
#   <link href="//cdnimg.izooto.com" rel="dns-prefetch"/>
#   <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
#   <link href="//fonts.gstatic.com" rel="dns-prefetch"/>
#   <link href="//www.googletagservices.com" rel="dns-prefetch"/>
#   <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
#   <script>
#    window.dynamicPage =""
# window.support_article_infinite_scroll ="true"
# window.similar_news_infinite_scroll ="true"
# window.xhrPageLoad =""
# window.isNewsArticlePage =""
#   </script>
#   <meta content="498164231566645" property="fb:app_id"/>
#   <meta content="website" property="og:type"/>
#   <script>
#    window.ignoreCoreScripts = "";
# window.exclude_dynamic_links_only =  "";
# window.disable_unveil = "";
# window.enableTransliteration = "";
# window.extra_whatsapp_share_message = "";
#   </script>
#   <script>
#    window.load_theme_resource_after_pageLoad = "true"
#   </script>
#   <meta content="Indian Sports Home - Latest News, Results, Stories | The Bridge" property="og:title"/>
#   <meta content="Indian Sports Home - Latest News, Results, Stories | The Bridge" property="og:description"/>
#   <meta content="https://thebridge.in/images/logo.png?width=500&amp;height=300" itemprop="image" property="og:image"/>
#   <meta content="thebridge" property="og:author"/>
#   <meta content="Indian Sports Home - Latest News, Results, Stories | The Bridge" name="twitter:title"/>
#   <meta content="Indian Sports Home - Latest News, Results, Stories | The Bridge" name="twitter:description"/>
#   <meta content="https://thebridge.in/images/logo.png?width=500&amp;height=300" name="twitter:image"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="630" property="og:image:height"/>
#   <meta content="enable=true ad_density=default" property="fb:use_automatic_ad_placement"/>
#   <script>
#    window.single_source_news_url = ""
# window.popup_ad_cookie_duration = ""
# window.popup_ad_display_duration = ""
# window.road_blocker_ad_cookie_duration="120"
# window.road_blocker_ad_display_duration="5"
# window.epaperClipRatio="7"
# window.scriptLoadDelay=parseInt("1000")
# window.windowLoadedDelay=parseInt("")
# window.exclude_common_ga=""
# window.exclude_all_ga=""
# window.payment_success_redirect_url = ""
# window.refresh_pages_on_interval = {};
#
# window.maxAllowCropHeightFactor = ""
# window.clipLogo = ""
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-TKDYNPT0B7">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
# window.gtag = function(){dataLayer.push(arguments);}
# gtag('js', new Date());
# var map = {}
# var data;
# var count1=1;
# if(""!="undefined" && ""!=""){
#     data = {};
# } else {
#     if("[object Object]"!="undefined"){
#         data = {"partnerName":"thebridge","domainName":"https://thebridge.in","storyUrl":"/","authorName":"thebridge","type":"website","campaignId":"NOT_FOUND"};
#     }
# }
# if(data){
#     for(var k in data){
#         map['dimension'+count1] = k;
#         count1++;
#     }
# }
# if(''){
#     gtag('config', '',{"custom_map":map});
#     gtag('event', 'custom_dimension',data);
#
#     window.setGTag = function(location,url,title){
#         //- debugger;
#         gtag('event', 'page_view', {
#           page_title: title,
#           page_location: location,
#           page_path: url,
#           send_to: ''
#         })
#
#     }
# }
# gtag('config', 'G-TKDYNPT0B7',{"custom_map":map,"group":"common"});
# window.setGTagCommon = function(location,url,title){
#     //- debugger;
#     gtag('event', 'page_view', {
#       page_title: title,
#       page_location: location,
#       page_path: url,
#       send_to: 'G-TKDYNPT0B7'
#     })
#
# }
#   </script>
#   <script type="text/javascript">
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# window.trackGA = function(ignoreCreate){
#     if(window.exclude_all_ga){
#         return;
#     }
#     var location = window.location.protocol+"//"+window.location.host;
#     var URL = document.URL || window.location.href;
#     URL = URL.replace(location,"");
#     var TITLE = document.title || "";
#     if(window.single_source_news_url){
#         var tUrl = URL;
#         tUrl = tUrl.split("?")[0];
#         tUrl = tUrl.split("#")[0];
#         URL = tUrl;
#     }
#     //- debugger;
#     if(window.gtag && ignoreCreate){
#         if(window.setGTag){
#             window.setGTag(location,URL,TITLE);
#         }
#         if(window.setGTagCommon){
#             window.setGTagCommon(location,URL,TITLE);
#         }
#     }
#     if(window.ga){
#         window.lastTracked = window.lastTracked || {};
#         window.lastTracked.url = document.URL || window.location.href;
#         window.lastTracked.title = document.title;
#         var gakey = 'UA-108865563-1';
#         if(!ignoreCreate){
#             window.ga('create', gakey, 'auto');
#         }
#         if(""!="undefined"){
#             var data = {};
#             var count1=1;
#             for(var k in data){
#                 window.ga('set','dimension'+count1, data[k]);
#                 count1++;
#             }
#         } else {
#             if("[object Object]"!="undefined"){
#                 var data = {"partnerName":"thebridge","domainName":"https://thebridge.in","storyUrl":"/","authorName":"thebridge","type":"website","campaignId":"NOT_FOUND"};
#                 var count=1;
#                 if(data && data.partnerName){
#                     for(var k in data){
#                         window.ga('set','dimension'+count, data[k]);
#                         count++;
#                     }
#                 }
#             }
#         }
#         window.ga('set','location', location+URL);
#         //- window.ga('set','page', URL);
#         if(TITLE){
#             window.ga('set','title',TITLE);
#         }
#         window.ga('send', 'pageview');
#
#         if(window.exclude_common_ga){
#             return;
#         }
#         if(!ignoreCreate){
#             window.ga('create', 'UA-93836544-1', {'name':'commonall'});
#         }
#         window.ga('commonall.set','location', location);
#         window.ga('commonall.set','page', location+URL);
#         if(TITLE){
#             window.ga('commonall.set','title',TITLE);
#         }
#
#         if("[object Object]"!="undefined"){
#             var data = {"partnerName":"thebridge","domainName":"https://thebridge.in","storyUrl":"/","authorName":"thebridge","type":"website","campaignId":"NOT_FOUND"};
#             var count=1;
#             if(data && data.partnerName){
#                 for(var k in data){
#                     window.ga('commonall.set','dimension'+count, data[k]);
#                     count++;
#                 }
#             }
#         }
#         window.ga('commonall.send', 'pageview');
#
#
#     }
# }
#
#
# window.trackGA();
#   </script>
#   <script>
#    window.FBCODE = "498164231566645";
#   </script>
#   <script>
#    window.insetLinkInCopy = '' || true;
# window.insetLinkInCopyLoggedIn = '';
#   </script>
#   <script>
#    window.trackingPageType = "home";
#   </script>
#   <script>
#    window.externalResourcesVersion = "1";
# window.externalResources = "https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js,https://www.instagram.com/embed.js,https://securepubads.g.doubleclick.net/tag/js/gpt.js,https://platform.twitter.com/widgets.js,https://rtbcdn.andbeyond.media/prod-global-552101.js";
# window.externalResourcesLength = "5";
#   </script>
#   <script>
#    window.Constants = {"url":{"xhrLogin":"/xhr/admin/login/loginUser","xhrLoginOrRegister":"/xhr/admin/login/loginOrRegisterUser","xhrRegister":"/xhr/admin/login/registerUser","xhrVerify":"/xhr/admin/login/verifyUser","xhrVerifyEmail":"/xhr/admin/login/verifyEmail","xhrForgotPassword":"/xhr/admin/login/forgotPassword","xhrResetPassword":"/xhr/admin/login/reset-password","xhrLogout":"/xhr/admin/login/logout","xhrRegenerateEmailCode":"/xhr/admin/login/regenerateEmailCode"}};
#   </script>
#   <script>
#    window.enable_webp_images = "true";
#   </script>
#   <script>
#    window.userDeviceType = "d";
#   </script>
#   <script>
#    window.hasIntagram = "true"
# window.hasTwitter = "true"
# window.isIOS = ""
# window.sendNewsReadState = ""
# window.image_quality_percentage = ""
# window.enable_js_image_compress = ""
# window.local_date_time_format = ""
#   </script>
#   <style class="styles" type="text/css">
#    body img,iframe,video{max-width:100%}img{height:auto}.details-content-story iframe.note-video-clip{width:100%}body,html{-webkit-overflow-scrolling:touch}#content{-webkit-overflow-scrolling:touch}#content{height:100%}#main #content{display:inline}.hide{display:none!important}.soft-hide{display:none}.bg-404{background:url(/images/404.jpg);background-repeat:no-repeat;background-size:100%;background-position:center;background-blend-mode:screen;min-height:400px;text-align:center}.bg-404 .error404-content{background:#fff;padding:20px;font-size:30px;opacity:.8}a img{max-width:100%}.newsSocialIcons li a{color:#fff}.newsSocialIcons li a:hover{text-decoration:none!important}.newsSocialIcons li a i{margin-right:4px}.newsSocialIcons{width:100%;display:inline-block;text-align:right}.newsSocialIcons a{padding:5px;display:inline-block}.hocalwire-cp-authors-social,.newsSocialIcons ul{width:100%;padding-left:0}.hocalwire-cp-authors-social{text-align:left}.newsSocialIcons li{list-style:none!important;width:25px;height:25px;text-decoration:none;font-family:Oswald!important;text-transform:uppercase;background:0 0;opacity:1;line-height:30px;padding:0;margin:0 3px;position:relative}.newsSocialIcons li a{color:#fff;height:21px}.newsSocialIcons li a:hover{text-decoration:none!important}.newsSocialIcons li a i{margin-right:4px}.newsSocialIcons li.facebook,.sticky li.facebook{border:0 solid #314b83;background-color:#4769a5}.newsSocialIcons li.whatsapp,.sticky li.whatsapp{border:0 solid #65bc54;background-color:#65bc54}.newsSocialIcons li.telegram,.sticky li.telegram{border:0 solid #379be5;background-color:#379be5}.newsSocialIcons li.pintrest{border:0;background-color:#d50c22}.newsSocialIcons li.twitter,.sticky li.twitter{border:0 solid #0092ba;background-color:#65ccef}.newsSocialIcons li.googleplus{border:0 solid #ab2b1d;background-color:#bf3727}.newsSocialIcons li.gplus{border:0 solid #ab2b1d;background-color:#bf3727}.newsSocialIcons li.linkedin,.sticky li.linkedin{border:0 solid #278cc0;background-color:#2ba3e1}.newsSocialIcons li.tumblr{border:0 solid #2c3c4c;background-color:#34495e}.newsSocialIcons li.pinterest,.sticky li.printrest{border:0 solid #ae1319;background-color:#cd252b}.newsSocialIcons li.email{border:0 solid #4b3b3b;background-color:#4b3b3b}.newsSocialIcons li.mail,.sticky li.mail{border:0 solid #18ae91;background-color:#1abc9c}.sticky li.email,.sticky li.mail{border:0 solid #4b3b3b;background-color:#4b3b3b}.newsSocialIcons li.print{border:0 solid #000;background-color:#000}.sticky li.print{border:0 solid #000;background-color:#000}.newsSocialIcons li.youtube{border:0 solid #e62117;background-color:#e62117}.newsSocialIcons li.insta{border:0 solid #0526c5;background-color:#0526c5}.newsSocialIcons li img{vertical-align:top}.newsSocialIcons ul{border-radius:3px;padding:5px;z-index:10;float:left;clear:both}.newsSocialIcons.right-navigation ul li+li{display:none;float:left;border-radius:30px;padding-top:2px}.newsSocialIcons li{float:left;border-radius:30px}.listing-social-share .newsSocialIcons li{border-radius:30px!important}.margin-top10{margin-top:10px}.sticky-container{position:fixed;top:40%;z-index:11111111111}.sticky-container ul li p{padding:5px}.sticky li.facebook{border:0 solid #314b83;background-color:#4769a5}.sticky li.twitter{border:0 solid #0092ba;background-color:#65ccef}.sticky li.googleplus{border:0 solid #ab2b1d;background-color:#bf3727}.sticky li.gplus{border:0 solid #ab2b1d;background-color:#bf3727}.sticky li.linkedin{border:0 solid #278cc0;background-color:#2ba3e1}.sticky li.tumblr{border:0 solid #2c3c4c;background-color:#34495e}.sticky li.pinterest{border:0 solid #ae1319;background-color:#cd252b}.sticky li.mail{border:0 solid #18ae91;background-color:#1abc9c}.sticky li.youtube{border:0 solid #e62117;background-color:#e62117}.sticky-container .fab{background:#03a9f4;width:35px;height:35px;text-align:center;color:#fff;box-shadow:0 0 3px rgba(0,0,0,.5),3px 3px 3px rgba(0,0,0,.25);position:fixed;right:1/4 * 3 * 64px;font- ...
#   </style>
#   <meta content="319889611791149" property="fb:pages">
#    <link as="font" crossorigin="anonymous" href="/theme_sport/fonts/Work_Sans/static/WorkSans-SemiBold.ttf" rel="preload"/>
#    <link as="font" crossorigin="anonymous" href="/theme_sport/fonts/Work_Sans/static/WorkSans-Bold.ttf" rel="preload"/>
#    <link as="font" crossorigin="anonymous" href="/theme_sport/fonts/Work_Sans/static/WorkSans-Regular.ttf" rel="preload"/>
#    <link as="font" crossorigin="anonymous" href="/theme_sport/fonts/Poppins/Poppins-SemiBold.ttf" rel="preload"/>
#    <link as="font" crossorigin="anonymous" href="/theme_sport/fonts/Poppins/Poppins-Bold.ttf" rel="preload"/>
#    <link as="font" crossorigin="anonymous" href="/theme_sport/fonts/Poppins/Poppins-Regular.ttf" rel="preload"/>
#    <link as="font" crossorigin="anonymous" href="/theme_era/fonts/fontawesome-webfont.woff2" rel="preload"/>
#    <script>
#     window._izq = window._izq || []; window._izq.push(["init" ]);
#    </script>
#    <script src="https://cdn.izooto.com/scripts/0f4d6d4289f80f0d4ecc70317da7799b3cf72133.js">
#    </script>
#    <style class="styles" type="text/css">
#     html{font-family:sans-serif;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}body{font-size:14px;line-height:1.428571429;color:#333;background-color:#fff}body{color:#2a3744;text-rendering:optimizeLegibility;-webkit-font-smoothing:antialiased}article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section,summary{display:block}b,strong{font-weight:700}*,:after,:before{box-sizing:border-box}html{font-size:10px;-webkit-tap-highlight-color:transparent}button,input,select,textarea{font-family:inherit;font-size:inherit;line-height:inherit}a{color:#337ab7;text-decoration:none}a:focus,a:hover{color:#23527c;text-decoration:underline}a:focus{outline:5px auto -webkit-focus-ring-color;outline-offset:-2px}figure{margin:0}img{vertical-align:middle}.img-responsive{display:block;max-width:100%;height:auto}.img-rounded{border-radius:6px}.img-thumbnail{padding:4px;line-height:1.428571429;background-color:#fff;border:1px solid #ddd;border-radius:4px;-webkit-transition:all .2s ease-in-out;transition:all .2s ease-in-out;display:inline-block;max-width:100%;height:auto}.img-circle{border-radius:50%}hr{margin-top:20px;margin-bottom:20px;border:0;border-top:1px solid #eee}.sr-only{position:absolute;width:1px;height:1px;margin:-1px;padding:0;overflow:hidden;clip:rect(0,0,0,0);border:0}.sr-only-focusable:active,.sr-only-focusable:focus{position:static;width:auto;height:auto;margin:0;overflow:visible;clip:auto}[role=button]{cursor:pointer}.h1,.h2,.h3,.h4,.h5,.h6,h1,h2,h3,h4,h5,h6{font-family:inherit;font-weight:500;line-height:1.1;color:inherit}.h1 .small,.h1 small,.h2 .small,.h2 small,.h3 .small,.h3 small,.h4 .small,.h4 small,.h5 .small,.h5 small,.h6 .small,.h6 small,h1 .small,h1 small,h2 .small,h2 small,h3 .small,h3 small,h4 .small,h4 small,h5 .small,h5 small,h6 .small,h6 small{font-weight:400;line-height:1;color:#777}.h1,.h2,.h3,h1,h2,h3{margin-top:20px;margin-bottom:10px}.h1 .small,.h1 small,.h2 .small,.h2 small,.h3 .small,.h3 small,h1 .small,h1 small,h2 .small,h2 small,h3 .small,h3 small{font-size:65%}.h4,.h5,.h6,h4,h5,h6{margin-top:10px;margin-bottom:10px}.h4 .small,.h4 small,.h5 .small,.h5 small,.h6 .small,.h6 small,h4 .small,h4 small,h5 .small,h5 small,h6 .small,h6 small{font-size:75%}.h1,h1{font-size:36px}.h2,h2{font-size:30px}.h3,h3{font-size:24px}.h4,h4{font-size:18px}.h5,h5{font-size:14px}.h6,h6{font-size:12px}p{margin:0 0 10px}.lead{margin-bottom:20px;font-size:16px;font-weight:300;line-height:1.4}@media(min-width:768px){.lead{font-size:21px}}.small,small{font-size:85%}.mark,mark{background-color:#fcf8e3;padding:.2em}.text-left{text-align:left}.text-right{text-align:right}.text-center{text-align:center}.text-justify{text-align:justify}.text-nowrap{white-space:nowrap}.text-lowercase{text-transform:lowercase}.initialism,.text-uppercase{text-transform:uppercase}.text-capitalize{text-transform:capitalize}.text-muted{color:#777}.text-primary{color:#337ab7}a.text-primary:focus,a.text-primary:hover{color:#286090}.text-success{color:#3c763d}a.text-success:focus,a.text-success:hover{color:#2b542c}.text-info{color:#31708f}a.text-info:focus,a.text-info:hover{color:#245269}.text-warning{color:#8a6d3b}a.text-warning:focus,a.text-warning:hover{color:#66512c}.text-danger{color:#a94442}a.text-danger:focus,a.text-danger:hover{color:#843534}.bg-primary{color:#fff;background-color:#337ab7}a.bg-primary:focus,a.bg-primary:hover{background-color:#286090}.bg-success{background-color:#dff0d8}a.bg-success:focus,a.bg-success:hover{background-color:#c1e2b3}.bg-info{background-color:#d9edf7}a.bg-info:focus,a.bg-info:hover{background-color:#afd9ee}.bg-warning{background-color:#fcf8e3}a.bg-warning:focus,a.bg-warning:hover{background-color:#f7ecb5}.bg-danger{background-color:#f2dede}a.bg-danger:focus,a.bg-danger:hover{background-color:#e4b9b9}.page-header{padding-bottom:9px;margin:40px 0 20px;border-bottom:1px solid #eee}.list-inline,.list-unstyled{padding-left:0;list-style:none}.list-inline{margin-left:-5px}.list-inline>li{disp ...
#          * https://github.com/sachinchoolur/lightslider
#          * Copyright (c) 2016 Sachin N; Licensed MIT *//*! lightslider - v1.1.3 - 2015-04-14
#          * https://github.com/sachinchoolur/lightslider
#          * Copyright (c) 2015 Sachin N; Licensed MIT */.lSSlideOuter{overflow:hidden;-webkit-touch-callout:none;-webkit-user-select:none;-khtml-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none}.lightSlider:after,.lightSlider:before{content:" ";display:table}.lightSlider{overflow:hidden;margin:0}.lSSlideWrapper{max-width:100%;overflow:hidden;position:relative}.lSSlideWrapper>.lightSlider:after{clear:both}.lSSlideWrapper .lSSlide{-webkit-transform:translate(0,0);-ms-transform:translate(0,0);transform:translate(0,0);-webkit-transition:all 1s;-webkit-transition-property:-webkit-transform,height;-moz-transition-property:-moz-transform,height;transition-property:transform,height;-webkit-transition-duration:inherit!important;transition-duration:inherit!important;-webkit-transition-timing-function:inherit!important;transition-timing-function:inherit!important}.lSSlideWrapper .lSFade{position:relative}.lSSlideWrapper .lSFade>*{position:absolute!important;top:0;left:0;z-index:9;margin-right:0;width:100%}.lSSlideWrapper.usingCss .lSFade>*{opacity:0;-webkit-transition-delay:0s;transition-delay:0s;-webkit-transition-duration:inherit!important;transition-duration:inherit!important;-webkit-transition-property:opacity;transition-property:opacity;-webkit-transition-timing-function:inherit!important;transition-timing-function:inherit!important}.lSSlideWrapper .lSFade>.active{z-index:10}.lSSlideWrapper.usingCss .lSFade>.active{opacity:1}.lSSlideOuter .lSPager.lSpg{margin:10px 0 0;padding:0;text-align:center}.lSSlideOuter .lSPager.lSpg>li{cursor:pointer;display:inline-block;padding:0 5px}.lSSlideOuter .lSPager.lSpg>li a{background-color:#222;border-radius:30px;display:inline-block;height:8px;overflow:hidden;text-indent:-999em;width:8px;position:relative;z-index:99;-webkit-transition:all .5s linear 0s;transition:all .5s linear 0s}.lSSlideOuter .lSPager.lSpg>li.active a,.lSSlideOuter .lSPager.lSpg>li:hover a{background-color:#428bca}.lSSlideOuter .media{opacity:.8}.lSSlideOuter .media.active{opacity:1}.lSSlideOuter .lSPager.lSGallery{list-style:none outside none;padding-left:0;margin:0;overflow:hidden;transform:translate3d(0,0,0);-moz-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);-webkit-transform:translate3d(0,0,0);-o-transform:translate3d(0,0,0);-webkit-transition-property:-webkit-transform;-moz-transition-property:-moz-transform;-webkit-touch-callout:none;-webkit-user-select:none;-khtml-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none}.lSSlideOuter .lSPager.lSGallery li{overflow:hidden;-webkit-transition:border-radius .12s linear 0s .35s linear 0s;transition:border-radius .12s linear 0s .35s linear 0s}.lSSlideOuter .lSPager.lSGallery li.active,.lSSlideOuter .lSPager.lSGallery li:hover{border-radius:5px}.lSSlideOuter .lSPager.lSGallery img{display:block;height:auto;max-width:100%}.lSSlideOuter .lSPager.lSGallery:after,.lSSlideOuter .lSPager.lSGallery:before{content:" ";display:table}.lSSlideOuter .lSPager.lSGallery:after{clear:both}.lSAction>a{width:32px;display:block;top:50%;height:32px;cursor:pointer;position:absolute;z-index:99;margin-top:-16px;opacity:.5;-webkit-transition:opacity .35s linear 0s;transition:opacity .35s linear 0s}.lSAction>a:hover{opacity:1}.lSAction>.lSPrev{background-position:0 0;left:10px}.lSAction>.lSNext{background-position:-32px 0;right:10px}.lSAction>a.disabled{pointer-events:none}.cS-hidden{height:1px;opacity:0;overflow:hidden}.lSSlideOuter.vertical{position:relative}.lSSlideOuter.vertical.noPager{padding-right:0!important}.lSSlideOuter.vertical .lSGallery{position:absolute!important;right:0;top:0}.lSSlideOuter.vertical .lightSlider>*{width:100%!important;max-width:none!important}.lSSlideOuter.vertical .lSAction>a{left:50%;margin-left:-14px;margin-top:0}.lSSlideOuter.vertical .lSAction>.lSNext{background-position:31px -31px;bottom:10px;top:auto}.lSSlideOuter.vertical .lSAction>.lSPrev{background-position:0 -31px;bottom:auto;top:10px}.lSSlideOuter.l ...
#          * https://github.com/sachinchoolur/lightslider
#          * Copyright (c) 2016 Sachin N; Licensed MIT *//*! lightslider - v1.1.3 - 2015-04-14
#          * https://github.com/sachinchoolur/lightslider
#          * Copyright (c) 2015 Sachin N; Licensed MIT */.lSSlideOuter{overflow:hidden;-webkit-touch-callout:none;-webkit-user-select:none;-khtml-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none}.lightSlider:after,.lightSlider:before{content:" ";display:table}.lightSlider{overflow:hidden;margin:0}.lSSlideWrapper{max-width:100%;overflow:hidden;position:relative}.lSSlideWrapper>.lightSlider:after{clear:both}.lSSlideWrapper .lSSlide{-webkit-transform:translate(0,0);-ms-transform:translate(0,0);transform:translate(0,0);-webkit-transition:all 1s;-webkit-transition-property:-webkit-transform,height;-moz-transition-property:-moz-transform,height;transition-property:transform,height;-webkit-transition-duration:inherit!important;transition-duration:inherit!important;-webkit-transition-timing-function:inherit!important;transition-timing-function:inherit!important}.lSSlideWrapper .lSFade{position:relative}.lSSlideWrapper .lSFade>*{position:absolute!important;top:0;left:0;z-index:9;margin-right:0;width:100%}.lSSlideWrapper.usingCss .lSFade>*{opacity:0;-webkit-transition-delay:0s;transition-delay:0s;-webkit-transition-duration:inherit!important;transition-duration:inherit!important;-webkit-transition-property:opacity;transition-property:opacity;-webkit-transition-timing-function:inherit!important;transition-timing-function:inherit!important}.lSSlideWrapper .lSFade>.active{z-index:10}.lSSlideWrapper.usingCss .lSFade>.active{opacity:1}.lSSlideOuter .lSPager.lSpg{margin:10px 0 0;padding:0;text-align:center}.lSSlideOuter .lSPager.lSpg>li{cursor:pointer;display:inline-block;padding:0 5px}.lSSlideOuter .lSPager.lSpg>li a{background-color:#222;border-radius:30px;display:inline-block;height:8px;overflow:hidden;text-indent:-999em;width:8px;position:relative;z-index:99;-webkit-transition:all .5s linear 0s;transition:all .5s linear 0s}.lSSlideOuter .lSPager.lSpg>li.active a,.lSSlideOuter .lSPager.lSpg>li:hover a{background-color:#428bca}.lSSlideOuter .media{opacity:.8}.lSSlideOuter .media.active{opacity:1}.lSSlideOuter .lSPager.lSGallery{list-style:none outside none;padding-left:0;margin:0;overflow:hidden;transform:translate3d(0,0,0);-moz-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);-webkit-transform:translate3d(0,0,0);-o-transform:translate3d(0,0,0);-webkit-transition-property:-webkit-transform;-moz-transition-property:-moz-transform;-webkit-touch-callout:none;-webkit-user-select:none;-khtml-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none}.lSSlideOuter .lSPager.lSGallery li{overflow:hidden;-webkit-transition:border-radius .12s linear 0s .35s linear 0s;transition:border-radius .12s linear 0s .35s linear 0s}.lSSlideOuter .lSPager.lSGallery li.active,.lSSlideOuter .lSPager.lSGallery li:hover{border-radius:5px}.lSSlideOuter .lSPager.lSGallery img{display:block;height:auto;max-width:100%}.lSSlideOuter .lSPager.lSGallery:after,.lSSlideOuter .lSPager.lSGallery:before{content:" ";display:table}.lSSlideOuter .lSPager.lSGallery:after{clear:both}.lSAction>a{width:32px;display:block;top:50%;height:32px;cursor:pointer;position:absolute;z-index:99;margin-top:-16px;opacity:.5;-webkit-transition:opacity .35s linear 0s;transition:opacity .35s linear 0s}.lSAction>a:hover{opacity:1}.lSAction>.lSPrev{background-position:0 0;left:10px}.lSAction>.lSNext{background-position:-32px 0;right:10px}.lSAction>a.disabled{pointer-events:none}.cS-hidden{height:1px;opacity:0;overflow:hidden}.lSSlideOuter.vertical{position:relative}.lSSlideOuter.vertical.noPager{padding-right:0!important}.lSSlideOuter.vertical .lSGallery{position:absolute!important;right:0;top:0}.lSSlideOuter.vertical .lightSlider>*{width:100%!important;max-width:none!important}.lSSlideOuter.vertical .lSAction>a{left:50%;margin-left:-14px;margin-top:0}.lSSlideOuter.vertical .lSAction>.lSNext{background-position:31px -31px;bottom:10px;top:auto}.lSSlideOuter.vertical .lSAction>.lSPrev{background-position:0 -31px;bottom:auto;top:10px}.lSSlideOuter.l ...
#    </style>
#    <style>
#     .roadblocker-ad-content-wrap .popup-content-container .center-content{
# 	margin-top:0px;
# }
#    </style>
#    <link href="/" hreflang="en" rel="canonical"/>
#   </meta>
#  </head>
#  <body class="wrapper">
#   <a class="cd-top" href="#0" id="top">
#    Top
#   </a>
#   <script>
#    window.scrollTopFn = function(){
#     window.scrollTo(0,0);
# }
# var elem = document.getElementsByClassName("cd-top")[0];
# if(elem){
#     elem.addEventListener('click', scrollTopFn , false);
# }
#   </script>
#   <link href="https://thebridge.in/images/logo.png?width=500&amp;height=300" itemprop="thumbnailUrl"/>
#   <span itemprop="thumbnail" itemscope="" itemtype="http://schema.org/ImageObject">
#    <link href="https://thebridge.in/images/logo.png?width=500&amp;height=300" itemprop="url"/>
#   </span>
#   <script type="application/ld+json">
#    {
#     "@context" : "http://schema.org",
#     "@type" : "WebSite",
#     "name" : "The Bridge - Home of Indian Sports",
#     "author" : {
#       "@type" : "Person",
#       "name" : "The Bridge - Home of Indian Sports"
#     },
#     "keywords" : "Indian Sports Home - Latest News, Results, Stories | The Bridge",
#     "interactivityType" : "mixed",
#     "inLanguage" : "",
#     "headline" : "Indian Sports Home - Latest News, Results, Stories | The Bridge",
#     "copyrightHolder" : "The Bridge - Home of Indian Sports",
#     "image" : {
#       "@context" : "http://schema.org",
#       "@type" : "ImageObject",
#       "contentUrl" : "https://thebridge.in/images/logo.png",
#       "height": "300",
#       "width" : "500",
#       "url" : "https://thebridge.in/images/logo.png"
#      },
#     "url" : "https://thebridge.in/",
#     "publisher" : {
#       "@type" : "Organization",
#        "name" : "The Bridge - Home of Indian Sports",
#        "logo" : {
#           "@context" : "http://schema.org",
#           "@type" : "ImageObject",
#           "contentUrl" : "/images/logo.png",
#           "height": "60",
#           "width" : "100",
#           "url" : "/images/logo.png"
#        }
#      },
#      "potentialAction": {
#         "@type": "SearchAction",
#           "target": "https://thebridge.in/search?search={search_term_string}",
#           "query-input": "required name=search_term_string"
#       },
#       "mainEntityOfPage": {
#            "@type": "WebPage",
#            "@id": "https://thebridge.in/"
#         }
#   }
#   </script>
#   <script type="application/ld+json">
#    {
#     "@context" : "http://schema.org",
#     "@type" : "Organization",
#     "url" : "https://thebridge.in",
#     "name" : "The Bridge - Home of Indian Sports",
#     "sameAs" : [],
#     "logo" : {
#           "@context" : "http://schema.org",
#           "@type" : "ImageObject",
#           "contentUrl" : "https://thebridge.in/images/logo.png",
#           "height": "60",
#           "width" : "100",
#           "url" : "https://thebridge.in/images/logo.png"
#     }
#   }
#   </script>
#   <div id="fb-root">
#   </div>
#   <div id="content-style">
#   </div>
#   <div class="ui-loader-new hide">
#   </div>
#   <div class="hide" id="left-ad-full-screen">
#   </div>
#   <div class="hide" id="right-ad-full-screen">
#   </div>
#   <div class="hide" id="generic_ad_block_before">
#   </div>
#   <div class="" data-cdnurl="" data-contentid="" data-ismobile="" data-logging-enabled="" data-newsid="" data-partner="thebridge" data-path="/" data-query-partner="thebridge" data-query-root="thebridge.in" data-query-sessionid="RDWEBC0MGOFOMALRAIFUR0HCZZJQUIM5WI1KT" data-registration-mode="undefined" data-root="https://thebridge.in" data-sessionid="RDWEBC0MGOFOMALRAIFUR0HCZZJQUIM5WI1KT" data-userid="" has-ga-store-key="" id="content">
#    <div class="before_content_mask">
#    </div>
#    <div>
#     <header>
#      <div class="tp-header1">
#       <div class="header-tp-strip">
#        <div class="container">
#         <div class="row">
#          <div class="col-sm-2">
#          </div>
#          <div class="col-sm-8">
#           <div class="" data-name="syncHtmlContent" id="top_black_banner">
#            <div class="html_content_wrapper">
#             <div class="bd-latest-news date-event-timer" data-event-date="2021-07-23">
#              <div>
#               <span class="bd-gamename">
#                TOKYO Olympics
#               </span>
#              </div>
#              <div class="bd-time-report">
#               <div class="bd-time-meter-wrapp">
#                <div class="bd-time-flex">
#                 <div class="bd-time-no days">
#                 </div>
#                 <span class="bd-t-sep">
#                  :
#                 </span>
#                </div>
#                <div class="bd-time-sp">
#                 Days
#                </div>
#               </div>
#               <div class="bd-time-meter-wrapp">
#                <div class="bd-time-flex">
#                 <div class="bd-time-no hours">
#                 </div>
#                 <span class="bd-t-sep">
#                  :
#                 </span>
#                </div>
#                <div class="bd-time-sp">
#                 Hrs
#                </div>
#               </div>
#               <div class="bd-time-meter-wrapp">
#                <div class="bd-time-flex">
#                 <div class="bd-time-no mins">
#                 </div>
#                 <span class="bd-t-sep">
#                  :
#                 </span>
#                </div>
#                <div class="bd-time-sp">
#                 Min
#                </div>
#               </div>
#               <div class="bd-time-meter-wrapp">
#                <div class="bd-time-flex">
#                 <div class="bd-time-no secs">
#                 </div>
#                 <span class="bd-t-sep">
#                 </span>
#                </div>
#                <div class="bd-time-sp">
#                 Sec
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="col-sm-2">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="tp-header2">
#       <div class="tp-header2-wrapp">
#        <div class="container">
#         <div class="row bd-headerflex">
#          <div class="col-xs-5 col-sm-5 col-md-2 col-lg-2">
#           <a href="/">
#            <img class="tplogoimg" src="/images/logo.png"/>
#           </a>
#          </div>
#          <div class="col-sm-7 d-hide col-md-8 col-lg-8">
#           <div class="bd-menu-box">
#            <ul class="bd-menu-ul">
#             <li class="bd-menu-li megali">
#              <a class="bd-menu-click active" href="/">
#               Home
#              </a>
#             </li>
#             <li class="bd-menu-li megali no-child">
#              <a class="bd-menu-click" href="/athletics">
#               Athletics
#              </a>
#             </li>
#             <li class="bd-menu-li megali no-child">
#              <a class="bd-menu-click" href="/badminton">
#               Badminton
#              </a>
#             </li>
#             <li class="bd-menu-li megali no-child">
#              <a class="bd-menu-click" href="/hockey">
#               Hockey
#              </a>
#             </li>
#             <li class="bd-menu-li megali no-child">
#              <a class="bd-menu-click" href="/shooting">
#               Shooting
#              </a>
#             </li>
#             <li class="bd-menu-li megali no-child">
#              <a class="bd-menu-click" href="/wrestling">
#               Wrestling
#              </a>
#             </li>
#             <li class="bd-menu-li megali no-child">
#              <a class="bd-menu-click" href="/weightlifting">
#               Weightlifting
#              </a>
#             </li>
#             <li class="bd-menu-li megali no-child">
#              <a class="bd-menu-click" href="/videos">
#               Videos
#              </a>
#             </li>
#             <li class="bd-menu-li megali has-child">
#              <a class="bd-menu-click">
#               Originals
#               <span class="fa fa-angle-down">
#               </span>
#              </a>
#              <div class="bd-dropwrapp">
#               <ul class="bd-dropdownul">
#                <li class="bd-dropdownli">
#                 <a class="bd-menu-click" href="/players-speak">
#                  <span class="bd-drpdwn-txt">
#                   Players Speak
#                  </span>
#                 </a>
#                </li>
#                <li class="bd-dropdownli">
#                 <a class="bd-menu-click" href="/coachs-corner">
#                  <span class="bd-drpdwn-txt">
#                   Coach's Corner
#                  </span>
#                 </a>
#                </li>
#                <li class="bd-dropdownli">
#                 <a class="bd-menu-click" href="/forgotten-heroes">
#                  <span class="bd-drpdwn-txt">
#                   Forgotten Heroes
#                  </span>
#                 </a>
#                </li>
#                <li class="bd-dropdownli">
#                 <a class="bd-menu-click" href="/from-the-grassroots">
#                  <span class="bd-drpdwn-txt">
#                   From The Grassroots
#                  </span>
#                 </a>
#                </li>
#                <li class="bd-dropdownli">
#                 <a class="bd-menu-click" href="/law-in-sports">
#                  <span class="bd-drpdwn-txt">
#                   Law in Sports
#                  </span>
#                 </a>
#                </li>
#                <li class="bd-dropdownli">
#                 <a class="bd-menu-click" href="/sports-market">
#                  <span class="bd-drpdwn-txt">
#                   Sports Market
#                  </span>
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </li>
#             <li class="bd-menu-li megali has-child split_menu">
#              <a class="bd-menu-click">
#               More
#               <span class="fa fa-angle-down">
#               </span>
#              </a>
#              <div class="bd-megadropdown">
#               <div class="bd-megadropul">
#                <div class="row">
#                 <div class="col-sm-6">
#                  <div class="row">
#                   <div class="col-sm-12">
#                    <h5 class="bd-megah5">
#                     <a href="/">
#                      Sports
#                     </a>
#                    </h5>
#                   </div>
#                   <div class="col-sm-6">
#                    <ul class="bd-megaul">
#                     <li class="bd-megali">
#                      <a href="/cricket">
#                       Cricket
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/para-sports">
#                       Para Sports
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/football">
#                       Football
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/boxing">
#                       Boxing
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/motorsport">
#                       Motorsport
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/squash">
#                       Squash
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/table-tennis">
#                       Table Tennis
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/gymnastics">
#                       Gymnastics
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/baseball">
#                       Baseball
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/basketball">
#                       Basketball
#                      </a>
#                     </li>
#                    </ul>
#                   </div>
#                   <div class="col-sm-6">
#                    <ul class="bd-megaul">
#                     <li class="bd-megali">
#                      <a href="/cycling">
#                       Cycling
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/kho-kho">
#                       Kho Kho
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/chess">
#                       Chess
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/golf">
#                       Golf
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/kabaddi">
#                       Kabaddi
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/swimming">
#                       Swimming
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/archery">
#                       Archery
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/rowing">
#                       Rowing
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/card-games">
#                       Card Games
#                      </a>
#                     </li>
#                    </ul>
#                   </div>
#                  </div>
#                 </div>
#                 <div class="col-sm-6">
#                  <div class="row">
#                   <div class="col-sm-12">
#                    <h5 class="bd-megah5">
#                     <a href="/">
#                      States
#                     </a>
#                    </h5>
#                   </div>
#                   <div class="col-sm-4">
#                    <ul class="bd-megaul">
#                     <li class="bd-megali">
#                      <a href="/tamil-nadu">
#                       Tamil Nadu
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/andhra-pradesh">
#                       Andhra
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/bihar">
#                       Bihar
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/punjab">
#                       Punjab
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/west-bengal">
#                       West Bengal
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/telangana">
#                       Telangana
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/gujarat">
#                       Gujarat
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/manipur">
#                       Manipur
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/karnataka">
#                       Karnataka
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/kerala">
#                       Kerala
#                      </a>
#                     </li>
#                    </ul>
#                   </div>
#                   <div class="col-sm-4">
#                    <ul class="bd-megaul">
#                     <li class="bd-megali">
#                      <a href="/rajasthan">
#                       Rajasthan
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/haryana">
#                       Haryana
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/maharashtra">
#                       Maharashtra
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/uttar-pradesh">
#                       U.P.
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/madhya-pradesh">
#                       M.P.
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/himachal-pradesh">
#                       Himachal Pradesh
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/delhi">
#                       Delhi
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/assam">
#                       Assam
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/odisha">
#                       Odisha
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/jammu-and-kashmir">
#                       J &amp; K
#                      </a>
#                     </li>
#                    </ul>
#                   </div>
#                   <div class="col-sm-4">
#                    <ul class="bd-megaul">
#                     <li class="bd-megali">
#                      <a href="/arunachal-pradesh">
#                       Arunachal Pradesh
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/chhattisgarh">
#                       Chhattisgarh
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/goa">
#                       Goa
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/jharkhand">
#                       Jharkhand
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/meghalaya">
#                       Meghalaya
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/mizoram">
#                       Mizoram
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/nagaland">
#                       Nagaland
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/sikkim">
#                       Sikkim
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/tripura">
#                       Tripura
#                      </a>
#                     </li>
#                     <li class="bd-megali">
#                      <a href="/uttarakhand">
#                       Uttarakhand
#                      </a>
#                     </li>
#                    </ul>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="col-xs-7 col-sm-7 col-md-2 col-lg-2">
#           <div class="bd-right-box">
#            <div class="hide" id="right_header_link_desk_before_search">
#            </div>
#            <span class="bd-search">
#             <a class="fa fa-search search-btn">
#             </a>
#            </span>
# ...
#           if(!rafFound){
#             window.setTimeout(loadDeferredStylesPart1, 0);
#           }
#           window.setTimeout(loadDeferredStylesPart2, window.scriptLoadDelay);
#
#         });
#     } else {
#         window.attachEvent('load', function() {
#           if(!rafFound){
#               window.setTimeout(loadDeferredStylesPart1, 0);
#           }
#             window.setTimeout(loadDeferredStylesPart2, window.scriptLoadDelay);
#         });
#
#     }
#   } else {
#     if(window.addEventListener){
#         window.addEventListener('load', function() {
#             window.setTimeout(loadDeferredStyles, window.scriptLoadDelay);
#
#         });
#     } else {
#         window.attachEvent('load', function() {
#             window.setTimeout(loadDeferredStyles, window.scriptLoadDelay);
#         });
#
#     }
#   }
#
# } else {
#   var raf = requestAnimationFrame || mozRequestAnimationFrame ||
#       webkitRequestAnimationFrame || msRequestAnimationFrame;
#   if (raf) raf(function() { window.setTimeout(loadDeferredStyles, 0); });
#   else window.addEventListener('load', loadDeferredStyles);
# }
#   </script>
#   <script override-script="true">
#    window.allScriptsTemplate = [{"id":"5254","end_point":"","link":"/latest","description":"","request_params":"","element_type":"CONTENT","is_sync":"false","content":"%3Cdiv%20class%3D%22ad_unit_wrapper%20track-click%20tp-ads%22%3E%20%20%3Cscript%20async%20src%3D%22https%3A%2F%2Fpagead2.googlesyndication.com%2Fpagead%2Fjs%2Fadsbygoogle.js%22%3E%3C%2Fscript%3E%20%20%3C!--%20level_1_right_home%20--%3E%20%20%3Cins%20class%3D%22adsbygoogle%22%20%20%20%20%20%20%20style%3D%22display%3Ablock%22%20%20%20%20%20%20%20data-ad-client%3D%22ca-pub-6736724849126886%22%20%20%20%20%20%20%20data-ad-slot%3D%221683142752%22%20%20%20%20%20%20%20data-ad-format%3D%22auto%22%20%20%20%20%20%20%20data-full-width-responsive%3D%22true%22%3E%3C%2Fins%3E%20%20%3Cscript%3E%20%20%20%20%20%20%20(adsbygoogle%20%3D%20window.adsbygoogle%20%7C%7C%20%5B%5D).push(%7B%7D)%3B%20%20%3C%2Fscript%3E%20%20%3C%2Fdiv%3E","extraIconCss":"fa-bullhorn","mixin_params":"undefined","displayHeading":"","content_type":"AD","election_content_type":"party","newsCount":"10","theme":"theme_sport","state":"LIVE","generic_content_type":"null","is_visible":"true","heading":"Home Page Right Skyscraper","mixinName":"newsLinks","element_id":"level_1_right","electionId":"null","adId":"null","page":"home","param_name":"","data_partner":"thebridge","categoryId":"349","default_content":"","extra_css":""},{"id":"5256","end_point":"","link":"/videos","description":"","request_params":"","element_type":"CONTENT","is_sync":"false","content":"","extraIconCss":"fa-play","mixin_params":"undefined","displayHeading":"","content_type":"CATEGORY_NEWS","election_content_type":"party","newsCount":"10","theme":"theme_sport","state":"LIVE","generic_content_type":"null","is_visible":"true","heading":"Latest Videos","mixinName":"smallSingleSlider","element_id":"level_3_right","electionId":"null","adId":"null","page":"home","param_name":"","data_partner":"thebridge","categoryId":"345","default_content":"","extra_css":"","merged-in-sync":true},{"id":"5259","end_point":"","link":"/featured","description":"","request_params":"","element_type":"CONTENT","is_sync":"false","content":"","mixin_params":"","displayHeading":"","content_type":"CATEGORY_NEWS","election_content_type":"party","newsCount":"4","theme":"theme_sport","state":"LIVE","generic_content_type":"null","is_visible":"true","heading":"","mixinName":"firstBigBottomListAndRightLinks","element_id":"level_3_mid","electionId":"null","adId":"null","page":"home","param_name":"","data_partner":"thebridge","categoryId":"240","default_content":"","extra_css":"","merged-in-sync":true},{"id":"5261","end_point":"","link":"/forgotten-heroes","description":"","request_params":"","element_type":"CONTENT","is_sync":"false","content":"","mixin_params":"","displayHeading":"","content_type":"CATEGORY_NEWS","election_content_type":"party","newsCount":"1","theme":"theme_sport","state":"LIVE","generic_content_type":"null","is_visible":"true","heading":"Forgotten Heroes","mixinName":"verticalImageListing","element_id":"level_10_right","electionId":"null","adId":"null","page":"home","param_name":"","data_partner":"thebridge","categoryId":"244","default_content":"","extra_css":"","merged-in-sync":true},{"id":"5262","end_point":"","link":"","description":"","request_params":"","element_type":"CONTENT","is_sync":"false","content":"%3Cdiv%20class%3D%22bd-trend-news%20bd-featured%22%3E%20%20%20%20%20%20%09%09%09%09%09%09%09%3Cdiv%20class%3D%22bd-head-wrapp%22%3E%20%20%20%20%20%20%09%09%09%09%09%09%09%09%3Cspan%20class%3D%22fa%20fa-paper-plane%22%3E%3C%2Fspan%3E%20%3Cspan%20class%3D%22bd-tr-head%22%3EFeatured%20Sports%3C%2Fspan%3E%20%20%20%20%20%20%09%09%09%09%09%09%09%3C%2Fdiv%3E%20%20%20%20%20%20%09%09%09%09%09%09%09%3Cdiv%20class%3D%22bd-featured-sport%22%3E%20%20%20%20%20%20%09%09%09%09%09%09%09%09%3Cul%20class%3D%22bd-featur-ul%22%3E%20%20%20%20%20%20%09%09%09%09%09%09%09%09%09%3Cli%20class%3D%22bd-featur-li%22%3E%20%20%20%20%20%20%09%09%09%09%09%09%09%09%09%09%3Ca%20href%3D%22%23 ...
#   </script>
#   <div class="mfp-hide" id="small-dialog">
#   </div>
#   <div id="floating-extra-container">
#   </div>
#   <div class="hide" id="fixed-bottom-content">
#   </div>
#   <div id="hidden_element_for_width">
#   </div>
#   <div id="hidden_element_for_desktop">
#   </div>
#   <div id="hidden_element_for_tablet_pro">
#   </div>
#   <div id="hidden_element_for_tablet">
#   </div>
#   <div class="hide" id="body_bottom_sync">
#   </div>
#   <div class="hide" id="after_everything">
#   </div>
#   <style>
#    #hidden_element_for_desktop {
#     display:block;
#     height:0px;
# }
# #hidden_element_for_tablet_pro {
#     display:none;
# }
# #hidden_element_for_tablet {
#     display:none;
#     height:0px;
# }
#
# @media(max-width:999px ){
#     #hidden_element_for_width {
#         display:none;
#     }
# }
# @media(min-width:1000px ){
#     #hidden_element_for_width {
#         display:block;
#         height:0px;
#     }
# }
# @media(max-width:1191px){
#     #hidden_element_for_desktop {
#         display:none;
#     }
#     #hidden_element_for_tablet {
#         display:none;
#     }
#     #hidden_element_for_tablet_pro {
#         display:block;
#     }
# }
# @media(max-width:767px){
#     #hidden_element_for_desktop {
#         display:none;
#     }
#     #hidden_element_for_tablet_pro {
#         display:none;
#     }
#     #hidden_element_for_tablet {
#         display:block;
#     }
# }
# @media(max-width:479px){
#     #hidden_element_for_desktop {
#         display:none;
#     }
#     #hidden_element_for_tablet_pro {
#         display:none;
#     }
#     #hidden_element_for_tablet {
#         display:none;
#     }
# }
#   </style>
#   <div aria-hidden="true" class="pswp hide" id="gallery" role="dialog" tabindex="-1">
#    <div class="pswp__bg">
#    </div>
#    <div class="pswp__scroll-wrap">
#     <div class="pswp__container">
#      <div class="pswp__item">
#      </div>
#      <div class="pswp__item">
#      </div>
#      <div class="pswp__item">
#      </div>
#     </div>
#     <div class="pswp__ui pswp__ui--hidden">
#      <div class="pswp__top-bar">
#       <div class="pswp__counter">
#       </div>
#       <button class="pswp__button pswp__button--close" title="Close (Esc)">
#       </button>
#       <button class="pswp__button pswp__button--share" title="Share">
#       </button>
#       <button class="pswp__button pswp__button--fs" title="Toggle fullscreen">
#       </button>
#       <button class="pswp__button pswp__button--zoom" title="Zoom in/out">
#       </button>
#       <div class="pswp__preloader">
#        <div class="pswp__preloader__icn">
#         <div class="pswp__preloader__cut">
#          <div class="pswp__preloader__donut">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="pswp__share-modal pswp__share-modal--hidden pswp__single-tap">
#       <div class="pswp__share-tooltip">
#       </div>
#      </div>
#      <button class="pswp__button pswp__button--arrow--left" title="Previous (arrow left)">
#      </button>
#      <button class="pswp__button pswp__button--arrow--right" title="Next (arrow right)">
#      </button>
#      <div class="pswp__caption">
#       <div class="pswp__caption__center">
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <style>
#    .roadblocker-ad-content-wrap .popup-content-container .center-content{
# 	margin-top:0px;
# }
#   </style>
#   <script type="text/javascript">
#    window.checkForAdBlockerGA = function(code){
#     if(window.ga && code=="1"){
#         console.log("sending GA event for adblock");
#         window.ga('common.send', 'event',"ad-block","detected","thebridge");
#         window.ga('common2.send', 'event',"ad-block","detected","thebridge");
#     }
# }
#   </script>
#   <script async="" onerror="window.checkForAdBlockerGA('1')" onload="window.checkForAdBlockerGA('0')" src="/scripts/adsbyhocalwiretest.js" type="text/javascript">
#   </script>
#   <div id="MODAL_DIALOG_PLACEHOLDER">
#   </div>
#   <div id="generic_style_body_bottom">
#   </div>
#   <div id="async_body_tags">
#   </div>
#   <div id="async_body_tags_2">
#   </div>
#   <div class="bottom_snackbar_common" id="bottom_snackbar">
#    <div id="bottom_snackbar_content">
#    </div>
#   </div>
#   <div class="hide" id="bottom_element_for_popup">
#   </div>
#   <div class="popup-ad-content-wrap hide exclude-font-change">
#    <div class="popup-overlay-bg">
#    </div>
#    <div class="popup-content-container exclude-font-change">
#     <div class="center-content exclude-font-change">
#      <div class="content-box exclude-font-change hocal-ad-block hide" id="POPUP_AD_CONTENT">
#      </div>
#      <div class="close-btn-popup">
#       X
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="roadblocker-ad-content-wrap exclude-font-change hide">
#    <div class="popup-overlay-bg">
#    </div>
#    <div class="popup-content-container exclude-font-change">
#     <div class="road-blocker-timer">
#     </div>
#     <div class="close-btn-popup">
#      X
#     </div>
#     <div class="center-content exclude-font-change">
#      <div class="content-box exclude-font-change hocal-ad-block hide" id="ROADBLOCKER_AD_CONTENT">
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    window.externalFunction = window.externalFunction || {};
#   </script>
#   <script>
#    window.externalFunction['loadScripts'+new Date().getTime()+"-"+Math.floor((Math.random()*10000))] = function() {
#     window.Utils.loadScripts('https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?v=1'.split(","),{'callback':function(){
#         var event = new CustomEvent("EXTERNAL_RESOURCES_LOADED", { "detail": 'https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js'.split(",")});
#         document.dispatchEvent(event);
#         if(window['']){
#             window['']();
#         }
#     }});
# };
# document.addEventListener("ALL_RESOURCE_HTML_LOADED", function(e) {
#     for(var k in window.externalFunction){
#         if(window.externalFunction[k] && !window.externalFunction[k].loaded){
#             window.externalFunction[k].loaded=true;
#             window.externalFunction[k]();
#         }
#     }
#
#
# });
# if(window.insertLoadTriggered){
#     for(var k in window.externalFunction){
#         if(window.externalFunction[k] && !window.externalFunction[k].loaded){
#             window.externalFunction[k].loaded=true;
#             window.externalFunction[k]();
#         }
#     }
# }
#   </script>
#   <script>
#    window.externalFunction = window.externalFunction || {};
#   </script>
#   <script>
#    window.externalFunction['loadScripts'+new Date().getTime()+"-"+Math.floor((Math.random()*10000))] = function() {
#     window.Utils.loadScripts('https://www.instagram.com/embed.js?v=1'.split(","),{'callback':function(){
#         var event = new CustomEvent("EXTERNAL_RESOURCES_LOADED", { "detail": 'https://www.instagram.com/embed.js'.split(",")});
#         document.dispatchEvent(event);
#         if(window['']){
#             window['']();
#         }
#     }});
# };
# document.addEventListener("ALL_RESOURCE_HTML_LOADED", function(e) {
#     for(var k in window.externalFunction){
#         if(window.externalFunction[k] && !window.externalFunction[k].loaded){
#             window.externalFunction[k].loaded=true;
#             window.externalFunction[k]();
#         }
#     }
#
#
# });
# if(window.insertLoadTriggered){
#     for(var k in window.externalFunction){
#         if(window.externalFunction[k] && !window.externalFunction[k].loaded){
#             window.externalFunction[k].loaded=true;
#             window.externalFunction[k]();
#         }
#     }
# }
#   </script>
#   <script>
#    window.externalFunction = window.externalFunction || {};
#   </script>
#   <script>
#    window.externalFunction['loadScripts'+new Date().getTime()+"-"+Math.floor((Math.random()*10000))] = function() {
#     window.Utils.loadScripts('https://securepubads.g.doubleclick.net/tag/js/gpt.js?v=1'.split(","),{'callback':function(){
#         var event = new CustomEvent("EXTERNAL_RESOURCES_LOADED", { "detail": 'https://securepubads.g.doubleclick.net/tag/js/gpt.js'.split(",")});
#         document.dispatchEvent(event);
#         if(window['']){
#             window['']();
#         }
#     }});
# };
# document.addEventListener("ALL_RESOURCE_HTML_LOADED", function(e) {
#     for(var k in window.externalFunction){
#         if(window.externalFunction[k] && !window.externalFunction[k].loaded){
#             window.externalFunction[k].loaded=true;
#             window.externalFunction[k]();
#         }
#     }
#
#
# });
# if(window.insertLoadTriggered){
#     for(var k in window.externalFunction){
#         if(window.externalFunction[k] && !window.externalFunction[k].loaded){
#             window.externalFunction[k].loaded=true;
#             window.externalFunction[k]();
#         }
#     }
# }
#   </script>
#   <script>
#    window.externalFunction = window.externalFunction || {};
#   </script>
#   <script>
#    window.externalFunction['loadScripts'+new Date().getTime()+"-"+Math.floor((Math.random()*10000))] = function() {
#     window.Utils.loadScripts('https://platform.twitter.com/widgets.js?v=1'.split(","),{'callback':function(){
#         var event = new CustomEvent("EXTERNAL_RESOURCES_LOADED", { "detail": 'https://platform.twitter.com/widgets.js'.split(",")});
#         document.dispatchEvent(event);
#         if(window['']){
#             window['']();
#         }
#     }});
# };
# document.addEventListener("ALL_RESOURCE_HTML_LOADED", function(e) {
#     for(var k in window.externalFunction){
#         if(window.externalFunction[k] && !window.externalFunction[k].loaded){
#             window.externalFunction[k].loaded=true;
#             window.externalFunction[k]();
#         }
#     }
#
#
# });
# if(window.insertLoadTriggered){
#     for(var k in window.externalFunction){
#         if(window.externalFunction[k] && !window.externalFunction[k].loaded){
#             window.externalFunction[k].loaded=true;
#             window.externalFunction[k]();
#         }
#     }
# }
#   </script>
#   <script>
#    window.externalFunction = window.externalFunction || {};
#   </script>
#   <script>
#    window.externalFunction['loadScripts'+new Date().getTime()+"-"+Math.floor((Math.random()*10000))] = function() {
#     window.Utils.loadScripts('https://rtbcdn.andbeyond.media/prod-global-552101.js?v=1'.split(","),{'callback':function(){
#         var event = new CustomEvent("EXTERNAL_RESOURCES_LOADED", { "detail": 'https://rtbcdn.andbeyond.media/prod-global-552101.js'.split(",")});
#         document.dispatchEvent(event);
#         if(window['']){
#             window['']();
#         }
#     }});
# };
# document.addEventListener("ALL_RESOURCE_HTML_LOADED", function(e) {
#     for(var k in window.externalFunction){
#         if(window.externalFunction[k] && !window.externalFunction[k].loaded){
#             window.externalFunction[k].loaded=true;
#             window.externalFunction[k]();
#         }
#     }
#
#
# });
# if(window.insertLoadTriggered){
#     for(var k in window.externalFunction){
#         if(window.externalFunction[k] && !window.externalFunction[k].loaded){
#             window.externalFunction[k].loaded=true;
#             window.externalFunction[k]();
#         }
#     }
# }
#   </script>
#   <div class="tooltip-wall">
#   </div>
#  </body>
# </html>

# %%
print(soup2.prettify())
# Out:
# <html class="b-reith-sans-font" lang="en-GB">
#  <head>
#   <script>
#    window.Morph = {}
#   </script>
#   <script type="text/javascript">
#    Morph.markPerformance = function(label) { if(window.performance && window.performance.mark) { window.performance.mark(label); } }; Morph.versions = {}; Morph.modules = {}; Morph.config = { cdn: "m.files.bbci.co.uk", pushEnv: "live" }; Morph.styles = {}; Morph.styleSrc = []; Morph.toInit = {bundles: [], registers: [], payloads: []};   Morph.initStyles = function() { if (!Morph.enhanced) { var eles = Array.prototype.slice.call(document.getElementsByTagName('noscript')); for (var i = 0, len = eles.length; i<len; i++) { if (eles[i].className === 'morph-core-style') { document.write(eles[i].innerText); eles[i].parentNode.removeChild(eles[i]); } } return; } for (var j = 0, jLen = Morph.styleSrc.length; j<jLen; j++) { document.write(Morph.styleSrc[j]); } Morph.styleSrc = []; };
#   </script>
#   <script type="text/javascript">
#    Morph.forceCore = window.location.search.indexOf('morph-disable-enhanced=1')>-1; Morph.modernBrowser = ( 'addEventListener' in window && 'querySelector' in document && 'localStorage' in window ); Morph.isOperaMini = ( window.navigator.userAgent.indexOf('Opera Mini/')>-1 && window.navigator.userAgent.indexOf('Presto/')>-1 ); Morph.enhanced = (!Morph.forceCore && Morph.modernBrowser && !Morph.isOperaMini);
#   </script>
#   <!--[if gt IE 8]><!-->
#   <noscript class="morph-core-style">
#    <!--<![endif]-->
#    <style>
#     body{background-color:#fff;color:#121212}#orb-modules{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box}#orb-modules *,#orb-modules *:before,#orb-modules *:after{-webkit-box-sizing:inherit;-moz-box-sizing:inherit;box-sizing:inherit}/*! normalize.css v5.0.0 | MIT License | github.com/necolas/normalize.css */html{font-family:sans-serif;line-height:1.15;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}article,aside,footer,header,nav,section{display:block}h1{font-size:2em;margin:0.67em 0}figcaption,figure,main{display:block}figure{margin:1em 40px}hr{box-sizing:content-box;height:0;overflow:visible}pre{font-family:monospace, monospace;font-size:1em}a{background-color:transparent;-webkit-text-decoration-skip:objects}a:active,a:hover{outline-width:0}b,strong{font-weight:inherit}b,strong{font-weight:bolder}code,kbd,samp{font-family:monospace, monospace;font-size:1em}dfn{font-style:italic}mark{background-color:#ff0;color:#000}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sub{bottom:-0.25em}sup{top:-0.5em}audio,video{display:inline-block}audio:not([controls]){display:none;height:0}img{border-style:none}svg:not(:root){overflow:hidden}button,input,optgroup,select,textarea{font-family:inherit;font-size:100%;line-height:1.15;margin:0}button,input{overflow:visible}button,select{text-transform:none}button,html [type="button"],[type="reset"],[type="submit"]{-webkit-appearance:button}button::-moz-focus-inner,[type="button"]::-moz-focus-inner,[type="reset"]::-moz-focus-inner,[type="submit"]::-moz-focus-inner{border-style:none;padding:0}button:-moz-focusring,[type="button"]:-moz-focusring,[type="reset"]:-moz-focusring,[type="submit"]:-moz-focusring{outline:1px dotted ButtonText}fieldset{border:1px solid #c0c0c0;margin:0 2px;padding:0.35em 0.625em 0.75em}legend{box-sizing:border-box;color:inherit;display:table;max-width:100%;padding:0;white-space:normal}progress{display:inline-block;vertical-align:baseline}textarea{overflow:auto}[type="checkbox"],[type="radio"]{box-sizing:border-box;padding:0}[type="number"]::-webkit-inner-spin-button,[type="number"]::-webkit-outer-spin-button{height:auto}[type="search"]{-webkit-appearance:textfield;outline-offset:-2px}[type="search"]::-webkit-search-cancel-button,[type="search"]::-webkit-search-decoration{-webkit-appearance:none}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}details,menu{display:block}summary{display:list-item}canvas{display:inline-block}template{display:none}[hidden]{display:none}body,h1,h2,h3,h4,h5,h6,p,blockquote,pre,dl,dd,ol,ul,form,fieldset,legend,figure,table,th,td,caption,hr{margin:0;padding:0}u,ins{text-decoration:none}ins{border-bottom:1px solid}h1,h2,h3,h4,h5,h6{font-weight:inherit}table{border-collapse:collapse;border-spacing:0}th{font-weight:normal}abbr[title]{text-decoration:none;border-bottom:0 !important;cursor:inherit !important}a{text-decoration:none;color:inherit}button{border-radius:0;font:inherit;cursor:pointer}.sp-o-tag{display:inline;padding:2px;line-height:1;text-align:center;text-transform:uppercase}.sp-o-tag--pre-event{background-color:#dbdbdb}.sp-o-tag--post-event{background-color:#ffd230}.sp-o-tag--live{background-color:#2866f6;color:#fff}.sp-o-link{text-decoration:none}.sp-o-link:visited{color:#5a5a5a}.sp-o-link:hover,.sp-o-link:focus{color:#255aa9;text-decoration:underline}.sp-o-link-split__anchor{text-decoration:none}.sp-o-link-split__anchor:visited .sp-o-link-split__text{color:#5a5a5a}.sp-o-link-split__anchor:hover .sp-o-link-split__text,.sp-o-link-split__anchor:focus .sp-o-link-split__text{color:#255aa9;text-decoration:underline}.sp-o-link--on-dark:visited{color:#f7f7f5}.sp-o-link--on-dark:hover,.sp-o-link--on-dark:focus{color:#b6e1f9;text-decoration:underline}.sp-o-link-split__anchor:visited .sp-o-link-split__text--on-dark{color:#f7f7f5}.sp-o-link-split__anchor:hover .sp-o-link-split__text--on-dark,.sp-o-link-split__anchor:focus .sp-o-link ...
#    </style>
#    <!--[if gt IE 8]><!-->
#   </noscript>
#   <!--<![endif]-->
#   <script>
#    if (Morph.enhanced) { Morph.styles["bbc-morph-sport-core-styles/1.3.0"]=true; Morph.styleSrc.push("<style>body{background-color:#fff;color:#121212}#orb-modules{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box}#orb-modules *,#orb-modules *:before,#orb-modules *:after{-webkit-box-sizing:inherit;-moz-box-sizing:inherit;box-sizing:inherit}/*! normalize.css v5.0.0 | MIT License | github.com/necolas/normalize.css */html{font-family:sans-serif;line-height:1.15;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}article,aside,footer,header,nav,section{display:block}h1{font-size:2em;margin:0.67em 0}figcaption,figure,main{display:block}figure{margin:1em 40px}hr{box-sizing:content-box;height:0;overflow:visible}pre{font-family:monospace, monospace;font-size:1em}a{background-color:transparent;-webkit-text-decoration-skip:objects}a:active,a:hover{outline-width:0}b,strong{font-weight:inherit}b,strong{font-weight:bolder}code,kbd,samp{font-family:monospace, monospace;font-size:1em}dfn{font-style:italic}mark{background-color:#ff0;color:#000}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sub{bottom:-0.25em}sup{top:-0.5em}audio,video{display:inline-block}audio:not([controls]){display:none;height:0}img{border-style:none}svg:not(:root){overflow:hidden}button,input,optgroup,select,textarea{font-family:inherit;font-size:100%;line-height:1.15;margin:0}button,input{overflow:visible}button,select{text-transform:none}button,html [type=\"button\"],[type=\"reset\"],[type=\"submit\"]{-webkit-appearance:button}button::-moz-focus-inner,[type=\"button\"]::-moz-focus-inner,[type=\"reset\"]::-moz-focus-inner,[type=\"submit\"]::-moz-focus-inner{border-style:none;padding:0}button:-moz-focusring,[type=\"button\"]:-moz-focusring,[type=\"reset\"]:-moz-focusring,[type=\"submit\"]:-moz-focusring{outline:1px dotted ButtonText}fieldset{border:1px solid #c0c0c0;margin:0 2px;padding:0.35em 0.625em 0.75em}legend{box-sizing:border-box;color:inherit;display:table;max-width:100%;padding:0;white-space:normal}progress{display:inline-block;vertical-align:baseline}textarea{overflow:auto}[type=\"checkbox\"],[type=\"radio\"]{box-sizing:border-box;padding:0}[type=\"number\"]::-webkit-inner-spin-button,[type=\"number\"]::-webkit-outer-spin-button{height:auto}[type=\"search\"]{-webkit-appearance:textfield;outline-offset:-2px}[type=\"search\"]::-webkit-search-cancel-button,[type=\"search\"]::-webkit-search-decoration{-webkit-appearance:none}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}details,menu{display:block}summary{display:list-item}canvas{display:inline-block}template{display:none}[hidden]{display:none}body,h1,h2,h3,h4,h5,h6,p,blockquote,pre,dl,dd,ol,ul,form,fieldset,legend,figure,table,th,td,caption,hr{margin:0;padding:0}u,ins{text-decoration:none}ins{border-bottom:1px solid}h1,h2,h3,h4,h5,h6{font-weight:inherit}table{border-collapse:collapse;border-spacing:0}th{font-weight:normal}abbr[title]{text-decoration:none;border-bottom:0 !important;cursor:inherit !important}a{text-decoration:none;color:inherit}button{border-radius:0;font:inherit;cursor:pointer}.sp-o-tag{display:inline;padding:2px;line-height:1;text-align:center;text-transform:uppercase}.sp-o-tag--pre-event{background-color:#dbdbdb}.sp-o-tag--post-event{background-color:#ffd230}.sp-o-tag--live{background-color:#2866f6;color:#fff}.sp-o-link{text-decoration:none}.sp-o-link:visited{color:#5a5a5a}.sp-o-link:hover,.sp-o-link:focus{color:#255aa9;text-decoration:underline}.sp-o-link-split__anchor{text-decoration:none}.sp-o-link-split__anchor:visited .sp-o-link-split__text{color:#5a5a5a}.sp-o-link-split__anchor:hover .sp-o-link-split__text,.sp-o-link-split__anchor:focus .sp-o-link-split__text{color:#255aa9;text-decoration:underline}.sp-o-link--on-dark:visited{color:#f7f7f5}.sp-o-link--on-dark:hover,.sp-o-link--on-dark:focus{color:#b6e1f9;text-decoration:underline}.sp-o-link-split__anchor:visited .sp-o-link-sp ...
#   </script>
#   <script type="text/javascript">
#    Morph.initStyles(); /* u7387539684810481 */
#   </script>
#   <script>
#    (function(){var hasTouch="ontouchstart"in window||window.DocumentTouch&&document instanceof DocumentTouch||window.hasOwnProperty&&(window.hasOwnProperty("ontouchstart")||navigator.msMaxTouchPoints);if(!hasTouch){document.documentElement.className+=" no-touch"}})();
#   </script>
#   <script type="text/javascript">
#    var domain = "co.uk";var edition = "";var prettyEdition = edition;if (window.NewsPage && window.NewsPage.edition) {edition = window.NewsPage.edition;prettyEdition = edition === "northernireland" ? "Northern Ireland" :edition.charAt(0).toUpperCase() + edition.slice(1);}var pathEdition = edition.length > 0 ? "/?" + edition.toLowerCase() : "";var _sf_async_config = _sf_async_config || {};var _sf_startpt=(new Date()).getTime();_sf_async_config.domain = "www" + ".bbc." + domain;_sf_async_config.uid = 50924;_sf_async_config.title = window.document.title.replace("##edition##", prettyEdition);_sf_async_config.path = "bbc." + domain + "/sport" + pathEdition;_sf_async_config.sections = "sport";_sf_async_config.mobileApp = false;
#   </script>
#   <meta content="app-id=377388936, app-argument=https://www.bbc.com/sport" name="apple-itunes-app"/>
#   <meta content="BBC Sport" name="apple-mobile-web-app-title"/>
#   <meta content="BBC Sport" name="application-name"/>
#   <meta content="https://m.files.bbci.co.uk/modules/bbc-morph-sport-page-app-meta/2.1.0/images/web-icons/bbc-sport-144.png" name="msapplication-TileImage"/>
#   <meta content="#ffd230" name="theme-color"/>
#   <link href="https://m.files.bbci.co.uk/modules/bbc-morph-sport-page-app-meta/2.1.0/images/web-icons/bbc-sport-180.png" rel="apple-touch-icon"/>
#   <link href="android-app://bbc.mobile.sport.ww/https/www.bbc.com/sport" rel="alternate"/>
#   <meta content="article" property="og:type"/>
#   <meta content="BBC Sport" property="og:site_name"/>
#   <meta content="1392506827668140,137920769558355,193435954068976,118450564909230,100978706649892,15286229625,21263239760,122103087870579,120655094632228,102814153147070,124715648647,153132638110668,150467675018739,1033940569952576,857410004307950,624989267645024,1471706783148263,228735667216,317278538359186,958681370814419,260967092113,168895963122035,114010462015043,8251776107,273726292719943,232455204224,1436581493296609,8585725981,8244244903,470911516262605,413132078795966,7519460786,1470145583204829" property="fb:pages"/>
#   <meta content="https://www.bbc.co.uk/sport" property="og:url"/>
#   <link href="https://www.bbc.co.uk/sport" hreflang="en-gb" rel="alternate"/>
#   <link href="https://www.bbc.com/sport" hreflang="en" rel="alternate"/>
#   <link href="https://www.bbc.co.uk/sport" rel="canonical"/>
#   <title>
#    Home - BBC Sport
#   </title>
#   <meta content="Breaking news &amp; live sports coverage including results, video, audio and analysis on Football, F1, Cricket, Rugby Union, Rugby League, Golf, Tennis and all the main world sports, plus major events such as the Olympic Games." name="description"/>
#   <meta content="Home - BBC Sport" property="og:title"/>
#   <meta content="Breaking news &amp; live sports coverage including results, video, audio and analysis on Football, F1, Cricket, Rugby Union, Rugby League, Golf, Tennis and all the main world sports, plus major events such as the Olympic Games." property="og:description"/>
#   <meta content="https:////m.files.bbci.co.uk/modules/bbc-morph-sport-seo-meta/1.20.23/images/bbc-sport-logo.png" property="og:image"/>
#   <meta content="index" name="robots">
#    <link href="https://feeds.bbci.co.uk/sport/rss.xml" hreflang="en" rel="alternate" type="application/rss+xml"/>
#    <script>
#     window.orb_fig_blocking = true
#     window.bbcredirection = {
#         geo: true,
#         device: false
#     };
#    </script>
#    <script src="https://static.files.bbci.co.uk/orbit/86efadef229d1a4ee7019331f832e9f5//js/require.min.js">
#    </script>
#    <link href="https://static.files.bbci.co.uk/orbit/86efadef229d1a4ee7019331f832e9f5//css/orb-ltr.min.css" rel="stylesheet"/>
#    <!-- Orbit: 3.0.0-1491.8d4f1179 -->
#    <!-- Environment: live -->
#    <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#    <script>
#     // nav-orbit-pollyfills
#     // Promise polyfill from https://github.com/bramstein/promis
#     (function(){'use strict';var f,g=[];function l(a){g.push(a);1==g.length&&f()}function m(){for(;g.length;)g[0](),g.shift()}f=function(){setTimeout(m)};function n(a){this.a=p;this.b=void 0;this.f=[];var b=this;try{a(function(a){q(b,a)},function(a){r(b,a)})}catch(c){r(b,c)}}var p=2;function t(a){return new n(function(b,c){c(a)})}function u(a){return new n(function(b){b(a)})}function q(a,b){if(a.a==p){if(b==a)throw new TypeError;var c=!1;try{var d=b&&b.then;if(null!=b&&"object"==typeof b&&"function"==typeof d){d.call(b,function(b){c||q(a,b);c=!0},function(b){c||r(a,b);c=!0});return}}catch(e){c||r(a,e);return}a.a=0;a.b=b;v(a)}} function r(a,b){if(a.a==p){if(b==a)throw new TypeError;a.a=1;a.b=b;v(a)}}function v(a){l(function(){if(a.a!=p)for(;a.f.length;){var b=a.f.shift(),c=b[0],d=b[1],e=b[2],b=b[3];try{0==a.a?"function"==typeof c?e(c.call(void 0,a.b)):e(a.b):1==a.a&&("function"==typeof d?e(d.call(void 0,a.b)):b(a.b))}catch(h){b(h)}}})}n.prototype.g=function(a){return this.c(void 0,a)};n.prototype.c=function(a,b){var c=this;return new n(function(d,e){c.f.push([a,b,d,e]);v(c)})}; function w(a){return new n(function(b,c){function d(c){return function(d){h[c]=d;e+=1;e==a.length&&b(h)}}var e=0,h=[];0==a.length&&b(h);for(var k=0;k<a.length;k+=1)u(a[k]).c(d(k),c)})}function x(a){return new n(function(b,c){for(var d=0;d<a.length;d+=1)u(a[d]).c(b,c)})};window.Promise||(window.Promise=n,window.Promise.resolve=u,window.Promise.reject=t,window.Promise.race=x,window.Promise.all=w,window.Promise.prototype.then=n.prototype.c,window.Promise.prototype["catch"]=n.prototype.g);}());
#
#
#     // Polyfill Event constructor for IE ref: ORBITEN-919
#     // see: https://stackoverflow.com/questions/26596123
#     (function () {
#       if (typeof window.CustomEvent === "function") {
#         return false;
#       }
#       function CustomEvent(event, params) {
#         params = params || { bubbles: false, cancelable: false, detail: undefined };
#         var evt = document.createEvent('CustomEvent');
#         evt.initCustomEvent(event, params.bubbles, params.cancelable, params.detail);
#         return evt;
#       }
#       CustomEvent.prototype = window.Event.prototype;
#       window.Event = CustomEvent;
#     })();
#
#
#     //Element.prototype.matches polyfill
#     //from https://developer.mozilla.org/en-US/docs/Web/API/Element/matches#Polyfill
#     if (!Element.prototype.matches) {
#       Element.prototype.matches = Element.prototype.msMatchesSelector ||
#                                   Element.prototype.webkitMatchesSelector;
#     }
#     //NodeList.forEach Polyfill
#     //from https://developer.mozilla.org/en-US/docs/Web/API/NodeList/forEach#Polyfill
#     if (window.NodeList && !NodeList.prototype.forEach) {
#       NodeList.prototype.forEach = Array.prototype.forEach;
#     }
#
#     // Object.assign polyfill from https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Object/assign#Polyfill
#     if (typeof Object.assign != 'function') {
#       // Must be writable: true, enumerable: false, configurable: true
#       Object.defineProperty(Object, "assign", {
#         value: function assign(target, varArgs) { // .length of function is 2
#           'use strict';
#           if (target == null) { // TypeError if undefined or null
#             throw new TypeError('Cannot convert undefined or null to object');
#           }
#
#           var to = Object(target);
#
#           for (var index = 1; index < arguments.length; index++) {
#             var nextSource = arguments[index];
#
#             if (nextSource != null) { // Skip over if undefined or null
#               for (var nextKey in nextSource) {
#                 // Avoid bugs when hasOwnProperty is shadowed
#                 if (Object.prototype.hasOwnProperty.call(nextSource, nextKey)) {
#                   to[nextKey] = nextSource[nextKey];
#                 }
#               }
#             }
#           }
#           return to;
#         },
#         writable: true,
#         configurable: true
#       });
#     }
#
#     // window.fetch polyfill https://github.com/github/fetch/blob/v0.11.0/fetch.js - chosen for IE9 compatibility
#     if(typeof window.fetch !== 'function') {
#       (function(self){"use strict";if(self.fetch){return}function normalizeName(name){if(typeof name!=="string"){name=String(name)}if(/[^a-z0-9\-#$%&'*+.\^_`|~]/i.test(name)){throw new TypeError("Invalid character in header field name")}return name.toLowerCase()}function normalizeValue(value){if(typeof value!=="string"){value=String(value)}return value}function Headers(headers){this.map={};if(headers instanceof Headers){headers.forEach(function(value,name){this.append(name,value)},this)}else if(headers){Object.getOwnPropertyNames(headers).forEach(function(name){this.append(name,headers[name])},this)}}Headers.prototype.append=function(name,value){name=normalizeName(name);value=normalizeValue(value);var list=this.map[name];if(!list){list=[];this.map[name]=list}list.push(value)};Headers.prototype["delete"]=function(name){delete this.map[normalizeName(name)]};Headers.prototype.get=function(name){var values=this.map[normalizeName(name)];return values?values[0]:null};Headers.prototype.getAll=function(name){return this.map[normalizeName(name)]||[]};Headers.prototype.has=function(name){return this.map.hasOwnProperty(normalizeName(name))};Headers.prototype.set=function(name,value){this.map[normalizeName(name)]=[normalizeValue(value)]};Headers.prototype.forEach=function(callback,thisArg){Object.getOwnPropertyNames(this.map).forEach(function(name){this.map[name].forEach(function(value){callback.call(thisArg,value,name,this)},this)},this)};function consumed(body){if(body.bodyUsed){return Promise.reject(new TypeError("Already read"))}body.bodyUsed=true}function fileReaderReady(reader){return new Promise(function(resolve,reject){reader.onload=function(){resolve(reader.result)};reader.onerror=function(){reject(reader.error)}})}function readBlobAsArrayBuffer(blob){var reader=new FileReader;reader.readAsArrayBuffer(blob);return fileReaderReady(reader)}function readBlobAsText(blob){var reader=new FileReader;reader.readAsText(blob);return fileReaderReady(reader)}var support={blob:"FileReader"in self&&"Blob"in self&&function(){try{new Blob;return true}catch(e){return false}}(),formData:"FormData"in self,arrayBuffer:"ArrayBuffer"in self};function Body(){this.bodyUsed=false;this._initBody=function(body){this._bodyInit=body;if(typeof body==="string"){this._bodyText=body}else if(support.blob&&Blob.prototype.isPrototypeOf(body)){this._bodyBlob=body}else if(support.formData&&FormData.prototype.isPrototypeOf(body)){this._bodyFormData=body}else if(!body){this._bodyText=""}else if(support.arrayBuffer&&ArrayBuffer.prototype.isPrototypeOf(body)){}else{throw new Error("unsupported BodyInit type")}if(!this.headers.get("content-type")){if(typeof body==="string"){this.headers.set("content-type","text/plain;charset=UTF-8")}else if(this._bodyBlob&&this._bodyBlob.type){this.headers.set("content-type",this._bodyBlob.type)}}};if(support.blob){this.blob=function(){var rejected=consumed(this);if(rejected){return rejected}if(this._bodyBlob){return Promise.resolve(this._bodyBlob)}else if(this._bodyFormData){throw new Error("could not read FormData body as blob")}else{return Promise.resolve(new Blob([this._bodyText]))}};this.arrayBuffer=function(){return this.blob().then(readBlobAsArrayBuffer)};this.text=function(){var rejected=consumed(this);if(rejected){return rejected}if(this._bodyBlob){return readBlobAsText(this._bodyBlob)}else if(this._bodyFormData){throw new Error("could not read FormData body as text")}else{return Promise.resolve(this._bodyText)}}}else{this.text=function(){var rejected=consumed(this);return rejected?rejected:Promise.resolve(this._bodyText)}}if(support.formData){this.formData=function(){return this.text().then(decode)}}this.json=function(){return this.text().then(JSON.parse)};return this}var methods=["DELETE","GET","HEAD","OPTIONS","POST","PUT"];function normalizeMethod(method){var upcased=method.toUpperCase();return methods.indexOf(upcased)>-1?upcased:method}function Request(input,options){options=options||{};var body=options.body;if(Request.proto ...
#     }
#
#     if (typeof window.CustomEvent !== 'function') {
#
#       function CustomEvent(event, params) {
#         params = params || { bubbles: false, cancelable: false, detail: null };
#         var evt = document.createEvent('CustomEvent');
#         evt.initCustomEvent(event, params.bubbles, params.cancelable, params.detail);
#         return evt;
#       }
#
#       CustomEvent.prototype = window.Event.prototype;
#
#       window.CustomEvent = CustomEvent;
#
#     }
#    </script>
#    <script>
#     window.orbitData = {};
#
#     var additionalPageProperties = {};
#         additionalPageProperties['app_type'] = 'responsive' || null;
#         additionalPageProperties['app_name'] = 'sport-gnl-web' || null;
#         additionalPageProperties['custom_var_9'] = '0' || null;
#         additionalPageProperties['custom_var_1'] = '2011-12-12T11:56:10+00:00' || null;
#         additionalPageProperties['custom_var_2'] = '2021-07-06T11:04:09+00:00' || null;
#
#     window.orbitData.partialCookieOvenUrl = 'https://cookie-oven.api.bbc';
#
#     window.orbitData.userProfileUrl = "https://www.bbc.co.uk/userprofile";
#
#     window.page = {
#         name: 'sport.page' || null,
#         destination: 'SPORT_GNL' || null,
#         producer: 'SPORT' || null,
#         section: 'other::homepage' || null,
#         site: '' || null,
#         contentId: 'urn:bbc:cps:b5c53246-3b2e-e059-e040-850a02846523' || null,
#         contentType: 'index-home' || null,
#         edition: '' || null,
#         additionalProperties: additionalPageProperties
#     };
#     window.page.language = 'en';
#     window.page.language = 'en';
#
#     window.page.modal = false;
#
#
#        window.orb = {
#          worldwideNavlinks: '<li class="orb-nav-homedotcom"><a href="https://www.bbc.com/">Home</a></li><li class="orb-nav-newsdotcom"><a href="https://www.bbc.com/news">News</a></li><li class="orb-nav-sport"><a href="https://www.bbc.com/sport">Sport</a></li><li class="orb-nav-reeldotcom"><a href="https://www.bbc.com/reel">Reel</a></li><li class="orb-nav-worklife"><a href="https://www.bbc.com/worklife">Worklife</a></li><li class="orb-nav-traveldotcom"><a href="https://www.bbc.com/travel">Travel</a></li><li class="orb-nav-future"><a href="https://www.bbc.com/future">Future</a></li><li class="orb-nav-culture"><a href="https://www.bbc.com/culture">Culture</a></li><li class="orb-nav-music"><a href="https://www.bbc.com/culture/music">Music</a></li><li class="orb-nav-tv"><a href="https://www.bbc.co.uk/schedules/p00fzl9m">TV</a></li><li class="orb-nav-weather"><a href="https://www.bbc.com/weather">Weather</a></li><li class="orb-nav-sounds"><a href="https://www.bbc.co.uk/sounds">Sounds</a></li>',
#        }
#
#
# !function(){var t={1391:function(t){function r(t,r){var e=Object.keys(t);if(Object.getOwnPropertySymbols){var n=Object.getOwnPropertySymbols(t);r&&(n=n.filter((function(r){return Object.getOwnPropertyDescriptor(t,r).enumerable}))),e.push.apply(e,n)}return e}function e(t){for(var e=1;e<arguments.length;e++){var o=null!=arguments[e]?arguments[e]:{};e%2?r(Object(o),!0).forEach((function(r){n(t,r,o[r])})):Object.getOwnPropertyDescriptors?Object.defineProperties(t,Object.getOwnPropertyDescriptors(o)):r(Object(o)).forEach((function(r){Object.defineProperty(t,r,Object.getOwnPropertyDescriptor(o,r))}))}return t}function n(t,r,e){return r in t?Object.defineProperty(t,r,{value:e,enumerable:!0,configurable:!0,writable:!0}):t[r]=e,t}var o=e({},window.page);document.addEventListener("bbc-page-reset",(function(t){var r;t.detail&&t.detail.page&&(r=t.detail.page,o=Object.assign(o,r)),document.dispatchEvent(new Event("bbc-page-updated"))}));var i={getName:function(){return Promise.resolve(o.name||function(){if("file:"===window.location.protocol)return"local.file";var t=window.location.pathname.replace(/\/$/,"").replace(/^\//,"").replace(/\//g,".");return"".concat(t,".page")}())},getLanguage:function(){return Promise.resolve(o.language)},getDestination:function(){return Promise.resolve(o.destination)},getProducer:function(){return Promise.resolve(o.producer)},getSection:function(){return Promise.resolve(o.section)},getContentType:function(){return Promise.resolve(o.contentType)},getContentId:function(){return Promise.resolve(o.contentId)},getReferrer:function(){return Promise.resolve(window.orb&&null!==window.orb.referrer&&void 0!==window.orb.referrer?window.orb.referrer:document.referrer)},getAdditionalProperties:function(){return Promise.resolve(e({},o.additionalProperties))},loadCSS:function(t){return new Promise((function(r,e){var n=document.createElement("link");n.type="text/css",n.rel="stylesheet",n.onload=function(){r()},n.href=t,document.getElementsByTagName("head")[0].appendChild(n)}))},isModal:function(){return Promise.resolve(o.modal)}};window.bbcpage=i,t.exports={bbcpage:i}},9135:function(t){function r(t){return(r="function"==typeof Symbol&&"symbol"==typeof Symbol.iterator?function(t){return typeof t}:function(t){return t&&"function"==typeof Symbol&&t.constructor===Symbol&&t!==Symbol.prototype?"symbol":typeof t})(t)}function e(t,r){if(!(t instanceof r))throw new TypeError("Cannot call a class as a function")}function n(t,e){return!e||"object"!==r(e)&&"function"!=typeof e?function(t){if(void 0===t)throw new ReferenceError("this hasn't been initialised - super() hasn't been called");return t}(t):e}function o(t){var r="function"==typeof Map?new Map:void 0;return(o=function(t){if(null===t||(e=t,-1===Function.toString.call(e).indexOf("[native code]")))return t;var e;if("function"!=typeof t)throw new TypeError("Super expression must either be null or a function");if(void 0!==r){if(r.has(t))return r.get(t);r.set(t,n)}function n(){return i(t,arguments,c(this).constructor)}return n.prototype=Object.create(t.prototype,{constructor:{value:n,enumerable:!1,writable:!0,configurable:!0}}),u(n,t)})(t)}function i(t,r,e){return(i=a()?Reflect.construct:function(t,r,e){var n=[null];n.push.apply(n,r);var o=new(Function.bind.apply(t,n));return e&&u(o,e.prototype),o}).apply(null,arguments)}function a(){if("undefined"==typeof Reflect||!Reflect.construct)return!1;if(Reflect.construct.sham)return!1;if("function"==typeof Proxy)return!0;try{return Boolean.prototype.valueOf.call(Reflect.construct(Boolean,[],(function(){}))),!0}catch(t){return!1}}function u(t,r){return(u=Object.setPrototypeOf||function(t,r){return t.__proto__=r,t})(t,r)}function c(t){return(c=Object.setPrototypeOf?Object.getPrototypeOf:function(t){return t.__proto__||Object.getPrototypeOf(t)})(t)}var s=function(t){!function(t,r){if("function"!=typeof r&&null!==r)throw new TypeError("Super expression must either be null or a function");t.prototype=Object.create(r&&r.prototype,{constructor:{value: ...
#     window.page = undefined;
#    </script>
#    <link as="font" crossorigin="" href="https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_Rg.woff2" rel="preload" type="font/woff2"/>
#    <script src="https://static.files.bbci.co.uk/orbit/86efadef229d1a4ee7019331f832e9f5//js/api-forge-free.min.js">
#    </script>
#    <!-- navid Web Module: 0.2.0-71.fd2b3be -->
#    <!-- searchbox Web Module: 3.0.0-280.c10a5d3 -->
#    <!-- navpromo Web Module: 3.0.0-234.6bc940e -->
#    <!-- cookiebanner Web Module: 0.0.3-632.6234f55 -->
#    <!-- useractivityhelper Web Module: 1.0.0-177.2024095 -->
#    <!-- reverb Web Module: 3.1.2 -->
#    <!-- ads Web Module: 20210702-093904-765f3e169-4.48.0 -->
#    <link href="https://static.files.bbci.co.uk/account/id-cta/1.54.4/style/id-cta.css" rel="stylesheet">
#     <!--[if IE 8]><link href="https://static.files.bbci.co.uk/account/id-cta/1.54.4/style/ie8.css" rel="stylesheet"/> <![endif]-->
#     <script type="text/javascript">
#      (function () {if (!window.require) {throw new Error('idcta: could not find require module');}if (typeof (map) == 'undefined') {var map = {};}if (!!document.createElementNS && !!document.createElementNS('http://www.w3.org/2000/svg', 'svg').createSVGRect) {document.documentElement.className += ' id-svg';}var ptrt = new RegExp("[\\?&]ptrt=([^&]*)").exec(document.location.href);var ENDPOINT_URL = 'https://idcta.api.bbc.co.uk';var ENDPOINT_CONFIG = ('/idcta/config?callback=&ptrt=' + (ptrt ? ptrt[1] : encodeURIComponent(document.location.href))).replace(/\&amp;/g, '&');var ENDPOINT_TRANSLATIONS = '/idcta/translations?callback=';function hasPromise() {var P = window.Promise;var promiseToString = null;if (P) {try {promiseToString = Object.prototype.toString.call(P.resolve());} catch (e) {/*silently ignored*/}}return (promiseToString === '[object Promise]' && !P.cast);}if (hasPromise()) {define('idcta/es6-promise', function () {return window.Promise;});define('idcta-v2/es6-promise', function () {return window.Promise;});}map['idcta-v2'] = 'https://static.files.bbci.co.uk/account/id-cta/1.54.4/modules/idcta-v2';map['idcta-v2/config'] = ENDPOINT_URL + ENDPOINT_CONFIG;map['idcta-v2/translations'] = ENDPOINT_URL + ENDPOINT_TRANSLATIONS;map['idcta'] = 'https://static.files.bbci.co.uk/account/id-cta/1.8.2/modules/idcta';map['idcta-v2/idcta-1'] = 'https://static.files.bbci.co.uk/account/id-cta/1.54.4/modules/idcta-v2/dist/idcta-1.min';map['idcta-v2/experiment-snippet'] = 'https://cdn.optimizely.com/public/4621041136/s/idcta_live';const idctaShim = {deps: ['idcta-v2/idcta-1'],};require({shim: {'idcta-v2/statusbar': idctaShim,'idcta-v2/id-config': idctaShim},map: {'*': {'idcta/idcta-1': 'idcta-v2/idcta-1','idcta': 'idcta-v2',}},paths: map});window.idctaBaseUrl = ENDPOINT_URL;define('idcta/config', ['idcta-v2/config'], function (data) { return data; });define('idcta/translations', ['idcta-v2/translations'], function (data) { return data; });})();
#     </script>
#     <script type="text/javascript">
#      // Globally available search context
#   window.SEARCHBOX={"variant":"default","locale":"en","feature":"forge-free","navSearchboxStaticPrefix":"https://nav.files.bbci.co.uk/searchbox/1bccf115d72bef1afbcc7fcd281c8334/","searchboxAppStaticPrefix":"https://nav.files.bbci.co.uk/searchbox/1bccf115d72bef1afbcc7fcd281c8334/drawer","searchFormHtml":"<div tabindex=\"-1\"><div><section class=\"se-searchbox-panel\"><div class=\"se-g-wrap\"><div class=\"se-g-layout\"><div class=\"se-g-layout__item se-searchbox-title\" aria-hidden=\"true\">search</div><div class=\"se-g-layout__item se-searchbox\"><form accept-charset=\"utf-8\" id=\"searchboxDrawerForm\" method=\"get\" action=\"https://search.bbc.co.uk/search\"><label class=\"se-searchbox__input\" for=\"se-searchbox-input-field\"><span class=\"se-sr-only\">Search Term</span><div><input type=\"text\" name=\"q\" value=\"\" id=\"se-searchbox-input-field\" class=\"se-searchbox__input__field\" maxLength=\"100\" autoComplete=\"off\" autoCorrect=\"off\" autoCapitalize=\"off\" spellcheck=\"false\" tabindex=\"0\"/></div></label><input type=\"hidden\" name=\"scope\" value=\"\"/><button type=\"submit\" class=\"se-searchbox__submit\" tabindex=\"0\" data-bbc-container=\"se-searchbox-panel\" data-bbc-title=\"search-icon\" data-bbc-metadata=\"{&quot;PAR&quot;:&quot;form::1&quot;,&quot;CHD&quot;:&quot;button::1&quot;}\" data-bbc-personalisation=\"{&quot;QRY&quot;:&quot;&quot;}\">Search</button><button type=\"button\" class=\"se-searchbox__clear se-searchbox__clear--visible\" tabindex=\"0\" data-bbc-container=\"se-searchbox-panel\" data-bbc-title=\"clear-icon\" data-bbc-metadata=\"{&quot;PAR&quot;:&quot;form::1&quot;,&quot;CHD&quot;:&quot;button::2&quot;}\" data-bbc-personalisation=\"{&quot;QRY&quot;:&quot;&quot;}\">Close</button></form></div></div></div></section><div aria-live=\"polite\" aria-atomic=\"true\" class=\"se-suggestions-container\"><section class=\"se-g-wrap\"></section></div></div></div>","searchScopePlaceholder":"","searchScopeParam":"","searchScopeTemplate":"","searchPlaceholderWrapperStart":"","searchPlaceholderWrapperEnd":""};
#   window.SEARCHBOX.searchScope = SEARCHBOX.searchScopeTemplate.split('-')[0];
#     </script>
#     <link href="https://nav.files.bbci.co.uk/searchbox/1bccf115d72bef1afbcc7fcd281c8334/css/main.css" rel="stylesheet"/>
#     <!--[if IE 8]>
#   <script type="text/javascript" src="https://nav.files.bbci.co.uk/searchbox/1bccf115d72bef1afbcc7fcd281c8334/script/html5shiv.min.js"></script>
#   <script type="text/javascript">window['searchboxIEVersion'] = 8;</script>
#   <link rel="stylesheet" href="https://nav.files.bbci.co.uk/searchbox/1bccf115d72bef1afbcc7fcd281c8334/css/ie8.css">
# <![endif]-->
#     <!--[if IE 9]>
#   <script type="text/javascript">window['searchboxIEVersion'] = 9;</script>
# <![endif]-->
#     <script src="https://static.files.bbci.co.uk/cookies/6df705c21589b69e7b725a88da1d2200/cookie-banner/cookie-library.bundle.js">
#     </script>
#     <script type="text/javascript">
#      void 0!==window.define&&define("orb/cookies",function(){return window.bbccookies})
#     </script>
#     <script type="text/javascript">
#      window.__detectview={clickManagementEnabled:false};
#     </script>
#     <script type="text/javascript">
#      "use strict";!function(){window.__reverbStaticLocation="https://mybbc-analytics.files.bbci.co.uk/reverb-client-js/",window.__smarttagVersion="5.27.0",window.__reverb={},window.__reverb.__reverbLoadedPromise=new Promise(function(e,i){window.__reverb.__resolveReverbLoaded=e,window.__reverb.__rejectReverbLoaded=i}),window.__reverb.__reverbTimeout=setTimeout(function(){window.__reverb.__rejectReverbLoaded()},5e3);var i=function(d,a){window.__reverb.__reverbLoadedPromise.then(function(e){if(d&&d.detail){var i=!!d.detail.item,n=d.detail.label,t=i?"viewability":d.detail.type,o=d.detail.elem,r=d.detail.originalEvent;d.detail.isClick&&(a=d.detail.isClick),e.userActionEvent(t,n,d.detail,o,r,a)}},function(){console.log("Reverb failed to load. Event not sent")})},n=function(){window.__reverb.__reverbLoadedPromise.then(function(e){e.initialise().then(function(){return e.viewEvent()})},function(){console.log("Reverb failed to load. Event not sent")})};document.addEventListener("bbc-user-event",function(e){i(e,!1)}),document.addEventListener("bbc-user-click",function(e){i(e,!0)}),document.addEventListener("bbc-page-updated",n),window.addEventListener("pageshow",function(e){e.persisted&&n()})}();
#     </script>
#     <script async="" src="https://mybbc-analytics.files.bbci.co.uk/reverb-client-js/reverb-3.1.2.js" type="text/javascript">
#     </script>
#     <script type="text/javascript">
#      const adsDebug=/[?|&]ads-debug/.test(window.location.href);var bbcdotcomConfig={},bbcdotcomForgeAsync=!0,googletag=window.googletag||{};googletag.cmd=window.googletag.cmd||[],bbcdotcomScripts=[],tp=window.tp||[],_comscore=window._comscore||[];var bbcdotcom={test:/test/.test(window.location.hostname),adverts:{keyValues:{},breakpoints:{}},advert:{write:function(){},show:function(){},isActive:function(){return!1},layout:function(){return{reset:function(){}}}},config:{init:function(){},isAvailable:function(){return new Promise(function(o){bbcdotcom.resolves?bbcdotcom.resolves.isAvailable.push(o):o(!1)})},isAdsEnabledAsync:function(){return new Promise(function(o){bbcdotcom.resolves?bbcdotcom.resolves.adsEnabled.push(o):o(!1)})},isAnalyticsEnabledAsync:function(){return new Promise(function(o){bbcdotcom.resolves?bbcdotcom.resolves.analyticsEnabled.push(o):o(!1)})},setSections:function(){},setAdsEnabled:function(){},setAnalyticsEnabled:function(){},setAssetPrefix:function(){},setFlagpoles:function(){},setVersion:function(){},setJsPrefix:function(){},setSwfPrefix:function(){},setCssPrefix:function(){},setConfig:function(){},getAssetPrefix:function(){},getJsPrefix:function(){},getSwfPrefix:function(){},getCssPrefix:function(){},isOptimizelyEnabled:function(){},isThirdPartyDisabled:function(){},isThirdPartyDisabledEU:function(){},setEU:function(){}},survey:{init:function(){return!1}},data:{},init:function(){},objects:function(o){return!1},locale:{set:function(){},get:function(){}},setAdKeyValue:function(){},utils:{addEvent:function(){},addHtmlTagClass:function(){},log:function(){}},addLoadEvent:function(){},resolves:{isAvailable:[],adsEnabled:[],analyticsEnabled:[]},resolvePromises:function(){if(bbcdotcom.resolves){for(var o=0;o<bbcdotcom.resolves.isAvailable.length;o++)bbcdotcom.resolves.isAvailable[o](!1);delete bbcdotcom.resolves}},flag:{a:!1,s:!1},asyncCmd:[],isSportApp:function(){var o=window.location.pathname;return void 0!==o&&-1!==o.indexOf(".app")&&0===o.indexOf("/sport")},init:function(o){bbcdotcom.asyncCmd.push(function(){bbcdotcom.init(o)})},slotAsync:function(o,n,t,e){bbcdotcom.asyncCmd.push(function(){bbcdotcom.slotAsync(o,n,t,e)})}};bbcdotcom.adverts.slotAsync=function(o,n,t){bbcdotcom.asyncCmd.push(function(){bbcdotcom.adverts.slotAsync(o,n,t)})},bbcdotcom.config.isAdsEnabled=function(){var o=window.location.pathname;return void 0===o||0!==o.indexOf("/sport")||-1===o.indexOf(".app")},bbcdotcom.config.isActive=function(){var o=window.location.pathname;return void 0===o||0!==o.indexOf("/sport")||-1===o.indexOf(".app")},bbcdotcom.config.isAnalyticsEnabled=function(){return!0},bbcdotcom.registerAd=function(o,n,t){bbcdotcom.asyncCmd.push(function(){bbcdotcom.registerAd(o,n,t)})},bbcdotcom.setAdUnit=function(o){bbcdotcom.asyncCmd.push(function(){bbcdotcom.setAdUnit(o)})},bbcdotcom.adverts.adUnit={},bbcdotcom.adverts.adUnit.setUid=function(o){bbcdotcom.asyncCmd.push(function(){bbcdotcom.adverts.adUnit.setUid(o)})},bbcdotcom.setConfig=function(o){bbcdotcom.asyncCmd.push(function(){bbcdotcom.setConfig(o)})},bbcdotcom.setAdKeyValue=function(o,n){bbcdotcom.asyncCmd.push(function(){bbcdotcom.setAdKeyValue(o,n)})},bbcdotcom.getFeature=function(){return{isEnabled:function(){return!0}}},bbcdotcom.disableAndCloseOpenAds=function(){bbcdotcom.asyncDisableAndCloseOpenAds=!0},bbcdotcom.setAdKeyValue=function(o,n){bbcdotcom.asyncCmd.push(function(){bbcdotcom.adverts.keyValues.set(o,n)})},bbcdotcom.adverts.keyValues.set=function(o,n){bbcdotcom.asyncCmd.push(function(){bbcdotcom.adverts.keyValues.set(o,n)})},bbcdotcom.adverts.keyValues.unset=function(o){bbcdotcom.asyncCmd.push(function(){bbcdotcom.adverts.keyValues.unset(o)})},bbcdotcom.pubsub={},bbcdotcom.pubsub.on=function(o,n){bbcdotcom.asyncCmd.push(function(){bbcdotcom.pubsub.on(o,n)})},bbcdotcom.pubsub.off=function(o,n){bbcdotcom.asyncCmd.push(function(){bbcdotcom.pubsub.off(o,n)})},bbcdotcom.analytics={},bbcdotcom.analytics.page=function(o){bbcdotcom.asyncCmd.push(function(){bbcdo ...
#     </script>
#     <!--[if gt IE 8]><!-->
#     <noscript class="morph-core-style">
#      <!--<![endif]-->
#      <link href="//m.files.bbci.co.uk/modules/bbc-morph-grandstand/5.5.2/latin/core.css" rel="stylesheet">
#       <!--[if gt IE 8]><!-->
#      </link>
#     </noscript>
#     <!--<![endif]-->
#     <script>
#      if (Morph.enhanced) { Morph.styles["bbc-morph-grandstand/5.5.2/latin"]=true; Morph.styleSrc.push("<link rel=\"stylesheet\" href=\"//m.files.bbci.co.uk/modules/bbc-morph-grandstand/5.5.2/latin/enhanced.css\"/>"); }
#     </script>
#     <!--[if gt IE 8]><!-->
#     <noscript class="morph-core-style">
#      <!--<![endif]-->
#      <style>
#       .sp-c-global-header{background-color:#ffd230}.sp-c-global-header__inner{position:relative}.sp-c-global-header__logo{display:inline-block;margin-top:12px;margin-right:8px;margin-bottom:12px;font-size:34px;font-size:2.125rem;font-weight:bold;text-transform:uppercase}.sp-c-global-header__all-sports{position:absolute;top:50%;right:0;margin:0;margin-top:-16px;padding:8px;font-size:16px;font-size:1rem;line-height:16px;line-height:1rem;cursor:pointer;border:1px solid rgba(18,18,18,0.2);background:none;-webkit-appearance:none;-moz-appearance:none;appearance:none}.no-touch .sp-c-global-header__all-sports{font-size:15px;font-size:0.9375rem;line-height:15px;line-height:0.9375rem}.sp-c-global-header__all-sports svg{height:13px !important;width:16px !important}.sp-c-global-header__all-sports--selected{border-bottom:16px solid #121212;background:#121212;color:#fff}.sp-c-sport-navigation{background-color:#ffd230}@media (max-width: 37.49em){.sp-c-sport-navigation--secondary .sport-app-nav--secondary{margin-left:0px !important}}.sp-c-sport-navigation--primary{display:none}.sp-c-sport-navigation--secondary{background-color:#121212}.sp-c-sport-navigation__wrapper{position:relative;overflow:hidden}.sp-c-sport-navigation__inner{white-space:nowrap;overflow-x:scroll;-webkit-overflow-scrolling:touch;-ms-overflow-style:-ms-autohiding-scrollbar;-ms-overflow-style:none;margin-left:-8px !important;margin-right:-8px !important;padding-left:8px !important}.sp-c-sport-navigation__inner::-webkit-scrollbar{display:none}.no-touch .sp-c-sport-navigation__inner{overflow-x:hidden}.sp-c-sport-navigation--primary .sp-c-sport-navigation__inner{margin-right:112px !important;margin-left:-24px !important}.sp-c-sport-navigation__item{overflow:hidden;white-space:nowrap;font-size:18px;font-size:1.125rem;line-height:18px;line-height:1.125rem}.sp-c-sport-navigation__item:first-child .sp-c-sport-navigation__link:after{width:0}.no-touch .sp-c-sport-navigation__item{font-size:15px;font-size:0.9375rem;line-height:15px;line-height:0.9375rem}.sp-c-sport-navigation__item--primary-selected{background-color:#121212}.sp-c-sport-navigation__item--primary-selected .sp-c-sport-navigation__link{color:#fff}.sp-c-sport-navigation__item--primary-selected .sp-c-sport-navigation__link:after{width:0}.sp-c-sport-navigation__item--primary-selected+.sp-c-sport-navigation__item .sp-c-sport-navigation__link:after{width:0}.sp-c-sport-navigation__item--primary-first-selected .sp-c-sport-navigation__link:before{position:absolute;bottom:0;left:0;content:'';width:100%;height:4px;background-color:#121212}.sp-c-sport-navigation__item--secondary-selected{position:relative}.sp-c-sport-navigation__item--secondary-selected:before{position:absolute;bottom:0;left:0;content:'';width:100%;height:4px;background-color:#ffd230}.sp-c-sport-navigation__link{position:relative;display:block;padding:12px 8px;font-size:18px;font-size:1.125rem;line-height:18px;line-height:1.125rem;color:#121212;text-decoration:none}.no-touch .sp-c-sport-navigation__link{font-size:15px;font-size:0.9375rem;line-height:15px;line-height:0.9375rem}.sp-c-sport-navigation__link:after{position:absolute;left:0;content:'';width:1px;height:16px;background-color:rgba(18,18,18,0.2)}.no-touch .sp-c-sport-navigation__link:hover,.no-touch .sp-c-sport-navigation__link:focus{cursor:pointer}.no-touch .sp-c-sport-navigation__link:hover:before,.no-touch .sp-c-sport-navigation__link:focus:before{position:absolute;bottom:0;left:0;content:'';width:100%;height:4px;background-color:#121212}.sp-c-sport-navigation__link--secondary{color:#fff}.sp-c-sport-navigation__link--secondary:after{background-color:rgba(255,255,255,0.3)}.sp-c-sport-navigation__inner :nth-child(2) .sp-c-sport-navigation__link--secondary:after{width:0}.no-touch .sp-c-sport-navigation__link--secondary:hover:before,.no-touch .sp-c-sport-navigation__link--secondary:focus:before{background-color:#ffd230}.sp-c-sport-navigation__link--crumb{padding-right:0;padding-left:0}.sp-c-sport-navigation__li ...
#      </style>
#      <!--[if gt IE 8]><!-->
#     </noscript>
#     <!--<![endif]-->
#     <script>
# ...
#
#         if (pageLength < getViewportHeight() + 300 || pageLength - getCurrentPosition() < PROMO_SHOW_BREAKPOINT) {
#             loadPromo();
#
#         } else {
#             window.onscroll = function () {
#                 didScroll = true;
#             };
#
#             scrollCheckTimer = setInterval(function () {
#                 if (didScroll) {
#                     hasScrolled();
#                     didScroll = false;
#                 }
#             }, 250);
#         }
#     }
#
#     function loadPromo() {
#         clearInterval(scrollCheckTimer);
#
#         require(['orb/async/_footerpromo'], function(promo) {
#             promo.init('https://navpromo.api.bbci.co.uk', '');
#         });
#     }
#
#     function getViewportHeight() {
#         return window.innerHeight;
#     }
#
#     function getCurrentPosition() {
#         return Math.abs(window.scrollY || document.body.scrollTop || document.documentElement.scrollTop);
#     }
#
#     function hasScrolled() {
#         var currentPosition = getCurrentPosition();
#
#         if (Math.abs(previousPosition - currentPosition) <= delta) {
#             return;
#         }
#         if (currentPosition > previousPosition) {
#             if ((pageLength - currentPosition) <= PROMO_SHOW_BREAKPOINT) {
#                 loadPromo();
#             }
#         }
#         previousPosition = currentPosition;
#     }
# })();
#   </script>
#   <script type="text/javascript">
#    window.COOKIES_STATIC_HOST="https://static.files.bbci.co.uk/cookies/6df705c21589b69e7b725a88da1d2200/cookie-banner/cookie-prompt/"
#   </script>
#   <script async="" src="https://static.files.bbci.co.uk/cookies/6df705c21589b69e7b725a88da1d2200/cookie-banner/cookie-banners.bundle.js">
#   </script>
#   <script async="" src="https://nav.files.bbci.co.uk//user-activity-helper/7f7e3cfe8ed2cbcec7e57473d0ed5809/js/detectview.bundle.js">
#   </script>
#   <script type="text/javascript">
#    "use strict";window.__reverb.__reverbLoadedPromise.then(function(e){return e.initialise().then(function(){return e.viewEvent()})},function(){console.log("Failed to load reverb. No event sent")});
#   </script>
#   <noscript>
#    <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=17986528&amp;cs_ucfr=0&amp;cv=2.0&amp;cj=1"/>
#   </noscript>
#   <script async="" src="https://static.files.bbci.co.uk/orbit/86efadef229d1a4ee7019331f832e9f5//js/performance.bundle.js" type="text/javascript">
#   </script>
#   <script>
#    require.config({"paths":{"bump-3":"//emp.bbci.co.uk/emp/bump-3/bump-3","bump-4":"//emp.bbci.co.uk/emp/bump-4/bump-4","echo-8.1.0":"//static.bbci.co.uk/echoclient/modules/echo-8.1.0.js","jssignals-1":"//static.bbci.co.uk/frameworks/jssignals/0.3.6/modules/jssignals-1","jquery-1":"//static.test.bbc.co.uk/frameworks/jquery/0.4.1/sharedmodules/jquery-1.7.2","jquery-1.9":"//static.bbci.co.uk/frameworks/jquery/0.4.1/sharedmodules/jquery-1.9.1","swfobject-2":"//static.bbci.co.uk/frameworks/swfobject/0.1.10/sharedmodules/swfobject-2","istats-1":"//nav.files.bbci.co.uk/orbit-webmodules/0.0.2-524.9a574c9/istats/istats-1"}})
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-sport-navigation/6.3.12/bundle.app.js">
#   </script>
#   <script type="text/javascript">
#    (function() {
#                 var resizeTimeout;
#
#                 window.addEventListener("resize", function() {
#                     clearTimeout(resizeTimeout);
#                     resizeTimeout = setTimeout(function() {
#                         bbcdotcom.reset();
#                     }, 500);
#                 }, false);
#             }());
#   </script>
#   <script>
#    Morph.toInit.payloads.push(function() { Morph.setPayload('/data/bbc-morph-sport-filter-data-provider-priority-order-football-scores/version/2.3.1', {"meta":{"responseCode":200,"errorMessage":null,"headers":{"x-morph-privacy-level":"public","content-type":"application\/json"}},"body":{"groups":[{"title":"Competitions","items":[{"text":"European Championship","selectedValue":"european-championship","competitionType":"international-groupcup"},{"text":"Premier League","selectedValue":"premier-league","competitionType":"domestic-league"},{"text":"Scottish Prem","selectedValue":"scottish-premiership","competitionType":"domestic-league"},{"text":"Championship","selectedValue":"championship","competitionType":"domestic-league"},{"text":"League One","selectedValue":"league-one","competitionType":"domestic-league"},{"text":"League Two","selectedValue":"league-two","competitionType":"domestic-league"},{"text":"Scottish Champ","selectedValue":"scottish-championship","competitionType":"domestic-league"},{"text":"Scottish League One","selectedValue":"scottish-league-one","competitionType":"domestic-league"},{"text":"Scottish League Two","selectedValue":"scottish-league-two","competitionType":"domestic-league"}],"onwardJourney":{"hyperlink":"\/sport\/football\/scores-fixtures","text":"View all leagues & cups"}}]}}); });
#   </script>
#   <script>
#    Morph.toInit.payloads.push(function() { Morph.setPayload('/data/bbc-morph-graphql/query/%7Bcontent%7BdynamicFeatureToggles%7Bactive%2Cname%7Dindex(path%3A%22%2Fsport%22%2CisUk%3Afalse%2CisApp%3Afalse)%7Bclusters(filter%3A%5B%22Top%20stories%22%2C%224-cluster%22%2C%22Cluster%201%22%2C%22Cluster%202%22%2C%225-slice%201%22%2C%224-slice%201%22%2C%22Most%20watched%22%2C%227-slice%201%22%2C%225-slice%202%22%2C%224-slice%202%22%2C%22Around%20the%20UK%22%2C%227-slice%202%22%2C%225-slice%203%22%2C%224-slice%203%22%2C%227-slice%203%22%5D)%7BclusterTypeTitle%2Citems(limits%3A%5B%7Btype%3A%22Top%20stories%22%2Cmin%3A1%2Cmax%3A14%7D%2C%7Btype%3A%224-cluster%22%2Cmin%3A4%2Cmax%3A4%7D%2C%7Btype%3A%22Cluster%201%22%2Cmin%3A7%2Cmax%3A7%7D%2C%7Btype%3A%22Cluster%202%22%2Cmin%3A7%2Cmax%3A7%7D%2C%7Btype%3A%225-slice%201%22%2Cmin%3A4%2Cmax%3A4%7D%2C%7Btype%3A%224-slice%201%22%2Cmin%3A4%2Cmax%3A4%7D%2C%7Btype%3A%22Most%20watched%22%2Cmin%3A4%2Cmax%3A4%7D%2C%7Btype%3A%227-slice%201%22%2Cmin%3A7%2Cmax%3A7%7D%2C%7Btype%3A%225-slice%202%22%2Cmin%3A4%2Cmax%3A4%7D%2C%7Btype%3A%224-slice%202%22%2Cmin%3A4%2Cmax%3A4%7D%2C%7Btype%3A%22Around%20the%20UK%22%2Cmin%3A3%2Cmax%3A4%7D%2C%7Btype%3A%227-slice%202%22%2Cmin%3A7%2Cmax%3A7%7D%2C%7Btype%3A%225-slice%203%22%2Cmin%3A4%2Cmax%3A4%7D%2C%7Btype%3A%224-slice%203%22%2Cmin%3A4%2Cmax%3A4%7D%2C%7Btype%3A%227-slice%203%22%2Cmin%3A7%2Cmax%3A7%7D%5D)%7BarticleType%2CcommentsCount%2Cimage%7Bdescription%2Curl%7DisLive%2Clink%2CpublishedDateTime%2CscheduledStartTime%2Csection%7Blink%2Cname%7Dsummary%2Ctitle%2Ctype%7Dlink%2Ctitle%2Ctype%7Dfeatures%7Bname%2Cprops%7Bname%2Cvalue%7D%7Dtitle%7D%7DsportNav%7Bnavigation(path%3A%22%2Fsport%22%2CisUk%3Afalse%2CisApp%3Afalse)%7BbreadcrumbItem%7Blink%7D%7D%7D%7D/token/13b334aea04d8890e16a9408964246bed8e2735d91c58b7c78ca830f21bfa6d6/version/2.3.92', {"meta":{"responseCode":200,"errorMessage":null,"headers":{"x-morph-privacy-level":"public","content-type":"application\/json"}},"body":{"content":{"dynamicFeatureToggles":[{"active":true,"name":"cps-story-pull-outs"},{"active":false,"name":"cps-story-idt2-iframe"},{"active":true,"name":"football-new-tables"},{"active":true,"name":"cps-story-match-stats-include"},{"active":true,"name":"cps-story-oppm-promos"},{"active":true,"name":"cps-story-quote-box"},{"active":true,"name":"football-new-scores"},{"active":true,"name":"football-assists"},{"active":true,"name":"cps-story-multi-thumb-promos"},{"active":true,"name":"cps-story-embeds"},{"active":true,"name":"cps-story-3rd-party-include"},{"active":true,"name":"cps-story-hearken-include"},{"active":true,"name":"cps-story-morph-include"},{"active":true,"name":"cps-story-body-adverts"},{"active":true,"name":"cps-story-comments"},{"active":true,"name":"reith-font"},{"active":true,"name":"graphql-ldp-core-followable-sport"},{"active":true,"name":"graphql-linked-data"},{"active":true,"name":"maps-mpv-endpoint"},{"active":false,"name":"geolocationRedirects"},{"active":false,"name":"app-bridge-debug"},{"active":true,"name":"optimizely-enabled"},{"active":true,"name":"ati-analytics-live-bucket"},{"active":true,"name":"uasServiceCalls"},{"active":true,"name":"versioned-mysport"},{"active":true,"name":"nitro-territory-filtering"},{"active":true,"name":"new-nitro-endpoint"},{"active":false,"name":"filtered-scores"},{"active":true,"name":"story-page-maps-video-experience"},{"active":true,"name":"versioned-football-components"},{"active":true,"name":"versioned-cricket-components"},{"active":true,"name":"football-table-competitions"},{"active":true,"name":"football-table-teams"},{"active":false,"name":"morph-scores"},{"active":false,"name":"smp-delay-embed"},{"active":true,"name":"oppm-responsive"},{"active":false,"name":"layout-preference"},{"active":true,"name":"byline-image"},{"active":true,"name":"beta-override"},{"active":false,"name":"mvt-enabled"},{"active":false,"name":"lx-push"},{"active":true,"name":"lazyload-srcset"},{"active":false,"name":"lx-lineups"},{"active":false,"name":"lx-matchstats"} ...
#   </script>
#   <script>
#    Morph.toInit.payloads.push(function() { Morph.setPayload('/data/bbc-morph-sport-football-scores-filter-priority-order-data/tournament/european-championship/version/2.1.10', {"meta":{"responseCode":200,"errorMessage":null,"headers":{"x-morph-privacy-level":"public","content-type":"application\/json"}},"body":{"rounds":[{"round":{"key":"CFBB32020S2R3","name":{"first":"Semi-final","full":"Semi-final","abbreviation":"Semi-final"}},"events":[{"eventKey":"EFBO2041929","startTime":"2021-07-06T20:00:00+01:00","minutesElapsed":null,"minutesIntoAddedTime":null,"eventStatus":"pre-event","eventStatusNote":"pre-event","eventStatusReason":null,"eventOutcomeType":null,"eventType":"Cup","seriesWinner":null,"cpsId":"51198738","cpsLive":"yes","attendance":null,"homeTeam":{"key":"TFBB119","scores":{"score":null,"halfTime":null,"fullTime":null,"extraTime":null,"shootout":null,"aggregate":null,"aggregateGoalsAway":null},"formation":null,"eventOutcome":null,"name":{"first":"Italy","full":"Italy","abbreviation":"Italy","last":null},"stats":null,"players":[]},"awayTeam":{"key":"TFBB118","scores":{"score":null,"halfTime":null,"fullTime":null,"extraTime":null,"shootout":null,"aggregate":null,"aggregateGoalsAway":null},"formation":null,"eventOutcome":null,"name":{"first":"Spain","full":"Spain","abbreviation":"Spain","last":null},"stats":null,"players":[]},"eventProgress":{"period":"FIXTURE","status":"FIXTURE"},"players":null,"venue":{"name":{"abbreviation":"Wembley Stadium","videCode":"Wembley Stadium","first":"Wembley Stadium","full":"Wembley Stadium"},"homeCountry":null},"officials":[],"tournamentInfo":null,"startTimeInUKHHMM":"20:00","comment":null,"href":"\/sport\/football\/51198738","tournamentName":{"first":"European Championship","full":"UEFA European Championship","abbreviation":"European Championship"},"tournamentSlug":"european-championship"}]}],"date":"Tuesday 6th July 2021","tournament":{"name":"European Championship","slug":"european-championship"},"type":"today"}}); });
#   </script>
#   <script>
#    Morph.toInit.registers.push(function() { Morph.register({"view":"bbc-morph-sport-index","isApp":"false","isUk":"false","path":"\/sport","uasServiceCalls":"true","version":"3.0.3","_mrrVersion":"2.2.1"},'u5743998214940021'); });
#   </script>
#   <script>
#    Morph.init = function() { if (!Morph.initCalled) { Morph.markPerformance('morph-init'); Morph.initCalled = true; requirejs.config({ paths: { 'live-push': '//m.files.bbci.co.uk/modules/morph-push-proxy-client/1.0.13/push-proxy' } }); } function attempt(fn) { fn(); } if (!Morph.toInitsCalled) { Morph.markPerformance('morph-init-core-deps-complete'); Morph.toInitsCalled = true; } Morph.toInit.bundles.forEach(attempt); Morph.toInit.bundles = []; Morph.markPerformance('morph-init-bundles-complete'); Morph.toInit.payloads.forEach(attempt); Morph.toInit.payloads = []; Morph.markPerformance('morph-init-payloads-complete'); Morph.toInit.registers.forEach(attempt); Morph.toInit.registers = []; Morph.markPerformance('morph-init-registers-complete'); };
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/morph-vendor/1.0.2/bundle.vendor.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/morph/5.3.1/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/morph-react-graphql/2.3.111/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-promise/1.0.6/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-id-helpers/2.1.0/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-sport-uas-service/2.1.1/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-classnames/1.0.2/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-gs-section-tag/3.1.1/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-gs-promo-summary/3.0.0/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-gs-promo-meta/4.0.0/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-ws-typography-info/1.0.6/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-responsive-image-srcset/3.0.1/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-image-chef-url-transformer/3.0.0/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-gs-promo-image/8.0.2/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-gs-promo-heading/6.0.2/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-gs-promo-body/6.0.0/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-gs-promo/6.0.0/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-gs-media-indicator/9.0.0/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-gs-live-pulse/6.0.12/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-gs-timestamp/3.0.0/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-gs-item-status/9.0.2/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-gs-comment-icon/5.0.1/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-sport-promos/6.3.0/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-sport-layouts/2.0.0/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-lazysizes/1.0.1/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-gnl-advert/2.0.0/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-sport-index/3.0.3/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-gs-media-indicator/9.0.0/ltr/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-grandstand/5.4.5/latin/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-sport-filter/2.0.3/ltr/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-gs-promo-body/6.0.0/ltr/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-gs-promo-image/8.0.2/ltr/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-gs-promo/6.0.0/ltr/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-sportsdata-soccer-event-progress-period-helper/3.0.0/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-sport-native-app-helper/2.0.1/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-grandstand/5.4.5/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-sport-football-scores-components/5.2.0/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-sport-filter/2.0.3/bundle.js">
#   </script>
#   <script src="//m.files.bbci.co.uk/modules/bbc-morph-sport-football-scores-filtered/1.1.6/bundle.js">
#   </script>
#   <script>
#    if (!Morph.manualInit) { Morph.init(); } /* u5743998214940021 */
#   </script>
#  </body>
# </html>

# %%
print(soup3.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/>
#   <!-- HTML5 shim and Respond.js IE8 support of HTML5 elements and media queries -->
#   <!--[if lt IE 9]>
#       <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
#       <script src="https://oss.maxcdn.com/libs/respond.js/1.4.2/respond.min.js"></script>
# <![endif]-->
#   <title>
#    Sports News, Latest Sports News Headlines, Cricket News Today, World Cup 2019, Football News, Tennis News, Live Scores |  The Indian Express
#   </title>
#   <meta content="Sports News - Read Latest Sports News Today Headlines on IndianExpress.com. Find latest cricket news, tennis, football, hockey, World cup 2019, IPL 2019 Live Score Updates. Stay updated on Sports News" name="description">
#    <meta content="sports news, latest news on sports, cricket news, live scores, football news, tennis news, latest football news, latest football news" name="keywords">
#     <meta content="max-image-preview:large" name="robots"/>
#     <!-- Jetpack Site Verification Tags -->
#     <meta content="UzbS4ghT-l3F85eDiPbzEUeeKcvrnrGCgvsNHCRgvIc" name="google-site-verification"/>
#     <meta content="CCA9DA5B985004F4462DA743E776C636" name="msvalidate.01"/>
#     <link crossorigin="" href="https://indianexpress.com/" rel="preconnect"/>
#     <link as="script" href="//securepubads.g.doubleclick.net/tag/js/gpt.js" rel="preload">
#      <link crossorigin="" href="https://s0.wp.com/" rel="preconnect"/>
#      <link crossorigin="" href="https://s1.wp.com/" rel="preconnect"/>
#      <link crossorigin="" href="https://fonts.googleapis.com/" rel="preconnect">
#       <link crossorigin="" href="https://fonts.gstatic.com/" rel="preconnect">
#        <link crossorigin="" href="https://www.google-analytics.com/" rel="preconnect"/>
#        <link crossorigin="" href="https://sb.scorecardresearch.com/" rel="preconnect"/>
#        <link crossorigin="" href="https://www.googletagservices.com/" rel="preconnect"/>
#        <link crossorigin="" href="https://securepubads.g.doubleclick.net/" rel="preconnect"/>
#        <link crossorigin="" href="https://partner.googleadservices.com/" rel="preconnect"/>
#        <link crossorigin="" href="https://pagead2.googlesyndication.com/" rel="preconnect"/>
#        <link crossorigin="" href="https://cdn.taboola.com/" rel="preconnect"/>
#        <link crossorigin="" href="https://images.taboola.com/" rel="preconnect"/>
#        <link crossorigin="" href="https://cdn.taboola.com" rel="preconnect"/>
#        <link crossorigin="" href="https://trc.taboola.com/" rel="preconnect"/>
#        <link crossorigin="" href="https://notify.indianexpress.com/" rel="preconnect"/>
#        <link crossorigin="" href="https://cdn.izooto.com/" rel="preconnect"/>
#        <link crossorigin="" href="https://cdn.ampproject.org/" rel="preconnect"/>
#        <link href="//fastlane.rubiconproject.com/" rel="dns-prefetch"/>
#        <link href="//s.w.org" rel="dns-prefetch">
#         <link href="//instagram.com" rel="dns-prefetch"/>
#         <link href="//youtube.com" rel="dns-prefetch"/>
#         <link href="//rtbcdn.andbeyond.media" rel="dns-prefetch"/>
#         <link href="//s3.ap-south-1.amazonaws.com" rel="dns-prefetch"/>
#         <link href="//platform.twitter.com" rel="dns-prefetch"/>
#         <link href="//v0.wordpress.com" rel="dns-prefetch"/>
#         <link href="https://images.indianexpress.com/" rel="preload"/>
#         <link href="https://indianexpress.com/_static/??-eJyVzFEOgjAQRdENWSZS0S/jWip9yEQ603QmgLtXl8DvTe6hrYZRxSFOPqPAiCVzEuy1wYzMPwsIqy76pl+aeEcOT1U3b6l2o9mJDiFYw8b5BbeusBwBbE4N/+FR7udrfxlivMX+C/dSSZk=" id="all-css-0" media="all" rel="stylesheet" type="text/css">
#          <link href="https://fonts.googleapis.com/css?family=Roboto+Condensed:400,700|Roboto:400,500,700|Droid+Serif:400,700|Fira+Sans:300,400,500,600,700&amp;display=swap" id="google-fonts-css-css" media="" rel="stylesheet">
#           <link href="https://indianexpress.com/_static/??-eJyNTcsOgzAM+6GxQMvgNPEtqFgiEk2rJhrs7wdoh93YxQ9ZtmnNVUhiECObEaHEMvEo2HKBKkUOJSnbEeSFgp7s6qa77/pGV3219wKaMU4olWD9r/XzuvucRPmF79aJx8wQn03n2of3vXcfKY9LPw==" id="all-css-2" media="all" rel="stylesheet" type="text/css">
#            <link href="https://fonts.googleapis.com/css?family=Open+Sans+Condensed%3A700&amp;ver=5.7.2#038;ver=4.3.1-alpha-336649#038;ver=3.9" id="font-open-sans-condensed-css" media="" rel="stylesheet">
#             <link href="https://indianexpress.com/_static/??/wp-content/themes/indianexpress/style/footer.css,/wp-content/mu-plugins/jetpack-9.8/css/jetpack.css?m=1623241285" id="all-css-4" media="all" rel="stylesheet" type="text/css">
#              <script src="https://indianexpress.com/_static/??-eJzTLy/QzcxLzilNSS3WzwKiwtLUokoopZebmaeXVayjj0+Rbm5melFiSSpUsX2uraGZkYGFmbGlpWEWAK9+IiU=" type="text/javascript">
#              </script>
#              <script async="async" id="ie-google-ad-gpt-js-js" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#              </script>
#              <script id="responsive-custom-new.js-js-extra">
#               var ajax_object = {"ajaxurl":"https:\/\/indianexpress.com\/wp-admin\/admin-ajax.php","security":"e646adbd1e","sname":"Sports"};
#              </script>
#              <script src="https://indianexpress.com/_static/??-eJyVzE0KAjEMQOEL2YaCMzgL8SzaBiZlmtYk8+PtrVs34vLx4IO9uVjZkA1sxoIKxInujEcTVIWssCGnKpCfK8rLPw5dKKH4QuyznuCXUChKVbI+erfKSht+3A5AXNVqcYz7vxa15QvRKNRMXT8du5VrGKZzuEzDGPIb1XhX0w==" type="text/javascript">
#              </script>
#              <script async="" defer="defer" id="ie_automated_axt_js-js" src="https://rtbcdn.andbeyond.media/prod-global-324113.js?ver=1.4">
#              </script>
#              <script id="ie-taboola-header-script-js-extra">
#               var taboolaHeaderExports = {"category":"auto","tracking":"utm_source=Taboola_Recirculation&utm_medium=RC&utm_campaign=IE"};
#              </script>
#              <script src="https://indianexpress.com/_static/??/wp-content/themes/indianexpress/js/min/ie-gdpr-ad-code.js,/wp-content/themes/indianexpress/js/vendor/taboola-header.js?m=1594189560j" type="text/javascript">
#              </script>
#              <link href="https://indianexpress.com/wp-json/" rel="https://api.w.org/">
#               <link href="https://indianexpress.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml">
#                <link href="https://indianexpress.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml">
#                 <meta content="WordPress 5.7.2" name="generator"/>
#                 <style type="text/css">
#                  img#wpstats{display:none}
#                 </style>
#                 <meta content="163648403825" property="fb:pages"/>
#                 <link href="https://indianexpress.com/section/sports/lite/" rel="amphtml">
#                  <script type="application/ld+json">
#                   {"@context":"https:\/\/schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https:\/\/indianexpress.com\/","name":"Home"}},{"@type":"ListItem","position":2,"item":{"@id":"https:\/\/indianexpress.com\/section\/sports\/","name":"Sports"}}]}
#                  </script>
#                  <link href="https://indianexpress.com/section/sports/" rel="canonical">
#                   <meta content="163648403825" property="fb:pages"/>
#                   <meta content="168619349359" property="fb:pages"/>
#                   <meta content="185763818464532" property="fb:pages"/>
#                   <meta content="1494497934210205" property="fb:pages"/>
#                   <meta content="1774784956154724" property="fb:pages"/>
#                   <meta content="1567211863297748" property="fb:pages"/>
#                   <meta content="291465928041678" property="fb:pages"/>
#                   <meta content="339520043138547" property="fb:pages"/>
#                   <meta content="376556412852346" property="fb:pages"/>
#                   <meta content="215732349153100" property="fb:pages"/>
#                   <meta content="website" property="og:type"/>
#                   <meta content="https://indianexpress.com/section/sports/" property="og:url"/>
#                   <meta content="The Indian Express" property="og:site_name"/>
#                   <meta content="en_US" property="og:locale"/>
#                   <meta content="Sports News, Latest Sports News Headlines, Cricket News Today, World Cup 2019, Football News, Tennis News, Live Scores" property="og:title"/>
#                   <meta content="Sports News - Read Latest Sports News Today Headlines on IndianExpress.com. Find latest cricket news, tennis, football, hockey, World cup 2019, IPL 2019 Live Score Updates. Stay updated on Sports News" property="og:description"/>
#                   <meta content="https://indianexpress.com/wp-content/themes/indianexpress/images/default-og-image.jpg" property="og:image"/>
#                   <meta content="image/jpeg" property="og:image:type"/>
#                   <meta content="962" property="og:image:width"/>
#                   <meta content="534" property="og:image:height"/>
#                   <meta content="summary_large_image" name="twitter:card"/>
#                   <meta content="The Indian Express" name="twitter:site"/>
#                   <meta content="@indianexpress" name="twitter:creator">
#                    <meta content="https://indianexpress.com/section/sports/" name="twitter:url"/>
#                    <meta content="Sports News, Latest Sports News Headlines, Cricket News Today, World Cup 2019, Football News, Tennis News, Live Scores" name="twitter:title"/>
#                    <meta content="Sports News - Read Latest Sports News Today Headlines on IndianExpress.com. Find latest cricket news, tennis, football, hockey, World cup 2019, IPL 2019 Live Score Updates. Stay updated on Sports News" name="twitter:description"/>
#                    <meta content="https://indianexpress.com/wp-content/themes/indianexpress/images/default-og-image.jpg" property="twitter:image">
#                     <meta content="image/jpeg" property="twitter:image:type">
#                      <meta content="962" property="twitter:image:width">
#                       <meta content="534" property="twitter:image:height">
#                        <meta content="en" itemprop="inLanguage"/>
#                        <meta content="Sports News, Latest Sports News Headlines, Cricket News Today, World Cup 2019, Football News, Tennis News, Live Scores" itemprop="name"/>
#                        <meta content="https://indianexpress.com/section/sports/" itemprop="mainEntityOfPage">
#                         <meta content="https://indianexpress.com/section/sports/" itemprop="url"/>
#                         <meta content="Sports News, Latest Sports News Headlines, Cricket News Today, World Cup 2019, Football News, Tennis News, Live Scores" itemprop="headline"/>
#                         <meta content="Sports News - Read Latest Sports News Today Headlines on IndianExpress.com. Find latest cricket news, tennis, football, hockey, World cup 2019, IPL 2019 Live Score Updates. Stay updated on Sports News" itemprop="description"/>
#                         <script type="application/ld+json">
#                          {"@context":"https:\/\/schema.org","@type":"WebPage","inLanguage":"en","name":"Sports News, Latest Sports News Headlines, Cricket News Today, World Cup 2019, Football News, Tennis News, Live Scores","description":"Sports News - Read Latest Sports News Today Headlines on IndianExpress.com. Find latest cricket news, tennis, football, hockey, World cup 2019, IPL 2019 Live Score Updates. Stay updated on Sports News","url":"https:\/\/indianexpress.com\/section\/sports\/","mainEntityOfPage":"","publisher":{"@type":"Organization","name":"The Indian Express","logo":{"@type":"ImageObject","url":"https:\/\/images.indianexpress.com\/2019\/11\/ienewlogo3_new.png","width":"600","height":"60"}}}
#                         </script>
#                         <meta content="00120a3a212c33eda15559fea6d0731769fd82f538180bd0a2dbe12991312ab4" name="ahrefs-site-verification"/>
#                         <meta content="NOODP" name="robots">
#                          <link href="https://indianexpress.com/section/sports/page/2/" rel="next"/>
#                          <meta content="MJ12_ad7db024-a46c-482a-bb2f-e1ae09432a65" name="majestic-site-verification"/>
#                          <link href="https://images.indianexpress.com/2018/10/fav-icon.png" rel="icon" sizes="32x32"/>
#                          <link href="https://images.indianexpress.com/2018/10/fav-icon.png" rel="icon" sizes="192x192"/>
#                          <link href="https://images.indianexpress.com/2018/10/fav-icon.png" rel="apple-touch-icon"/>
#                          <meta content="https://images.indianexpress.com/2018/10/fav-icon.png" name="msapplication-TileImage">
#                           <script type="application/ld+json">
#                            [{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"India","url":"https:\/\/indianexpress.com\/section\/india\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Elections","url":"https:\/\/indianexpress.com\/elections\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Cities","url":"https:\/\/indianexpress.com\/section\/cities\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Opinion","url":"https:\/\/indianexpress.com\/section\/opinion\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Sports","url":"https:\/\/indianexpress.com\/section\/sports\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Entertainment","url":"https:\/\/indianexpress.com\/section\/entertainment\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Lifestyle","url":"https:\/\/indianexpress.com\/section\/lifestyle\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Technology","url":"https:\/\/indianexpress.com\/section\/technology\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Viral","url":"https:\/\/indianexpress.com\/trending\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Photos","url":"https:\/\/indianexpress.com\/photos\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Videos","url":"https:\/\/indianexpress.com\/videos\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"ePaper","url":"https:\/\/epaper.indianexpress.com\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Elections 2018","url":"https:\/\/indianexpress.com\/elections\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Home","url":"https:\/\/indianexpress.com\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Latest News","url":"https:\/\/indianexpress.com\/latest-news\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Business","url":"https:\/\/indianexpress.com\/section\/business\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Explained","url":"https:\/\/indianexpress.com\/section\/explained\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Trending","url":"https:\/\/indianexpress.com\/section\/trending\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Astrology","url":"https:\/\/indianexpress.com\/astrotype\/daily\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Today\u2019s Paper","url":"https:\/\/indianexpress.com\/todays-paper\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Education","url":"https:\/\/indianexpress.com\/section\/education\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"What Is","url":"https:\/\/indianexpress.com\/section\/what-is\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"When Is","url":"https:\/\/indianexpress.com\/section\/when-is\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Who Is","url":"https:\/\/indianexpress.com\/section\/who-is\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"How to","url":"https:\/\/indianexpress.com\/section\/how-to\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Budget 2018","url":"https:\/\/indianexpress.com\/section\/business\/budget\/"},{"@context":"https:\/\/schema.org","@type":"SiteNavigationElement","name":"Brand Solutions","url":"https:\/\/indianexpress.com\/brand-solutions\/"}]
#                           </script>
#                           <script type="application/ld+json">
#                            {"@context":"https:\/\/schema.org","@type":"WebSite","url":"https:\/\/indianexpress.com","name":"The Indian Express","potentialAction":{"@type":"SearchAction","target":"https:\/\/indianexpress.com\/?s={search_term_string}","query-input":"required name=search_term_string"}}
#                           </script>
#                           <script type="application/ld+json">
#                            {"@context":"https:\/\/schema.org","@type":"Organization","name":"The Indian Express","url":"https:\/\/indianexpress.com","logo":"https:\/\/images.indianexpress.com\/2019\/11\/ienewlogo3_new.png","address":{"@type":"PostalAddress","streetAddress":"B-1\/B, Sector-10","addressLocality":"Noida","addressRegion":"India","postalCode":"201301","Telephone":"+91-0120-25 0049"},"sameAs":["https:\/\/www.facebook.com\/indianexpress","https:\/\/twitter.com\/indianexpress","https:\/\/www.youtube.com\/IndianExpress"]}
#                           </script>
#                           <script type="text/javascript">
#                            (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 				(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 				m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 			})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# 			ga('create', 'UA-1403607-3', 'auto');
# 			 ga('set', 'dimension2', 'Sports');  ga('set', 'dimension5', 'Listing Page'); ga('send', 'pageview');
#                           </script>
#                           <!-- Begin comScore Tag -->
#                           <script>
#                            var _comscore = _comscore || [];
# 			_comscore.push( { c1: "2", c2: "8738137" } );
# 			( function() {
# 				var s = document.createElement("script"), el = document.getElementsByTagName( "script" )[0];
# 				s.async = true;
# 				s.src = ( document.location.protocol === "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
# 				el.parentNode.insertBefore( s, el );
# 			})();
#                           </script>
#                           <noscript>
#                            <img alt="scorecardresearch" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=8738137&amp;cv=2.0&amp;cj=1"/>
#                           </noscript>
#                           <!-- End comScore Tag -->
#                          </meta>
#                         </meta>
#                        </meta>
#                       </meta>
#                      </meta>
#                     </meta>
#                    </meta>
#                   </meta>
#                  </link>
#                 </link>
#                </link>
#               </link>
#              </link>
#             </link>
#            </link>
#           </link>
#          </link>
#         </link>
#        </link>
#       </link>
#      </link>
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body class="archive tax-ie_section term-sports term-67">
#   <div id="wrapper">
#    <header id="common">
#     <div class="vernaculars-topbar">
#      <ul class="hide_utm_paytm_phonepe">
#       <li>
#        <a class="active" href="https://indianexpress.com/" id="IE_TOP_VERNACULAR_ENGLISH" rel="noopener" target="_blank">
#         English
#         <strong>
#          English
#         </strong>
#        </a>
#       </li>
#       <li>
#        <a class="click-event" href="https://tamil.indianexpress.com/" id="IE_TOP_VERNACULAR_TAMIL" rel="noopener" target="_blank">
#         தமிழ்
#         <strong>
#          Tamil
#         </strong>
#        </a>
#       </li>
#       <li>
#        <a class="click-event" href="https://bengali.indianexpress.com/" id="IE_TOP_VERNACULAR_BANGLA" rel="noopener" target="_blank">
#         বাংলা
#         <strong>
#          Bangla
#         </strong>
#        </a>
#       </li>
#       <li>
#        <a class="click-event" href="https://malayalam.indianexpress.com/" id="IE_TOP_VERNACULAR_MALAYALAM" rel="noopener" target="_blank">
#         മലയാളം
#         <strong>
#          Malayalam
#         </strong>
#        </a>
#       </li>
#       <li>
#        <a class="click-event" href="https://www.jansatta.com/" id="IE_TOP_VERNACULAR_HINDI" rel="noopener" target="_blank">
#         हिंदी
#         <strong>
#          Hindi
#         </strong>
#        </a>
#       </li>
#       <li>
#        <a class="click-event" href="https://www.loksatta.com/" id="IE_TOP_VERNACULAR_MARATHI" rel="noopener" target="_blank">
#         मराठी
#         <strong>
#          Marathi
#         </strong>
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="header-holder">
#      <div class="header-section">
#       <div class="followusbx hide_utm_paytm_phonepe">
#        <span class="followustxt">
#         Follow Us:
#        </span>
#        <a href="https://www.facebook.com/indianexpress" target="_blank">
#         <i class="ieo-facebook">
#          <img alt="" height="34" src="https://indianexpress.com/wp-content/themes/indianexpress/images/fb-followus.svg" width="34"/>
#         </i>
#        </a>
#        <a href="https://twitter.com/indianexpress" target="_blank">
#         <i class="ieo-twitter">
#          <img alt="" height="34" src="https://indianexpress.com/wp-content/themes/indianexpress/images/twitter-followus.svg" width="34"/>
#         </i>
#        </a>
#       </div>
#       <div class="ie-logos">
#        <a href="/" title="The Indian Express">
#         <img alt="The Indian Express" class="-logo" src="https://indianexpress.com/wp-content/themes/indianexpress/images/indian-express-logo-n.svg" title="The Indian Express"/>
#        </a>
#        <div class="datefollow">
#         <span class="datebox">
#          Tuesday, July 06, 2021
#         </span>
#         <div class="clear">
#         </div>
#        </div>
#       </div>
#       <div class="promo-top-slug-ad">
#        <div class="" id="gpt_ad_IE_ROS_PROMO_SLUG_DESK">
#        </div>
#       </div>
#      </div>
#     </div>
#     <nav id="fixednavbar">
#      <div class="toggle-menu">
#       <a class="hamburger-menu" href="javascript:void(0);">
#       </a>
#      </div>
#      <div class="mainnav">
#       <div class="small-logo">
#        <a href="/">
#         <img alt="" src="https://indianexpress.com/wp-content/themes/indianexpress/images/theindianexpress-logo-n.svg"/>
#        </a>
#       </div>
#       <ul id="navbar">
#        <li>
#         <a href="/">
#          Home
#         </a>
#        </li>
#        <li>
#         <a href="/section/india/">
#          India
#         </a>
#        </li>
#        <li>
#         <a href="/section/world/">
#          World
#         </a>
#        </li>
#        <li>
#         <a href="/section/cities/">
#          Cities
#         </a>
#        </li>
#        <li>
#         <a href="/section/opinion/">
#          Opinion
#         </a>
#        </li>
#        <li>
#         <a href="/section/sports/">
#          Sports
#         </a>
#        </li>
#        <li>
#         <a href="/section/entertainment/">
#          Entertainment
#         </a>
#        </li>
#        <li>
#         <a href="/section/lifestyle/">
#          Lifestyle
#         </a>
#        </li>
#        <li>
#         <a href="/section/technology/">
#          Tech
#         </a>
#        </li>
#        <li>
#         <a href="/videos/">
#          Videos
#         </a>
#        </li>
#        <li>
#         <a href="/section/explained/">
#          Explained
#         </a>
#        </li>
#        <li>
#         <a href="/audio/">
#          Audio
#         </a>
#        </li>
#        <li class="epaperlink">
#         <a href="javascript:void(0);" onclick="window.open('/express-plus/today-newsstand/','_self')">
#          Epaper
#          <span class="subscribe-links">
#           Subscribe
#          </span>
#         </a>
#        </li>
#        <li>
#         <div id="demo-modal-target">
#          <div class="iesso-login">
#          </div>
#         </div>
#        </li>
#       </ul>
#      </div>
#      <div class="topsocial right">
#       <a class="searchbxbrn" href="javascript:void(0);">
#        <i class="ie-searchicon">
#        </i>
#       </a>
#       <div class="search-form-full">
#        <div class="search-holder">
#         <div class="closebtn2">
#          <i class="fa-closebtn">
#          </i>
#         </div>
#         <form action="https://indianexpress.com/" class="searchform" id="searchform" method="get" role="search">
#          <div>
#           <label class="screen-reader-text" for="s">
#            Search for:
#           </label>
#           <input id="s" name="s" type="text" value=""/>
#           <input id="searchsubmit" type="submit" value="Search"/>
#          </div>
#         </form>
#         <span id="searcherr">
#         </span>
#         <div class="clear">
#         </div>
#        </div>
#       </div>
#      </div>
#     </nav>
#     <div class="container-header">
#      <div class="adsbox970x90">
#       <div class="" id="gpt_ad_IE_ROS_ATF_728X90">
#       </div>
#      </div>
#     </div>
#    </header>
#    <div class="add-left">
#     <div class="" id="gpt_ad_IE_ROS_LEFT_GUTTER">
#     </div>
#    </div>
#    <div class="add-right">
#     <div class="" id="gpt_ad_IE_ROS_RIGHT_GUTTER">
#     </div>
#    </div>
#    <script>
#     if (window.innerWidth) //if browser supports window.innerWidth
# 		var page_w=window.innerWidth;
# 		else if (document.all) //else if browser supports document.all (IE 4+)
# 		var page_w=document.body.clientWidth;
# 		//var page_w=screen.width;
# 		if( page_w > 1024 ) {
# 			jQuery(".add-left,.add-right").show();
# 		}else{
# 			jQuery(".add-left,.add-right").hide();
# 		}
#    </script>
#    <div id="section">
#     <div class="container">
#      <div class="breaking-news">
#       <div class="breaking-title">
#        Must Read
#       </div>
#       <div class="breakingbx" id="mobilebreakingslider">
#        <ul class="breaking">
#         <li>
#          <a href="https://indianexpress.com/article/education/cbse-class-10-12-board-exams-board-releases-special-assessment-scheme-for-academic-year-2021-22-7390437/" onclick="ga( 'send', 'event', 'Breaking_Ticker', 'Click', 'https://indianexpress.com/article/education/cbse-class-10-12-board-exams-board-releases-special-assessment-scheme-for-academic-year-2021-22-7390437/' );">
#           CBSE Class 10, 12 exams: Board releases special assessment scheme for 2021-22
#          </a>
#         </li>
#         <li>
#          <a href="https://indianexpress.com/article/explained/section-43d5-how-it-sets-the-bar-for-bail-so-high-under-uapa-7390673/" onclick="ga( 'send', 'event', 'Breaking_Ticker', 'Click', 'https://indianexpress.com/article/explained/section-43d5-how-it-sets-the-bar-for-bail-so-high-under-uapa-7390673/' );">
#           Section 43D(5): How it sets the bar for bail so high under UAPA
#          </a>
#         </li>
#         <li>
#          <a href="https://indianexpress.com/article/india/father-stan-swamy-dead-elgar-parishad-case-nia-probe-7390722/" onclick="ga( 'send', 'event', 'Breaking_Ticker', 'Click', 'https://indianexpress.com/article/india/father-stan-swamy-dead-elgar-parishad-case-nia-probe-7390722/' );">
#           Stan Swamy dead: NIA didn’t seek custody but kept him behind bars, rejected his plea
#          </a>
#         </li>
#         <li>
#          <a href="https://indianexpress.com/article/india/indian-daughters-islamic-state-afghanistan-jail-7390727/" onclick="ga( 'send', 'event', 'Breaking_Ticker', 'Click', 'https://indianexpress.com/article/india/indian-daughters-islamic-state-afghanistan-jail-7390727/' );">
#           Daughters in Afghan jail, two women take separate routes
#          </a>
#         </li>
#         <li>
#          <a href="https://indianexpress.com/article/sports/football/sergio-busquets-jorginho-euro-2020-italy-vs-spain-invisible-enforcers-7390730/" onclick="ga( 'send', 'event', 'Breaking_Ticker', 'Click', 'https://indianexpress.com/article/sports/football/sergio-busquets-jorginho-euro-2020-italy-vs-spain-invisible-enforcers-7390730/' );">
#           Sergio Busquets and Jorginho: The enchanting invisible enforcers at Euro 2020
#          </a>
#         </li>
#         <li>
#          <a href="https://indianexpress.com/article/technology/tech-news-technology/microsofts-bringing-android-apps-to-windows-11-but-the-indian-whos-been-doing-that-for-a-decade-is-not-worried-7390361/" onclick="ga( 'send', 'event', 'Breaking_Ticker', 'Click', 'https://indianexpress.com/article/technology/tech-news-technology/microsofts-bringing-android-apps-to-windows-11-but-the-indian-whos-been-doing-that-for-a-decade-is-not-worried-7390361/' );">
#           Microsoft's bringing Android apps to Windows 11, but the Indian who’s been doing that for a decade is not worried
#          </a>
#         </li>
#         <li>
#          <a href="https://indianexpress.com/article/education/narendra-modi-cabinet-reshuffle-this-week-eye-on-coming-polls-covid-control-7390738/" onclick="ga( 'send', 'event', 'Breaking_Ticker', 'Click', 'https://indianexpress.com/article/education/narendra-modi-cabinet-reshuffle-this-week-eye-on-coming-polls-covid-control-7390738/' );">
#           Cabinet reshuffle this week, eye on coming polls, Covid control
#          </a>
#         </li>
#         <li>
#          <a href="https://indianexpress.com/article/india/punjab-congress-crisis-sidhu-vs-amarinder-singh-7390768/" onclick="ga( 'send', 'event', 'Breaking_Ticker', 'Click', 'https://indianexpress.com/article/india/punjab-congress-crisis-sidhu-vs-amarinder-singh-7390768/' );">
#           Punjab: Sidhu’s noise masks growing chorus of promises not kept
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="row">
#       <div class="leftpanel">
#        <div class="top-section">
#         <nav aria-label="Breadcrumb" class="ie-breadcrumb">
#          <ol class="m-breadcrumb">
#           <li>
#            <a href="https://indianexpress.com/">
#             Home
#            </a>
#           </li>
#           <li>
#            <span>
#             Sports
#            </span>
#           </li>
#          </ol>
#         </nav>
#        </div>
#        <div class="page-nav">
#         <ul>
#          <li>
#           <a class="active" href="/sports/">
#            Sports
#           </a>
#          </li>
#          <li>
#           <a href="https://indianexpress.com/about/euro-2020/">
#            EURO 2020
#           </a>
#          </li>
#          <li>
#           <a href="https://indianexpress.com/section/sports/cricket/">
#            Cricket
#           </a>
#          </li>
#          <li>
#           <a href="/section/sports/football/">
#            Football
#           </a>
#          </li>
#          <li>
#           <a href="https://indianexpress.com/about/tokyo-olympics/">
#            Olympics
#           </a>
#          </li>
#          <li>
#           <a href="https://indianexpress.com/section/sports/tennis/">
#            Tennis
#           </a>
#          </li>
#          <li>
#           <a href="https://indianexpress.com/section/sports/wwe-wrestling/">
#            WWE
#           </a>
#          </li>
#          <li>
#           <a href="https://indianexpress.com/picture-gallery-section/sports-gallery/">
#            PHOTOS
#           </a>
#          </li>
#          <li>
#           <a href="https://indianexpress.com/audio/express-sports/">
#            PODCAST
#           </a>
#          </li>
#         </ul>
#        </div>
#        <h1>
#         Sports
#        </h1>
#        <br/>
#        <div class="slider">
#         <div class="sports">
#          <div class="mainslider">
#           <div class="sliderholder left">
#            <ul>
#             <li class="swiper-slide">
#              <a href="https://indianexpress.com/article/sports/cricket/7-members-of-england-cricket-team-test-positive-for-covid-19-stokes-to-lead-against-pakistan-7391566/">
#               <figure>
#                <img alt="7 members of England team test positive for Covid-19, Stokes to lead against Pakistan" src="//images.indianexpress.com/2021/03/ben-stokes-england.jpg?resize=450,250">
#                 <p class="slug">
#                  <img alt="Cricket" src="https://indianexpress.com/wp-content/themes/indianexpress/microsites/ipl/images/cricket.svg">
#                   Cricket
#                  </img>
#                 </p>
#                </img>
#               </figure>
#               <span>
#                7 members of England team test positive for Covid-19, Stokes to lead against Pakistan
#               </span>
#              </a>
#             </li>
#             <li class="swiper-slide">
#              <a href="https://indianexpress.com/article/sports/sport-others/2020-tokyo-games-will-miss-maidens-from-kerala-athletics-7391593/">
#               <figure>
#                <img alt="2020 Tokyo Games will ‘miss’ maidens from Kerala athletics" src="//images.indianexpress.com/2021/07/PT-Usha.jpg?resize=450,250">
#                 <p class="slug">
#                 </p>
#                </img>
#               </figure>
#               <span>
#                2020 Tokyo Games will ‘miss’ maidens from Kerala athletics
#               </span>
#              </a>
#             </li>
#             <li class="swiper-slide">
#              <a href="https://indianexpress.com/article/sports/cricket/mithali-raj-reclaims-no-1-spot-in-icc-womens-odi-player-rankings-7391642/">
#               <figure>
#                <img alt="Mithali Raj reclaims No.1 spot in ICC Women’s ODI player rankings" src="//images.indianexpress.com/2021/07/mithali-raj-bcci.jpg?resize=450,250">
#                 <p class="slug">
#                  <img alt="Cricket" src="https://indianexpress.com/wp-content/themes/indianexpress/microsites/ipl/images/cricket.svg"/>
#                  Cricket
#                 </p>
#                </img>
#               </figure>
#               <span>
#                Mithali Raj reclaims No.1 spot in ICC Women’s ODI player rankings
#               </span>
#              </a>
#             </li>
#             <li class="swiper-slide">
#              <a href="https://indianexpress.com/article/sports/cricket/suryakumar-yadav-pressure-on-sri-lanka-series-7391600/">
#               <figure>
#                <img alt="If there is no pressure, there is no fun: Suryakumar Yadav on Lanka series" src="//images.indianexpress.com/2021/03/suryakumar-yadav-2.jpg?resize=450,250"/>
#                <p class="slug">
#                 <img alt="Cricket" src="https://indianexpress.com/wp-content/themes/indianexpress/microsites/ipl/images/cricket.svg"/>
#                 Cricket
#                </p>
#               </figure>
#               <span>
#                If there is no pressure, there is no fun: Suryakumar Yadav on Lanka series
#               </span>
#              </a>
#             </li>
#             <li class="swiper-slide">
#              <a href="https://indianexpress.com/article/sports/football/sergio-busquets-jorginho-euro-2020-italy-vs-spain-invisible-enforcers-7390730/">
#               <figure>
#                <img alt="Sergio Busquets and Jorginho: The enchanting invisible enforcers" src="//images.indianexpress.com/2021/07/busquets-jorginho.jpg?resize=450,250"/>
#                <p class="slug">
#                 <img alt="Football" src="https://indianexpress.com/wp-content/themes/indianexpress/microsites/ipl/images/football.svg"/>
#                 Football
#                </p>
#               </figure>
#               <span>
#                Sergio Busquets and Jorginho: The enchanting invisible enforcers
#               </span>
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="sec_item left">
#            <ul>
#             <li class="swiper-slide">
#              <a href="https://indianexpress.com/article/sports/football/ousmane-dembele-antoine-griezmann-racism-video-7389865/">
#               <figure>
#                <img alt="Dembele, Griezmann in hot water after leaked 'racist' video clip" src="//images.indianexpress.com/2021/07/Dembele-Griezmann.jpg?resize=450,250"/>
#                <p class="slug">
#                 <img alt="Football" src="https://indianexpress.com/wp-content/themes/indianexpress/microsites/ipl/images/football.svg"/>
#                 Football
#                </p>
#               </figure>
#               <span>
#                Dembele, Griezmann in hot water after leaked 'racist' video clip
#               </span>
#              </a>
#             </li>
#             <li class="swiper-slide">
#              <a href="https://indianexpress.com/article/sports/sport-others/1900-to-2016-indias-history-medal-winners-at-olympics-7389839/">
#               <figure>
#                <img alt="1900 to 2016: India's history, medal winners at Olympics" src="//images.indianexpress.com/2021/07/olympic-medallists.jpg?resize=450,254"/>
#                <p class="slug">
#                </p>
#               </figure>
#               <span>
#                1900 to 2016: India's history, medal winners at Olympics
#               </span>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="second-stories">
#         <div class="story">
#          <figure>
#           <a href="https://indianexpress.com/article/sports/football/italyvs-spain-preview-euro-2020-7389955/">
#            <img alt="Euro 2020: Italy, Spain take unbeaten runs into semis" src="//images.indianexpress.com/2021/06/ItalyvsSwitzerland.jpg"/>
#           </a>
#           <p class="slug">
#            <img alt="Football" src="https://indianexpress.com/wp-content/themes/indianexpress/microsites/ipl/images/football.svg"/>
#            Football
#           </p>
#          </figure>
#          <h6>
#           <a href="https://indianexpress.com/article/sports/football/italyvs-spain-preview-euro-2020-7389955/">
#            Euro 2020: Italy, Spain take unbeaten runs into semis
#           </a>
#          </h6>
#         </div>
#         <div class="story">
#          <figure>
#           <a href="https://indianexpress.com/article/sports/football/euro-2020-luke-shaw-emerges-from-hurt-humiliation-7390493/">
#            <img alt="Luke Shaw emerges from hurt, humiliation" src="//images.indianexpress.com/2021/07/luke-shaw-england.jpg?resize=450,250"/>
#           </a>
#           <p class="slug">
#            <img alt="Football" src="https://indianexpress.com/wp-content/themes/indianexpress/microsites/ipl/images/football.svg"/>
#            Football
#           </p>
#          </figure>
#          <h6>
#           <a href="https://indianexpress.com/article/sports/football/euro-2020-luke-shaw-emerges-from-hurt-humiliation-7390493/">
#            Luke Shaw emerges from hurt, humiliation
#           </a>
#          </h6>
#         </div>
#         <div class="story">
#          <figure>
#           <a href="https://indianexpress.com/article/sports/tennis/golden-oldie-federer-weathers-sonego-storm-to-reach-wimbledon-quarters-7390994/">
#            <img alt="Roger Federer reaches Wimbledon quarters" src="//images.indianexpress.com/2021/07/Untitled-design-43.jpg?resize=450,250"/>
#           </a>
#           <p class="slug">
#            <img alt="Tennis" src="https://indianexpress.com/wp-content/themes/indianexpress/microsites/ipl/images/tennis.svg"/>
#            Tennis
#           </p>
#          </figure>
#          <h6>
#           <a href="https://indianexpress.com/article/sports/tennis/golden-oldie-federer-weathers-sonego-storm-to-reach-wimbledon-quarters-7390994/">
#            Roger Federer reaches Wimbledon quarters
#           </a>
#          </h6>
#         </div>
#        </div>
#        <div class="nation">
#         <div class="section-priority-border">
#         </div>
#         <div class="articles first">
#          <div class="snaps">
#           <a href="https://indianexpress.com/article/sports/football/cristiano-ronaldos-personal-interests-difficult-to-manage-says-maurizio-sarri-juventus-7391746/">
#            <img alt="" class="attachment-thumbnail size-thumbnail wp-post-image" data-lazy-sizes="(max-width: 450px) 100vw, 450px" data-lazy-src="https://images.indianexpress.com/2019/11/sarri-ronaldo-1200.jpg?resize=450,250" data-lazy-srcset="https://images.indianexpress.com/2019/11/sarri-ronaldo-1200.jpg?resize=450,250 450w, https://images.indianexpress.com/2019/11/sarri-ronaldo-1200.jpg?resize=600,334 600w, https://images.indianexpress.com/2019/11/sarri-ronaldo-1200.jpg?resize=768,427 768w, https://images.indianexpress.com/2019/11/sarri-ronaldo-1200.jpg?resize=728,405 728w, https://images.indianexpress.com/2019/11/sarri-ronaldo-1200.jpg?resize=150,83 150w, https://images.indianexpress.com/2019/11/sarri-ronaldo-1200.jpg 1200w" height="250" loading="lazy" src="https://indianexpress.com/wp-content/plugins/lazy-load/images/1x1.trans.gif" width="450"/>
#            <noscript>
#             <img alt="" class="attachment-thumbnail size-thumbnail wp-post-image" height="250" loading="lazy" src="https://images.indianexpress.com/2019/11/sarri-ronaldo-1200.jpg?resize=450,250" width="450"/>
#            </noscript>
#           </a>
#          </div>
#          <h2 class="title">
#           <a href="https://indianexpress.com/article/sports/football/cristiano-ronaldos-personal-interests-difficult-to-manage-says-maurizio-sarri-juventus-7391746/">
#            Cristiano Ronaldo’s personal interests difficult to manage, says Maurizio Sarri
#           </a>
#          </h2>
#          <div class="date">
#           July 6, 2021 4:34:52 pm
#          </div>
#          <p>
#           Maurizio Sarri was appointed as Lazio coach last month, a year after being sacked by the Turin club, where five-time Ballon d'Or winner Ronaldo has played since 2018.
#          </p>
#         </div>
#         <div class="articles">
#          <div class="snaps">
#           <a href="https://indianexpress.com/article/sports/cricket/england-name-new-squad-to-face-pakistan-after-covid-19-cases-include-9-uncapped-players-7391698/">
#            <img alt="ICC Men’s T20I Player Rankings, Dawid Malan, Dawid Malan ICC rankings" class="attachment-thumbnail size-thumbnail wp-post-image" data-lazy-sizes="(max-width: 450px) 100vw, 450px" data-lazy-src="https://images.indianexpress.com/2020/09/Untitled-design-36.jpg?resize=450,250" data-lazy-srcset="https://images.indianexpress.com/2020/09/Untitled-design-36.jpg?resize=450,250 450w, https://images.indianexpress.com/2020/09/Untitled-design-36.jpg?resize=600,334 600w, https://images.indianexpress.com/2020/09/Untitled-design-36.jpg?resize=768,427 768w, https://images.indianexpress.com/2020/09/Untitled-design-36.jpg?resize=728,405 728w, https://images.indianexpress.com/2020/09/Untitled-design-36.jpg?resize=150,83 150w, https://images.indianexpress.com/2020/09/Untitled-design-36.jpg 1200w" height="250" loading="lazy" src="https://indianexpress.com/wp-content/plugins/lazy-load/images/1x1.trans.gif" width="450"/>
#            <noscript>
#             <img alt="ICC Men’s T20I Player Rankings, Dawid Malan, Dawid Malan ICC rankings" class="attachment-thumbnail size-thumbnail wp-post-image" height="250" loading="lazy" src="https://images.indianexpress.com/2020/09/Untitled-design-36.jpg?resize=450,250" width="450"/>
#            </noscript>
#           </a>
#          </div>
#          <h2 class="title">
#           <a href="https://indianexpress.com/article/sports/cricket/england-name-new-squad-to-face-pakistan-after-covid-19-cases-include-9-uncapped-players-7391698/">
#            England name new squad to face Pakistan after COVID-19 cases, include 9 uncapped players
#           </a>
#          </h2>
#          <div class="date">
#           July 6, 2021 4:24:49 pm
#          </div>
#          <p>
#           Two days before the series gets underway with the first of the three one-dayers in Cardiff, Ben Stokes was named captain of an 18-man squad which included nine uncapped players.
#          </p>
#         </div>
#         <div class="articles">
#          <div class="snaps">
#           <a href="https://indianexpress.com/article/sports/cricket/its-still-this-kit-right-stuart-broad-asks-james-anderson-as-ecb-identify-a-new-squad-for-pakistan-series-7391639/">
#            <img alt="Stuart Broad, James Anderson, Stuart Broad odi return, James Anderson odi return, Stuart Broad odi comeback, James Anderson odi comeback, england players covid 19, england odi squad vs pakistan, ben stokes" class="attachment-thumbnail size-thumbnail wp-post-image" data-lazy-sizes="(max-width: 450px) 100vw, 450px" data-lazy-src="https://images.indianexpress.com/2021/07/Anderson-Broad-reuters.jpg?resize=450,250" data-lazy-srcset="https://images.indianexpress.com/2021/07/Anderson-Broad-reuters.jpg?resize=450,250 450w, https://images.indianexpress.com/2021/07/Anderson-Broad-reuters.jpg?resize=600,334 600w, https://images.indianexpress.com/2021/07/Anderson-Broad-reuters.jpg?resize=768,427 768w, https://images.indianexpress.com/2021/07/Anderson-Broad-reuters.jpg?resize=728,405 728w, https://images.indianexpress.com/2021/07/Anderson-Broad-reuters.jpg?resize=150,83 150w, https://images.indianexpress.com/2021/07/Anderson-Broad-reuters.jpg 1200w" height="250" loading="lazy" src="https://indianexpress.com/wp-content/plugins/lazy-load/images/1x1.trans.gif" width="450"/>
#            <noscript>
#             <img alt="Stuart Broad, James Anderson, Stuart Broad odi return, James Anderson odi return, Stuart Broad odi comeback, James Anderson odi comeback, england players covid 19, england odi squad vs pakistan, ben stokes" class="attachment-thumbnail size-thumbnail wp-post-image" height="250" loading="lazy" src="https://images.indianexpress.com/2021/07/Anderson-Broad-reuters.jpg?resize=450,250" width="450"/>
#            </noscript>
#           </a>
#          </div>
#          <h2 class="title">
#           <a href="https://indianexpress.com/article/sports/cricket/its-still-this-kit-right-stuart-broad-asks-james-anderson-as-ecb-identify-a-new-squad-for-pakistan-series-7391639/">
#            “It’s still this kit?”: Stuart Broad asks James Anderson as ECB identify a new squad for Pakistan series
#           </a>
#          </h2>
#          <div class="date">
#           July 6, 2021  4:29:37 pm
#          </div>
#          <p>
#           While Broad and Anderson had their online banter, ECB selected an 18-man squad including nine new faces. However, Alex Hales was still missing from the squad.
#          </p>
#         </div>
#         <div class="articles">
#          <div class="snaps">
#           <a href="https://indianexpress.com/article/sports/cricket/mithali-raj-reclaims-no-1-spot-in-icc-womens-odi-player-rankings-7391642/">
#            <img alt="Mithali Raj" class="attachment-thumbnail size-thumbnail wp-post-image" data-lazy-sizes="(max-width: 450px) 100vw, 450px" data-lazy-src="https://images.indianexpress.com/2021/07/mithali-raj-bcci.jpg?resize=450,250" data-lazy-srcset="https://images.indianexpress.com/2021/07/mithali-raj-bcci.jpg?resize=450,250 450w, https://images.indianexpress.com/2021/07/mithali-raj-bcci.jpg?resize=600,334 600w, https://images.indianexpress.com/2021/07/mithali-raj-bcci.jpg?resize=768,427 768w, https://images.indianexpress.com/2021/07/mithali-raj-bcci.jpg?resize=728,405 728w, https://images.indianexpress.com/2021/07/mithali-raj-bcci.jpg?resize=150,83 150w, https://images.indianexpress.com/2021/07/mithali-raj-bcci.jpg 1200w" height="250" loading="lazy" src="https://indianexpress.com/wp-content/plugins/lazy-load/images/1x1.trans.gif" width="450"/>
#            <noscript>
#             <img alt="Mithali Raj" class="attachment-thumbnail size-thumbnail wp-post-image" height="250" loading="lazy" src="https://images.indianexpress.com/2021/07/mithali-raj-bcci.jpg?resize=450,250" width="450"/>
#            </noscript>
#           </a>
#          </div>
#          <h2 class="title">
#           <a href="https://indianexpress.com/article/sports/cricket/mithali-raj-reclaims-no-1-spot-in-icc-womens-odi-player-rankings-7391642/">
# ...
#         Dance Classes for Kids
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="g-footer-aux">
#     <div class="g-footer-block">
#      <div class="g-footer-sec g-footer-lft">
#       <div class="g-footer-title">
#        Follow Us
#       </div>
#       <ul class="g-follow-icon g-follow">
#        <li>
#         <a href="https://www.facebook.com/indianexpress" rel="noopener" target="_blank" title="Facebook">
#          <img alt="Facebook" height="32" src="https://indianexpress.com/wp-content/themes/indianexpress/images/icons/icon-facebook.svg" width="32">
#          </img>
#         </a>
#        </li>
#        <li>
#         <a href="https://twitter.com/indianexpress" rel="noopener" target="_blank" title="Twitter">
#          <img alt="Twitter" height="32" src="https://indianexpress.com/wp-content/themes/indianexpress/images/icons/icon-twitter.svg" width="32">
#          </img>
#         </a>
#        </li>
#        <li>
#         <a href="https://www.linkedin.com/company/indian-express/" rel="noopener" target="_blank" title="Linkedin">
#          <img alt="Linkedin" height="32" src="https://indianexpress.com/wp-content/themes/indianexpress/images/icons/icon-linkedin.svg" width="32">
#          </img>
#         </a>
#        </li>
#        <li>
#         <a href="https://www.instagram.com/indianexpress/" rel="noopener" target="_blank" title="Instagram">
#          <img alt="Instagram" height="32" src="https://indianexpress.com/wp-content/themes/indianexpress/images/icons/icon-instagram.svg" width="32">
#          </img>
#         </a>
#        </li>
#       </ul>
#       <div class="g-footer-title">
#        Download Apps
#       </div>
#       <ul class="g-follow-icon">
#        <li>
#         <a href="https://play.google.com/store/apps/details?id=com.indianexpress.android&amp;hl=en" rel="noopener" target="_blank" title="Android">
#          <img alt="Android" height="32" src="https://indianexpress.com/wp-content/themes/indianexpress/images/icons/icon-android.svg" width="32"/>
#         </a>
#        </li>
#        <li>
#         <a href="https://itunes.apple.com/us/app/the-indian-express/id506351833?mt=8" rel="noopener" target="_blank" title="iPhone">
#          <img alt="iPhone" height="32" src="https://indianexpress.com/wp-content/themes/indianexpress/images/icons/icon-apple.svg" width="32"/>
#         </a>
#        </li>
#       </ul>
#       <div class="news-guard ev-meter-content">
#        <ul>
#         <li>
#          <img height="18" src="https://indianexpress.com/wp-content/themes/indianexpress/images/newsguard-logo-w.svg" width="120"/>
#         </li>
#         <li>
#          <img height="26" src="https://indianexpress.com/wp-content/themes/indianexpress/images/newsguard-check.svg" width="20"/>
#         </li>
#         <li>
#          The Indian Express website has been rated GREEN for its credibility and trustworthiness by Newsguard, a global service that rates news sources for their journalistic standards.
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="g-footer-sec g-footer-md">
#       <div class="g-footer-title">
#        Express Group
#       </div>
#       <ul class="g-express-group" id="express-group">
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-home menu-item-6454151" id="menu-item-6454151">
#         <a href="https://indianexpress.com/">
#          The Indian Express
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6454159" id="menu-item-6454159">
#         <a href="https://tamil.indianexpress.com/">
#          ieTamil.com
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6454152" id="menu-item-6454152">
#         <a href="https://www.financialexpress.com/">
#          The Financial Express
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6454162" id="menu-item-6454162">
#         <a href="https://bengali.indianexpress.com/">
#          ieBangla.com
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6454153" id="menu-item-6454153">
#         <a href="https://www.loksatta.com/">
#          Loksatta
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6454163" id="menu-item-6454163">
#         <a href="https://malayalam.indianexpress.com/">
#          ieMalayalam.com
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6454156" id="menu-item-6454156">
#         <a href="https://www.jansatta.com/">
#          Jansatta
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6454164" id="menu-item-6454164">
#         <a href="https://www.inuth.com/">
#          inUth
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6454166" id="menu-item-6454166">
#         <a href="https://expressgroup.indianexpress.com/">
#          The ExpressGroup
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6703745" id="menu-item-6703745">
#         <a href="https://www.myinsuranceclub.com/">
#          MyInsuranceClub
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-7076813" id="menu-item-7076813">
#         <a href="https://indianexpress.com/newsletters/">
#          Newsletters
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6454169" id="menu-item-6454169">
#         <a href="https://indianexpress.com/26-11/">
#          26/11 Stories of Strength
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6454167" id="menu-item-6454167">
#         <a href="https://rngfoundation.com/awards/">
#          Ramnath Goenka Excellence in Journalism Awards
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-7321503" id="menu-item-7321503">
#         <a href="https://eureka.indianexpress.com/">
#          Online Classes for Kids
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="g-footer-sec g-footer-rht">
#       <div class="g-footer-title">
#        Quick Links
#       </div>
#       <ul class="g-express-group quick-links" id="g-express-group">
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6454140" id="menu-item-6454140">
#         <a href="/terms-and-conditions/">
#          T&amp;C
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6454142" id="menu-item-6454142">
#         <a href="/privacy-policy/">
#          Privacy Policy
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6454143" id="menu-item-6454143">
#         <a href="https://expressgroup.indianexpress.com/advertise.html">
#          Advertise with Us
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-7349376" id="menu-item-7349376">
#         <a href="https://indianexpress.com/brand-solutions/">
#          Brand Solutions
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6454144" id="menu-item-6454144">
#         <a href="/contact-us/">
#          Contact Us
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6454146" id="menu-item-6454146">
#         <a href="http://subscribe.indianexpress.com/">
#          Subscribe
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6454147" id="menu-item-6454147">
#         <a href="https://indianexpress.com/article/what-is/what-is-the-protection-of-children-from-sexual-offences-act-2012/">
#          Statutory provisions on reporting (sexual offenses)
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6787146" id="menu-item-6787146">
#         <a href="https://indianexpress.com/article/india/code-of-ethics-for-digital-news-websites-6758543/">
#          This website follows the DNPA’s code of conduct
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="g-foot">
#      <div class="privacy">
#       Copyright © 2021 The Indian Express [P] Ltd. All Rights Reserved
#      </div>
#      <div class="wp">
#       <a class="powered-by-wpcom" href="https://vip.wordpress.com/?utm_source=vip_powered_wpcom&amp;utm_medium=web&amp;utm_campaign=VIP%20Footer%20Credit&amp;utm_term=indianexpress.com" rel="nofollow" target="_blank">
#        <img alt="Powered by WordPress.com VIP" height="26" src="https://s1.wp.com/wp-content/themes/vip/plugins/vip-do-not-include-on-wpcom/vip-powered-wpcom/images/vip-powered-dark-small.png?m=1401974073h" width="187"/>
#       </a>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <div class="" id="gpt_ad_IE_ROS_ATF_1X1">
#   </div>
#   <div class="" id="gpt_ad_IE_ROS_OOP_INNOV1">
#   </div>
#   <div class="" id="gpt_ad_IE_ROS_OOP_INNOV2">
#   </div>
#   <script type="text/javascript">
#    var siteDomain  = "https:\/\/ecommerce.indianexpress.com";
# 				var authDomain  = "https:\/\/authentication.indianexpress.com\/";
# 				var eCommConfig = {
# 						orderPage: "https:\/\/accounts.indianexpress.com\/account\/new\/order\/",
# 						newsStandPage: "https:\/\/indianexpress.com\/express-plus\/today-newsstand\/",
# 						issuesPage: "https:\/\/indianexpress.com\/express-plus\/epaper\/previous-issues\/",
# 						productPage: "https:\/\/indianexpress.com\/express-plus\/subscription-plan\/"
# 				};
#   </script>
#   <script>
#    (function (d, s, id) {
# 			IESSO = window.IESSO || (window.IESSO = []);
# 			var js, fjs = d.getElementsByTagName(s)[0];
# 			if (d.getElementById(id)) return;
# 			js = d.createElement(s); js.id = id;
# 			js.defer = "defer";
# 			js.src = "https://accounts.indianexpress.com/swagger-js/v2.0.0/sdk.js?v=21052021.1";
# 			fjs.parentNode.insertBefore(js, fjs);
# 		}(document, "script", "ie-jssdk"));
# 		IESSO.push({
# 			client_id: "indianexpress-03",
# 			redirect_uri: "https://indianexpress.com/accountredirects/",
# 			request_uri: location.href,
# 		});
#   </script>
#   <script type="text/javascript">
#    var clevertap = {event:[], profile:[], account:[], onUserLogin:[], notifications:[], privacy:[]};
# 		sessionStorage['WZRK_D'] = " ";
# 		localStorage['WZRK_D'] = " ";
# 		 // replace with the CLEVERTAP_ACCOUNT_ID with the actual ACCOUNT ID value from your Dashboard -> Settings page
# 		clevertap.account.push({"id": "844-RZZ-995Z"});
# 		clevertap.privacy.push({optOut: false}); //set the flag to true, if the user of the device opts out of sharing their data
# 		clevertap.privacy.push({useIP: false}); //set the flag to true, if the user agrees to share their IP data
# 		 (function () {
# 			 var wzrk = document.createElement('script');
# 			 wzrk.type = 'text/javascript';
# 			 wzrk.async = true;
# 			 wzrk.src = ('https:' == document.location.protocol ? 'https://d2r1yp2w7bby2u.cloudfront.net' : 'http://static.clevertap.com') + '/js/a.js';
# 			 var s = document.getElementsByTagName('script')[0];
# 			 s.parentNode.insertBefore(wzrk, s);
# 		  })();
#   </script>
#   <script id="ie_async_ad_code_js-js-extra">
#    var ad_code_params = {"articleId":"","loop_counter":"11","ad_units":[{"slot_name":"\/1050432\/www.indianexpress.com\/IE_ROS_SPORTS_HP_ATF_1x1","slot_size":[1,1],"slot_id":"gpt_ad_IE_ROS_ATF_1X1"},{"slot_name":"\/1050432\/www.indianexpress.com\/IE_ROS_SPORTS_HP_ATF_728X90","slot_size":[[970,250],[970,90],[970,200],[728,90],"fluid"],"slot_id":"gpt_ad_IE_ROS_ATF_728X90"},{"slot_name":"\/1050432\/www.indianexpress.com\/IE_ROS_SPORTS_HP_ATF_300X250","slot_size":[[300,250],[300,600],"fluid"],"slot_id":"gpt_ad_IE_ROS_ATF_300X250"},{"slot_name":"\/1050432\/www.indianexpress.com\/IE_ROS_SPORTS_HP_MID_300X250","slot_size":[[300,250],[300,600],"fluid"],"slot_id":"gpt_ad_IE_ROS_MID_300X250"},{"slot_name":"\/1050432\/www.indianexpress.com\/IE_ROS_SPORTS_HP_BTF_300X250","slot_size":[[300,250],[300,600],"fluid"],"slot_id":"gpt_ad_IE_ROS_BTF_300X250"},{"slot_name":"\/1050432\/www.indianexpress.com\/IE_ROS_SPORTS_HP_BTF_728X90","slot_size":[[970,250],[970,90],[970,200],[728,90],"fluid"],"slot_id":"gpt_ad_IE_ROS_BTF_728X90"},{"slot_name":"\/1050432\/www.indianexpress.com\/IE_ROS_SPORTS_HP_OOP_INNOV1","slot_size":"","slot_id":"gpt_ad_IE_ROS_OOP_INNOV1"},{"slot_name":"\/1050432\/www.indianexpress.com\/IE_ROS_SPORTS_HP_OOP_INNOV2","slot_size":"","slot_id":"gpt_ad_IE_ROS_OOP_INNOV2"},{"slot_name":"\/1050432\/www.indianexpress.com\/IE_ROS_SPORTS_HP_SKIN_LHS","slot_size":[[120,600],[160,600]],"slot_id":"gpt_ad_IE_ROS_LEFT_GUTTER"},{"slot_name":"\/1050432\/www.indianexpress.com\/IE_ROS_SPORTS_HP_SKIN_RHS","slot_size":[[120,600],[160,600]],"slot_id":"gpt_ad_IE_ROS_RIGHT_GUTTER"},{"slot_name":"\/1050432\/www.indianexpress.com\/IE_Promotional_Slug_220x70","slot_size":[220,70],"slot_id":"gpt_ad_IE_ROS_PROMO_SLUG_DESK"}]};
#   </script>
#   <script id="ie_async_ad_code_js-js" src="https://indianexpress.com/wp-content/plugins/express-ad-code-manager/js/page-ad-codes.js?ver=05052021.0">
#   </script>
#   <script id="ie_async_ad_code_js-js-after">
#    var templateType = "other";
# 			var peCid=2;
# 			(function(d, s) {
# 				var js, fjs = d.getElementsByTagName(s)[0];
# 				js = d.createElement(s);
# 				js.id = "psdk";
# 				js.async = 1;
# 				js.src = "https://ua.indianexpress.com/personlization-sdk.min.js";
# 				fjs.parentNode.insertBefore(js, fjs);
# 			}(document, "script"));
#   </script>
#   <script id="ev-em-js-extra">
#    var custom_ev_data = {"articleId":"","site":"The Indian Express","title":"Sports","authors":"","category":"","section":"sports","tags":"section_tags","count_metering":"true","premium":""};
#   </script>
#   <script src="https://indianexpress.com/_static/??-eJydzE0SQDAMQOELqQz1szLOYjRDS1IjoY6vV2D3Nt+DdJg5siIr6IqEAp6dnxif40QRCAJ4xz1uQJ5zGqQyVxmkgM82ebegyo9BxvMlGim7kYaqq5vW2t7W4QUCzUfi" type="text/javascript">
#   </script>
#   <script id="english-premier-league-2017-18-js-js" src="https://sportsassets.indianexpress.com/football/js/init.js?ver=1.1">
#   </script>
#   <script id="ie-chat-bot-js-js-extra">
#    var onscroll_bot = {"chat_bot":"https:\/\/chat.amplify.ai\/plugin\/5d8c79fc71d7034e8751eec9\/chat_plugin.js?pluginId=5d8c79fc71d7034e8751eec9","device_type":"desktop","event_url":"https:\/\/indianexpress.com\/section\/sports\/"};
#   </script>
#   <script id="ie-author-follow-widget-script-js-extra">
#    var af_widget_data = {"af_article_count":"2"};
#   </script>
#   <script id="ie-mafl-widget-script-js-extra">
#    var mafl_check = {"mafl_count":"3","box_msg":"Get email alerts for your favourite author. Sign up here","ie_mobile_check":"no","theme_url":"https:\/\/indianexpress.com\/wp-content\/themes\/indianexpress","tracking_c":null};
#   </script>
#   <script id="ie-taboola-script-js-extra">
#    var taboolaExports = {"mode":"alternating-thumbnails-b","placement":"below content","container":"taboola-below-content","target_type":"mix"};
#   </script>
#   <script src="https://indianexpress.com/_static/??-eJydkMFOw0AMRH8IZ6FIVXNAfIuTdZMNXjusnYb265tIhQPKIXAcj9/I4zCP0Ko4iQfvKZOFJDGh0NdYyCwMy4BAaDYmdyrVYE9hH9T26NCog4q1RZn3sjnJyuPkvRaIZB+uI8wpduSwmH+4ISOffyXspS8kUUtwbFQZ/0fBWXXjaSNPXRILjLcrsGJcyeFzonKtTAVLtdFyE/oR39tJWp6Wwqu5SMoNxUfae357OR6eT8fXuj4Md9s7vfo=" type="text/javascript">
#   </script>
#   <script async="" id="ie-google-onetap-js-js" src="//accounts.google.com/gsi/client?ver=20210706">
#   </script>
#   <script defer="" src="https://stats.wp.com/e-202127.js">
#   </script>
#   <script>
#    _stq = window._stq || [];
# 	_stq.push([ 'view', {v:'ext',j:'1:9.8.1',blog:'150893645',post:'0',tz:'5.5',srv:'indianexpress.com'} ]);
# 	_stq.push([ 'clickTrackerInit', '150893645', '0' ]);
#   </script>
#   <div id="cptup-ready">
#   </div>
#   <div id="user">
#   </div>
#   <div class="widget-dialog" id="offermapmain" style="width:90%">
#   </div>
#  </body>
# </html>

# %%
print(soup4.prettify())
# Out:
# ﻿
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Sports News: Latest Sports News, Live Scores, Results Today's Sports Headlines Updates
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="Sports News - Get Latest Sports News Today Headlines on Times Now news.com. Find latest cricket news, tennis, football, hockey, World cup 2021, IPL 2021, Live Score Updates. Stay updated on Sports News at Times Now" name="description"/>
#   <meta content="TimesNow" name="author"/>
#   <meta content="Sports News: Latest Sports News, Live Scores, Results Today's Sports Headlines Updates" itemprop="name"/>
#   <meta content="Sports News - Get Latest Sports News Today Headlines on Times Now news.com. Find latest cricket news, tennis, football, hockey, World cup 2021, IPL 2021, Live Score Updates. Stay updated on Sports News at Times Now" itemprop="description"/>
#   <meta content="https://iks.timesnownews.com/s/v1/img/logo/c_tnlogo.png" property="image"/>
#   <meta content="https://iks.timesnownews.com/s/v1/img/c_tnplaceholder.png" id="meta_image" itemprop="image"/>
#   <meta content="https://iks.timesnownews.com/s/v1/img/logo/c_tnlogo.png" id="meta_img" property="og:image"/>
#   <meta content="TimesNow" property="og:site_name"/>
#   <meta content="Sports News: Latest Sports News, Live Scores, Results Today's Sports Headlines Updates" id="meta_title" property="og:title">
#    <meta content="Sports News - Get Latest Sports News Today Headlines on Times Now news.com. Find latest cricket news, tennis, football, hockey, World cup 2021, IPL 2021, Live Score Updates. Stay updated on Sports News at Times Now" id="meta_description" property="og:description">
#     <meta content="Sports News, Cricket News,cricket news today,india cricket news,cricket news today match, latest cricket news, WWE Results, Football News, Badminton News, Hockey News, Tennis News, Kabaddi News, Cricket Score, Latest News, News Headlines, Sports Headlines" id="meta_news_keywords" name="keywords"/>
#     <!-- include css -->
#     <link href="https://iks.timesnownews.com/s/v1/css/d_catindia2.css?v=7.4" rel="stylesheet" type="text/css"/>
#     <style type="text/css">
#      .tabunmute{position:absolute;width:168px;height:32px;box-shadow:0 0 4px 0 rgba(0,0,0,0.5);top:10px;left:16px;background:url(https://iks.timesnownews.com/s/v1/img/m_unmute.svg) no-repeat 7px center #fff;font-size:1em;color:#000;line-height:32px;padding-left:32px;z-index:1;user-select:none;cursor:pointer;overflow:hidden}
# .content-block .section-six { margin-top: 10px}
#     </style>
#     <meta content="218735715310" property="fb:pages">
#      <link href="https://www.timesnownews.com/sports" rel="canonical"/>
#      <link href="https://iks.timesnownews.com/s/v1/css/d_header1.css?v=7.4" rel="stylesheet" type="text/css">
#       <link href="https://iks.timesnownews.com/s/v1/css/d_footer.css?v=7.4" rel="stylesheet" type="text/css"/>
#       <link href="https://iks.timesnownews.com/s/v1/css/d_vendor.css" rel="stylesheet" type="text/css"/>
#       <link href="https://iks.timesnownews.com/s/v1/css/d_widgets.css?v=7.4" rel="stylesheet" type="text/css"/>
#       <style type="text/css">
#        .tncls_ad{width:100%;position:relative;display:flex;align-items:center;justify-content: center;}
# .tncls_ad:before{content:'ADVERTISEMENT';font-size:12px;line-height:1;color:#000;width:100%;text-align:center;position:absolute;top:50%;margin-top:-7px;z-index:1;left:0}
# .tncls_ad>div{position:relative;z-index:2}
# .tncls_ad_90{min-height:95px}
# .tncls_ad_250{min-height:250px}
# .tncls_ad_300 {min-height: 290px;}
# .tncls_ad_600 {min-height: 600px;}
# .tncls_icon {min-height: 20px;}
# .tncls_50 {min-height: 50px;}
# .tncls_common_200 {min-height: 200px;}
# .tncls_common_70 {min-height:70px;}
# .tncls_comp_140 {min-height:140px;}
# .night .tncls_ad {background-color:#081018}
# .day .tncls_ad {background-color:#f1f1f1}
# .tnas_16_9 {min-height:56vw;}
# .tncls_comp_500{min-height:500px}
# .tncls_ad{background-color:#ebebeb}
# .tncls_embds{min-height:400px}
# .tncls_ov_player  {min-height:479px;}
# .tncls_ov_div {min-height:819px;}
# .tncls_ov_btn {min-height:40px;}
# .tncls_ad_110 {min-height:103px;}
# ._live_tv_content {min-height: 190px;}
#       </style>
#       <!-- <style type="text/css">.tncls_ad{background-color:#ebebeb;}</style> -->
#       <meta content="#254A96" name="theme-color">
#        <link href="https://iks.timesnownews.com/s/v1/img/c_favicon48x48.ico" rel="icon" type="image/x-icon"/>
#        <link href="https://iks.timesnownews.com/s/v1/img/c_favicon48x48.ico" rel="shortcut icon"/>
#        <script async="async" type="text/javascript">
#         (function(i, s, o, g, r, a, m) {i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function() {(i[r].q = i[r].q || []).push(arguments) }, i[r].l = 1 * new Date(); a = s.createElement(o), m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m) })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
# ga('create', 'UA-64032556-12', {'cookieDomain': 'none'});
# ga('send', 'pageview');
# document.addEventListener("DOMContentLoaded", function(event) {var ad = document.createElement('ins'); ad.className = 'adsbox'; ad.innerHTML = '&nbsp;'; document.body.appendChild(ad); window.setTimeout(function() {if (ad.offsetHeight === 0) {ga('send', 'event', 'AdSetting', 'Adblock', 'Enabled', {nonInteraction: true}); } ad.remove(); }, 1000); });
#        </script>
#        <!-- comscore script starts -->
#        <script>
#         var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "26200502" });
#   (function() {
#         var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#         s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#         el.parentNode.insertBefore(s, el);
#   })();
#        </script>
#        <noscript>
#         <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=26200502&amp;cv=2.0&amp;cj=1"/>
#        </noscript>
#        <!-- comscore script ends -->
#        <script type="text/javascript">
#         window._taboola = window._taboola || [];
#      _taboola.push({'category':'auto', 'tracking':'utm_source=taboola&utm_medium=referral&utm_campaign=en-category-sports'});
#     document.addEventListener("DOMContentLoaded", function(event) {
#     // setTimeout(function(){
#       !function (e, f, u, i) {
#         if (!document.getElementById(i)){
#           e.async = 1;
#           e.src = u;
#           e.id = i;
#           f.parentNode.insertBefore(e, f);
#         }
#       }(document.createElement('script'),
#       document.getElementsByTagName('script')[0],
#       '//cdn.taboola.com/libtrc/timesnow-timesnownews/loader.js',
#       'tb_loader_script');
#       if(window.performance && typeof window.performance.mark == 'function')
#         {window.performance.mark('tbl_ic');}
#     // },2000);
#     });
#        </script>
#        <!-- Taboola End -->
#        <!-- Taboola Pixel Code -->
#        <script type="text/javascript">
#         window._tfa = window._tfa || [];
#       window._tfa.push({notify: 'event', name: 'page_view', id: 1121229});
#       !function (t, f, a, x) {
#              if (!document.getElementById(x)) {
#                 t.async = 1;t.src = a;t.id=x;f.parentNode.insertBefore(t, f);
#              }
#       }(document.createElement('script'),
#       document.getElementsByTagName('script')[0],
#       '//cdn.taboola.com/libtrc/unip/1121229/tfa.js',
#       'tb_tfa_script');
#        </script>
#        <noscript>
#         <img height="0" src="//trc.taboola.com/1121229/log/3/unip?en=page_view" style="display:none" width="0"/>
#        </noscript>
#        <!-- End of Taboola Pixel Code -->
#        <script src="https://imasdk.googleapis.com/js/sdkloader/ima3_dai.js" type="text/javascript">
#        </script>
#        <input id="is_dai_enable" type="hidden" value="1"/>
#        <style type="text/css">
#         .content-block .section-five{margin-top: 5px}
#        </style>
#       </meta>
#      </link>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div class="wrapper">
#    <!-- Removed -->
#    <div class="top-bar">
#     <div class="partner-menu">
#      <ul>
#       <li>
#        <a class="times" href="https://www.timesnownews.com">
#         Times Now
#        </a>
#       </li>
#      </ul>
#      <div style="font-size:14px; line-height: 1; color: #fff;  float:left; margin-left: 10px; padding-top: 3px;text-transform: uppercase;">
#       Tue, Jul 06, 2021 | UPDATED 16:35 IST
#      </div>
#     </div>
#     <div class="social-menu tncls_icon">
#      <ul>
#       <li>
#        <a>
#         Follow us on :
#        </a>
#       </li>
#       <li>
#        <a href="https://www.facebook.com/Timesnow" target="_blank" title="facebook">
#         <div class="social-share fb">
#         </div>
#        </a>
#       </li>
#       <li>
#        <a href="https://twitter.com/TIMESNOW" target="_blank" title="twitter">
#         <div class="social-share tw">
#         </div>
#        </a>
#       </li>
#       <li>
#        <a href="https://www.instagram.com/timesnow/" target="_blank" title="instagram">
#         <div class="social-share inst">
#         </div>
#        </a>
#       </li>
#       <li>
#        <a href="https://t.me/timesnowofficial" target="_blank" title="telegram">
#         <div class="home_tele">
#         </div>
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <style>
#     .top-bar .partner-menu ul { float: left}
# .top-bar .partner-menu ul li a { color:#000 !important }
# .top-bar .partner-menu ul li a.times {color: #5ab4f9 !important}
# .home_tele {background:url(https://imgk.timesnownews.com/s/v1/img/c_telegramhover.svg) no-repeat center ; float: left; width: 12px; height: 12px; background-size: 12px}
# .top-bar .social-menu ul li:last-child a::after { display: none; }
#    </style>
#    <style>
#     header .header .main-menu ul>li>a{ font-size: 12px; line-height: 1}
# header .header .main-menu ul li a.arrow::after { top: 2px;width: 10px; height: 10px; right: 3px}
# header .header .main-menu ul li .sub-cover { top:9px}
#  ._seo_links { width:100%; float: left; display: flex; flex-wrap: wrap; padding-top: 10px; }
#  ._seo_text_links { color: #000!important; line-height: 1; font-size:0.750em; padding: 5px 8px; margin-bottom: 8px; background:#f4f4f4 ; border-radius: 3px; border: 1px solid #e7e7e7; overflow: hidden; margin-right: 10px; font-family: Arial, Helvetica, sans-serif}
# a {text-decoration: none;}
#
# header .header .main-menu ul li a._tn_tvlive_desktop {    background: url(https://iks.timesnownews.com/s/v1/img/Live-tv-icon.svg) no-repeat left top;
#     height: 17px;
#     line-height: 16px;
#     font-weight: bold;
#     color: #dc252a;
#     padding-left: 22px;
#     font-size: 12px;
#     padding-right: 0;
#     margin-left: 8px;
# }
# header.et-now-header .header .main-menu ul li a._tn_tvlive_desktop,
# header.mirror-now-header .header .main-menu ul li a._tn_tvlive_desktop,
# header.drive-one .header .main-menu ul li a._tn_tvlive_desktop,
# header.recipe .header .main-menu ul li a._tn_tvlive_desktop,
# header.zoom-tv-header .header .main-menu ul li a._tn_tvlive_desktop { color: #fff;    background: url(https://iks.timesnownews.com/s/v1/img/Live-tv-wicon.svg) no-repeat left top;}
# header .header .main-menu ul li a {    font-weight: bold;}
# header .header .main-menu ul li a.last { color: #264a96}
# header.zoom-tv-header .header .main-menu ul li a._tn_tvlive_desktop {padding-right: 8px}
# @media screen and (max-width: 1290px) {  header .header .main-menu ul li .level-one .section { width:200px; }}
#    </style>
#    <header id="siteheader">
#     <div class="alert-box success error primary hide">
#      <div class="note">
#      </div>
#     </div>
#     <div class="header" id="siteheader">
#      <a class="logo tncls_icon" href="https://www.timesnownews.com">
#       <img alt="Latest News by Times now News" src="https://iks.timesnownews.com/s/v1/img/logo/c_tnlogo.png" title="Latest News by Times now News"/>
#      </a>
#      <div class="search-icon">
#       <img alt="search" onclick="sendEvent('category','Click','Search Icon')" src="https://iks.timesnownews.com/s/v1/img/d_search.svg" title="search"/>
#       <div class="search-content">
#        <div class="form-input">
#         <input autofocus="autofocus" class="search" name="search" placeholder="Search Article, Videos, Images.. " type="text"/>
#         <input id="autosuggest" name="autosuggest" type="hidden" value="">
#          <div class="close-search">
#          </div>
#         </input>
#        </div>
#        <div class="search-result">
#        </div>
#       </div>
#      </div>
#      <div class="main-menu list tncls_icon">
#       <ul>
#        <li>
#         <a href="/sports/football" onclick="sendEvent('Top Navigation','Level 1','/sports/football')">
#          FOOTBALL
#         </a>
#        </li>
#        <li>
#         <a href="/sports/tennis" onclick="sendEvent('Top Navigation','Level 1','/sports/tennis')">
#          TENNIS
#         </a>
#        </li>
#        <li>
#         <a href="/sports/others" onclick="sendEvent('Top Navigation','Level 1','/sports/others')">
#          OTHERS
#         </a>
#        </li>
#        <li>
#         <a href="/sports/badminton" onclick="sendEvent('Top Navigation','Level 1','/sports/badminton')">
#          BADMINTON
#         </a>
#        </li>
#        <li>
#         <a href="/sports/wwe" onclick="sendEvent('Top Navigation','Level 1','/sports/wwe')">
#          WWE
#         </a>
#        </li>
#        <li>
#         <a class="arrow" href="/sports/cricket" onclick="sendEvent('Top Navigation','Level 1','/sports/cricket')">
#          CRICKET
#         </a>
#         <div class="sub-cover">
#          <div class="sub-menu">
#           <ul>
#            <li>
#             <a href="/sports/cricket/cricket-news" onclick="sendEvent('Top Navigation','Level 2','/sports/cricket/cricket-news')">
#              Cricket news
#             </a>
#            </li>
#            <li>
#             <a href="https://www.timesnownews.com/sports/cricket/ipl" onclick="sendEvent('Top Navigation','Level 2','https://www.timesnownews.com/sports/cricket/ipl')" target="_blank">
#              IPL 2021
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </li>
#        <li>
#         <a class="_tn_tvlive_desktop" href="https://www.timesnownews.com/live-tv" onclick="sendEvent('LiveTVbutton','Click','livtv');">
#          LIVE TV
#         </a>
#        </li>
#        <li class="menu-more">
#         <a class="last" href="#">
#          MORE+
#         </a>
#         <div class="level-one">
#          <div class="section">
#           <div class="sector">
#            <div class="title">
#             <a href="/videos" onclick="sendEvent('Top Navigation','Level 1','/videos')">
#              VIDEOS
#             </a>
#            </div>
#            <div class="level-two">
#             <ul>
#              <li>
#               <a class="arrow" href="/videos/et-now" onclick="sendEvent('Top Navigation','Level 2','/videos/et-now')">
#                ET Now
#               </a>
#               <div class="level-three">
#                <ul>
#                 <li>
#                  <a href="/videos/et-now/companies" onclick="sendEvent('Top Navigation','Level 3','/videos/et-now/companies')">
#                   Companies
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/et-now/financial-reports" onclick="sendEvent('Top Navigation','Level 3','/videos/et-now/financial-reports')">
#                   Financial Reports
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/et-now/markets" onclick="sendEvent('Top Navigation','Level 3','/videos/et-now/markets')">
#                   Markets
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/et-now/news" onclick="sendEvent('Top Navigation','Level 3','/videos/et-now/news')">
#                   News
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/et-now/shows" onclick="sendEvent('Top Navigation','Level 3','/videos/et-now/shows')">
#                   Shows
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </li>
#              <li>
#               <a class="arrow" href="/videos/health" onclick="sendEvent('Top Navigation','Level 2','/videos/health')">
#                Health
#               </a>
#               <div class="level-three">
#                <ul>
#                 <li>
#                  <a href="/videos/health/fitness" onclick="sendEvent('Top Navigation','Level 3','/videos/health/fitness')">
#                   Fitness
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/health/fitness-weight-loss" onclick="sendEvent('Top Navigation','Level 3','/videos/health/fitness-weight-loss')">
#                   Weight Loss
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/health/fitness-yoga" onclick="sendEvent('Top Navigation','Level 3','/videos/health/fitness-yoga')">
#                   Yoga
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </li>
#              <li>
#               <a class="arrow" href="/videos/lifestyle" onclick="sendEvent('Top Navigation','Level 2','/videos/lifestyle')">
#                Lifestyle
#               </a>
#               <div class="level-three">
#                <ul>
#                 <li>
#                  <a href="/videos/lifestyle/beauty-diy" onclick="sendEvent('Top Navigation','Level 3','/videos/lifestyle/beauty-diy')">
#                   DIY
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/lifestyle/fashion-hacks" onclick="sendEvent('Top Navigation','Level 3','/videos/lifestyle/fashion-hacks')">
#                   Hacks
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/lifestyle/horoscope" onclick="sendEvent('Top Navigation','Level 3','/videos/lifestyle/horoscope')">
#                   Horoscope
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/lifestyle/mens-fashion" onclick="sendEvent('Top Navigation','Level 3','/videos/lifestyle/mens-fashion')">
#                   Men's Fashion
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/lifestyle/womens-fashion" onclick="sendEvent('Top Navigation','Level 3','/videos/lifestyle/womens-fashion')">
#                   Women's Fashion
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/lifestyle/shows" onclick="sendEvent('Top Navigation','Level 3','/videos/lifestyle/shows')">
#                   Shows
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </li>
#              <li>
#               <a class="arrow" href="/videos/mirror-now" onclick="sendEvent('Top Navigation','Level 2','/videos/mirror-now')">
#                Mirror Now
#               </a>
#               <div class="level-three">
#                <ul>
#                 <li>
#                  <a href="/videos/mirror-now/crime" onclick="sendEvent('Top Navigation','Level 3','/videos/mirror-now/crime')">
#                   Crime
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/mirror-now/politics" onclick="sendEvent('Top Navigation','Level 3','/videos/mirror-now/politics')">
#                   Politics
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/mirror-now/shows" onclick="sendEvent('Top Navigation','Level 3','/videos/mirror-now/shows')">
#                   Shows
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/mirror-now/society" onclick="sendEvent('Top Navigation','Level 3','/videos/mirror-now/society')">
#                   Society
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/mirror-now/urban-debate" onclick="sendEvent('Top Navigation','Level 3','/videos/mirror-now/urban-debate')">
#                   Urban Debate
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/mirror-now/specials" onclick="sendEvent('Top Navigation','Level 3','/videos/mirror-now/specials')">
#                   Specials
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </li>
#              <li>
#               <a class="arrow" href="/videos/foodie" onclick="sendEvent('Top Navigation','Level 2','/videos/foodie')">
#                The Foodie
#               </a>
#               <div class="level-three">
#                <ul>
#                 <li>
#                  <a href="/videos/foodie/baking-recipes" onclick="sendEvent('Top Navigation','Level 3','/videos/foodie/baking-recipes')">
#                   Baking Recipes
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/foodie/breakfast-recipes" onclick="sendEvent('Top Navigation','Level 3','/videos/foodie/breakfast-recipes')">
#                   Breakfast Recipes
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/foodie/food-features" onclick="sendEvent('Top Navigation','Level 3','/videos/foodie/food-features')">
#                   Features
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/foodie/foodie-facts" onclick="sendEvent('Top Navigation','Level 3','/videos/foodie/foodie-facts')">
#                   Foodie Facts
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/foodie/healthy-recipes" onclick="sendEvent('Top Navigation','Level 3','/videos/foodie/healthy-recipes')">
#                   Healthy Recipes
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/foodie/seasonal-festive-recipes" onclick="sendEvent('Top Navigation','Level 3','/videos/foodie/seasonal-festive-recipes')">
#                   Seasonal Recipes
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/foodie/shows" onclick="sendEvent('Top Navigation','Level 3','/videos/foodie/shows')">
#                   Shows
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/foodie/starters-snacks" onclick="sendEvent('Top Navigation','Level 3','/videos/foodie/starters-snacks')">
#                   Starters &amp; Snacks
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </li>
#              <li>
#               <a class="arrow" href="/videos/times-drive" onclick="sendEvent('Top Navigation','Level 2','/videos/times-drive')">
#                Times Drive
#               </a>
#               <div class="level-three">
#                <ul>
#                 <li>
#                  <a href="/videos/times-drive/features" onclick="sendEvent('Top Navigation','Level 3','/videos/times-drive/features')">
#                   Features
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/times-drive/car-reviews" onclick="sendEvent('Top Navigation','Level 3','/videos/times-drive/car-reviews')">
#                   Car Reviews
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/times-drive/bike-reviews" onclick="sendEvent('Top Navigation','Level 3','/videos/times-drive/bike-reviews')">
#                   Bike Reviews
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/times-drive/cars-first-look" onclick="sendEvent('Top Navigation','Level 3','/videos/times-drive/cars-first-look')">
#                   Cars First Look
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/times-drive/bikes-first-look" onclick="sendEvent('Top Navigation','Level 3','/videos/times-drive/bikes-first-look')">
#                   Bikes First Look
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/times-drive/bike-comparisons" onclick="sendEvent('Top Navigation','Level 3','/videos/times-drive/bike-comparisons')">
#                   Bike Comparisons
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/times-drive/car-comparisons" onclick="sendEvent('Top Navigation','Level 3','/videos/times-drive/car-comparisons')">
#                   Car Comparisons
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/times-drive/features-shows" onclick="sendEvent('Top Navigation','Level 3','/videos/times-drive/features-shows')">
#                   Shows
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </li>
#              <li>
#               <a class="arrow" href="/videos/times-now" onclick="sendEvent('Top Navigation','Level 2','/videos/times-now')">
#                Times Now
#               </a>
#               <div class="level-three">
#                <ul>
#                 <li>
#                  <a href="/videos/times-now/india" onclick="sendEvent('Top Navigation','Level 3','/videos/times-now/india')">
#                   India
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/times-now/india-upfront" onclick="sendEvent('Top Navigation','Level 3','/videos/times-now/india-upfront')">
#                   India Upfront
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/times-now/newshour" onclick="sendEvent('Top Navigation','Level 3','/videos/times-now/newshour')">
#                   Newshour
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/times-now/shows" onclick="sendEvent('Top Navigation','Level 3','/videos/times-now/shows')">
#                   Shows
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/times-now/world" onclick="sendEvent('Top Navigation','Level 3','/videos/times-now/world')">
#                   World
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </li>
#              <li>
#               <a class="arrow" href="/videos/news-plus" onclick="sendEvent('Top Navigation','Level 2','/videos/news-plus')">
#                TN+
#               </a>
#               <div class="level-three">
#                <ul>
#                 <li>
#                  <a href="/videos/news-plus/singles" onclick="sendEvent('Top Navigation','Level 3','/videos/news-plus/singles')">
#                   Singles
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/news-plus/series" onclick="sendEvent('Top Navigation','Level 3','/videos/news-plus/series')">
#                   Series
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </li>
#              <li>
#               <a class="arrow" href="/videos/zoom" onclick="sendEvent('Top Navigation','Level 2','/videos/zoom')">
#                Zoom
#               </a>
#               <div class="level-three">
#                <ul>
#                 <li>
#                  <a href="/videos/zoom/bollywood" onclick="sendEvent('Top Navigation','Level 3','/videos/zoom/bollywood')">
#                   Bollywood
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/zoom/bollywood-fashion" onclick="sendEvent('Top Navigation','Level 3','/videos/zoom/bollywood-fashion')">
#                   Bollywood Fashion &amp; Fitness
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/zoom/bollywood-gossip" onclick="sendEvent('Top Navigation','Level 3','/videos/zoom/bollywood-gossip')">
#                   Gossip
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/zoom/movie-reviews" onclick="sendEvent('Top Navigation','Level 3','/videos/zoom/movie-reviews')">
#                   Movie Reviews
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/zoom/bollywood-news" onclick="sendEvent('Top Navigation','Level 3','/videos/zoom/bollywood-news')">
#                   News
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/zoom/shows" onclick="sendEvent('Top Navigation','Level 3','/videos/zoom/shows')">
#                   Shows
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/zoom/telly-talk" onclick="sendEvent('Top Navigation','Level 3','/videos/zoom/telly-talk')">
#                   Telly Talk
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/videos/zoom/tv-gossip" onclick="sendEvent('Top Navigation','Level 3','/videos/zoom/tv-gossip')">
#                   TV Gossip
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="sector noborder">
#            <a class="link" href="/videos/podcasts" onclick="sendEvent('Top Navigation','Level 1','/videos/podcasts')">
#             Podcasts
#            </a>
#            <a class="link" href="/international" onclick="sendEvent('Top Navigation','Level 1','/international')">
#             WORLD
#            </a>
#            <a class="link" href="/info/timesnetwork-trai-value-package/337775" onclick="sendEvent('Top Navigation','Level 1','/info/timesnetwork-trai-value-package/337775')">
#             Times Channel Packs
#            </a>
#           </div>
#          </div>
#          <div class="section">
#           <div class="sector">
#            <div class="title">
#             <a href="/business-economy" onclick="sendEvent('Top Navigation','Level 1','/business-economy')">
#              BUSINESS
#             </a>
#            </div>
#            <div class="level-two">
#             <ul>
#              <li>
#               <a href="/business-economy/economy" onclick="sendEvent('Top Navigation','Level 2','/business-economy/economy')">
#                Economy
#               </a>
#              </li>
#              <li>
#               <a href="/business-economy/markets" onclick="sendEvent('Top Navigation','Level 2','/business-economy/markets')">
#                Markets
#               </a>
#              </li>
#              <li>
#               <a href="/business-economy/world-news" onclick="sendEvent('Top Navigation','Level 2','/business-economy/world-news')">
#                World News
#               </a>
#              </li>
#              <li>
#               <a href="/business-economy/companies" onclick="sendEvent('Top Navigation','Level 2','/business-economy/companies')">
#                Companies
#               </a>
#              </li>
#              <li>
#               <a href="/business-economy/industry" onclick="sendEvent('Top Navigation','Level 2','/business-economy/industry')">
#                Industry
#               </a>
#              </li>
#              <li>
#               <a class="arrow" href="/business-economy/personal-finance" onclick="sendEvent('Top Navigation','Level 2','/business-economy/personal-finance')">
#                Personal Finance
#               </a>
#               <div class="level-three">
#                <ul>
#                 <li>
#                  <a href="/business-economy/personal-finance/tax" onclick="sendEvent('Top Navigation','Level 3','/business-economy/personal-finance/tax')">
#                   Tax
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/business-economy/personal-finance/insurance" onclick="sendEvent('Top Navigation','Level 3','/business-economy/personal-finance/insurance')">
#                   Insurance
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/business-economy/personal-finance/planning-investing" onclick="sendEvent('Top Navigation','Level 3','/business-economy/personal-finance/planning-investing')">
#                   Planning &amp; Investing
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </li>
#              <li>
#               <a href="/business-economy/real-estate" onclick="sendEvent('Top Navigation','Level 2','/business-economy/real-estate')">
#                Real Estate
#               </a>
#              </li>
#              <li>
#               <a href="/inspiration-inc" onclick="sendEvent('Top Navigation','Level 2','/inspiration-inc')">
#                Inspiration Inc
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="sector noborder">
#            <div class="title">
#             <a href="/mirror-now" onclick="sendEvent('Top Navigation','Level 1','/mirror-now')">
#              MIRROR NOW
#             </a>
#            </div>
#            <div class="level-two">
#             <ul>
#              <li>
#               <a href="/mirror-now/crime" onclick="sendEvent('Top Navigation','Level 2','/mirror-now/crime')">
#                Crime
#               </a>
#              </li>
#              <li>
#               <a href="/mirror-now/society" onclick="sendEvent('Top Navigation','Level 2','/mirror-now/society')">
#                Society
#               </a>
#              </li>
#              <li>
#               <a href="/mirror-now/civic-issues" onclick="sendEvent('Top Navigation','Level 2','/mirror-now/civic-issues')">
#                Civic Issues
#               </a>
#              </li>
#              <li>
#               <a href="/mirror-now/in-focus" onclick="sendEvent('Top Navigation','Level 2','/mirror-now/in-focus')">
#                In Focus
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="section">
#           <div class="sector">
#            <div class="title">
#             <a href="/sports" onclick="sendEvent('Top Navigation','Level 1','/sports')">
#              SPORTS
#             </a>
#            </div>
#            <div class="level-two">
#             <ul>
#              <li>
#               <a class="arrow" href="/sports/cricket" onclick="sendEvent('Top Navigation','Level 2','/sports/cricket')">
#                Cricket
#               </a>
#               <div class="level-three">
#                <ul>
#                 <li>
#                  <a href="/sports/cricket/cricket-news" onclick="sendEvent('Top Navigation','Level 3','/sports/cricket/cricket-news')">
#                   Cricket News
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </li>
#              <li>
#               <a href="/sports/others" onclick="sendEvent('Top Navigation','Level 2','/sports/others')">
#                Others
#               </a>
#              </li>
#              <li>
#               <a href="/sports/football" onclick="sendEvent('Top Navigation','Level 2','/sports/football')">
#                Football
#               </a>
#              </li>
#              <li>
#               <a href="/sports/tennis" onclick="sendEvent('Top Navigation','Level 2','/sports/tennis')">
#                Tennis
#               </a>
#              </li>
#              <li>
#               <a href="/sports/badminton" onclick="sendEvent('Top Navigation','Level 2','/sports/badminton')">
#                Badminton
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="sector">
#            <a class="link" href="/entertainment-news" onclick="sendEvent('Top Navigation','Level 1','/entertainment-news')">
#             ENTERTAINMENT NEWS
#            </a>
#           </div>
#           <div class="sector">
#            <a class="link" href="/technology-science" onclick="sendEvent('Top Navigation','Level 1','/technology-science')">
#             TECH &amp; GADGETS
#            </a>
#            <a class="link" href="/the-buzz" onclick="sendEvent('Top Navigation','Level 1','/the-buzz')">
#             BUZZ
#            </a>
#           </div>
#           <div class="sector noborder">
#            <div class="title">
#             <a href="/spiritual" onclick="sendEvent('Top Navigation','Level 1','/spiritual')">
#              SPIRITUALITY
#             </a>
#            </div>
#            <div class="level-two">
#             <ul>
#              <li>
#               <a href="/spiritual/religion" onclick="sendEvent('Top Navigation','Level 2','/spiritual/religion')">
#                Religion
#               </a>
#              </li>
#              <li>
#               <a href="/spiritual/dreams-meaning" onclick="sendEvent('Top Navigation','Level 2','/spiritual/dreams-meaning')">
#                Meaning Of Dreams
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="section">
#           <div class="sector">
#            <div class="title">
#             <a href="/auto" onclick="sendEvent('Top Navigation','Level 1','/auto')">
#              Auto
#             </a>
#            </div>
#            <div class="level-two">
#             <ul>
#              <li>
#               <a class="arrow" href="javascript:void(0)">
#                Cars
#               </a>
#               <div class="level-three">
#                <ul>
#                 <li>
#                  <a href="/auto/car-news" onclick="sendEvent('Top Navigation','Level 2','/auto/car-news')">
#                   Car News
#                  </a>
#                 </li>
#                 <li>
#                  <a class="link" href="/auto/car-reviews" onclick="sendEvent('Top Navigation','Level 2','/auto/car-reviews')">
#                   Car Reviews
#                  </a>
#                 </li>
#                 <li>
#                  <a class="link" href="/auto/compare-cars" onclick="sendEvent('Top Navigation','Level 2','/auto/compare-cars')">
#                   Comparisons
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </li>
#              <li>
#               <a class="arrow" href="javascript:void(0)">
#                Bikes
#               </a>
#               <div class="level-three">
#                <ul>
#                 <li>
#                  <a href="/auto/bike-news" onclick="sendEvent('Top Navigation','Level 2','/auto/bike-news')">
#                   Bike News
#                  </a>
#                 </li>
#                 <li>
#                  <a class="link" href="/auto/bike-reviews" onclick="sendEvent('Top Navigation','Level 2','/auto/bike-reviews')">
#                   Bike Reviews
#                  </a>
#                 </li>
#                 <li>
#                  <a class="link" href="/auto/compare-bikes" onclick="sendEvent('Top Navigation','Level 2','/auto/compare-bikes')">
#                   Comparisons
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </li>
#              <li>
#               <a href="/auto/features" onclick="sendEvent('Top Navigation','Level 2','/auto/features')">
#                Features
#               </a>
#              </li>
#              <li>
#               <a href="/videos/times-drive" onclick="sendEvent('Top Navigation','Level 2','/videos/times-drive')">
#                Videos
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="sector noborder">
#            <a class="link" href="/health" onclick="sendEvent('Top Navigation','Level 1','/health')">
#             HEALTH
#            </a>
#            <a class="link" href="/education" onclick="sendEvent('Top Navigation','Level 1','/education')">
#             EDUCATION
#            </a>
#            <a class="link" href="/photos" onclick="sendEvent('Top Navigation','Level 1','/photos')">
#             PHOTOS
#            </a>
#            <a class="link" href="/astrology" onclick="sendEvent('Top Navigation','Level 1','/astrology')">
#             ASTROLOGY
#            </a>
#            <a class="link" href="/todays-headlines" onclick="sendEvent('Top Navigation','Level 1','/todays-headlines')">
#             TODAY
#            </a>
#            <a class="link" href="/latest-news" onclick="sendEvent('Top Navigation','Level 1','/latest-news')">
#             LATEST NEWS
#            </a>
#            <a class="link" href="/trending-news" onclick="sendEvent('Top Navigation','Level 1','/trending-news')">
#             TRENDING NEWS
#            </a>
#            <a class="link" href="/live-tv" onclick="sendEvent('Top Navigation','Level 1','/live-tv')">
#             LIVE TV
#            </a>
#           </div>
#          </div>
#          <div class="section">
#           <div class="sector">
#            <!-- Removed IPL menu 17-Nov-2020 -->
#            <div class="title">
#             <a class="link" href="/web-stories" onclick="sendEvent('Top Navigation','Level 1','/web-stories')">
#              Visual stories
#             </a>
#            </div>
#            <div class="level-two">
#             <ul>
#              <li>
#               <a href="/sports/web-stories" onclick="sendEvent('Top Navigation','Level 2','/sports/web-stories')">
#                Sports
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="sector noborder">
#            <div class="title">
#             <a href="/city" onclick="sendEvent('Top Navigation','Level 1','/city')">
#              Cities
#             </a>
#            </div>
#            <div class="level-two">
#             <ul>
#              <li>
#               <a href="/delhi" onclick="sendEvent('Top Navigation','Level 1','/city')">
#                Delhi
#               </a>
#              </li>
#              <li>
#               <a href="/mumbai" onclick="sendEvent('Top Navigation','Level 1','/mumbai')">
#                Mumbai
#               </a>
#              </li>
#              <li>
#               <a href="/hyderabad" onclick="sendEvent('Top Navigation','Level 1','/hyderabad')">
#                Hyderabad
#               </a>
#              </li>
#              <li>
#               <a href="/ahmedabad" onclick="sendEvent('Top Navigation','Level 1','/ahmedabad')">
#                Ahmedabad
#               </a>
#              </li>
#              <li>
#               <a href="/pune" onclick="sendEvent('Top Navigation','Level 1','/pune')">
#                Pune
#               </a>
#              </li>
#              <li>
#               <a href="/kolkata" onclick="sendEvent('Top Navigation','Level 1','/kolkata')">
#                Kolkata
#               </a>
#              </li>
#              <li>
#               <a href="/bengaluru" onclick="sendEvent('Top Navigation','Level 1','/bengaluru')">
#                Bengaluru
#               </a>
#              </li>
#              <li>
#               <a href="/chennai" onclick="sendEvent('Top Navigation','Level 1','/chennai')">
#                Chennai
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="section noborder">
#           <div class="sector noborder">
#            <div class="title">
#             <a href="/india" onclick="sendEvent('Top Navigation','Level 1','/india')">
#              INDIA
#             </a>
#            </div>
#            <div class="level-two">
#             <ul>
#              <li>
#               <a href="/india/bihar" onclick="sendEvent('Top Navigation','Level 2','/india/bihar')">
#                Bihar
#               </a>
#              </li>
#              <li>
#               <a href="/india/maharashtra-news" onclick="sendEvent('Top Navigation','Level 2','/india/maharashtra-news')">
#                Maharashtra
#               </a>
#              </li>
#              <li>
#               <a href="/india/haryana-news" onclick="sendEvent('Top Navigation','Level 2','/india/haryana-news')">
#                Haryana
#               </a>
#              </li>
#              <li>
#               <a href="/india/jharkhand" onclick="sendEvent('Top Navigation','Level 2','/india/jharkhand')">
#                Jharkhand
#               </a>
#              </li>
#              <li>
#               <a href="/india/west-bengal" onclick="sendEvent('Top Navigation','Level 2','/india/west-bengal')">
#                West Bengal
#               </a>
#              </li>
#              <li>
#               <a href="/india/tamil-nadu" onclick="sendEvent('Top Navigation','Level 2','/india/tamil-nadu')">
#                Tamil Nadu
#               </a>
#              </li>
#              <li>
#               <a href="/india/assam" onclick="sendEvent('Top Navigation','Level 2','/india/assam')">
#                Assam
#               </a>
#              </li>
#              <li>
#               <a href="/india/kerala" onclick="sendEvent('Top Navigation','Level 2','/india/kerala')">
#                Kerala
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#        </li>
#       </ul>
#      </div>
#      <input class="page-header-text" name="page-header" type="hidden" value="category"/>
#     </div>
#     <div class="page-map">
#      <div class="breadcum">
#       <ul>
#        <li>
#         <a href="https://www.timesnownews.com">
#          News
#         </a>
#        </li>
#        <li>
#         <a class="no-pointer active" href="javascript:void(0)">
#          Sports News
#         </a>
#        </li>
#       </ul>
#      </div>
#      <script type="application/ld+json">
#       {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://www.timesnownews.com","name":"News"}},{"@type":"ListItem","position":2,"item":{"@id":"https://www.timesnownews.com/sports","name":"Sports News"}}]}
#      </script>
#      <h1 class="head">
#       SPORTS
#      </h1>
#     </div>
#    </header>
#    <div class="uniqe-add">
#     <div class="adunit advBanner onload-ads tncls_ad tncls_common_200 display-block" data-adunit="/21806551354/TN_English/Desktop/Listing/TN_ENGL_DSKT_LST_Sports_ATF_728" data-dimensions="728x90,970x90" id="div_ad_1425">
#     </div>
#    </div>
#    <div class="body-wrap">
#     <div class="content-block">
#      <!-- Removed -->
#      <!-- Removed -->
#      <div class="section-one tncls_ad_300">
#       <div class="frame-one">
#        <a class="component_4" href="/sports/cricket/article/3-eng-players-4-backroom-staff-members-test-positive-for-covid-19-ecb-to-name-new-team-for-series-vs-pak/781060">
#         <div class="img-pod">
#          <img alt="3 Eng players test +tive for Covid-19 ahead of Pak series" class="b-lazy" data-src="https://imgk.timesnownews.com/story/England_cricket_team_AP8.jpg?tr=w-400,h-300" src="https://iks.timesnownews.com/s/v1/img/c_tnplaceholder.png?tr=w-400,h-300" title="3 Eng players test +tive for Covid-19 ahead of Pak series">
#          </img>
#         </div>
#         <h3 class="content">
#          3 Eng players test +tive for Covid-19 ahead of Pak series
#         </h3>
#        </a>
#       </div>
#       <div class="frame-one">
#        <a class="component_4" href="/sports/cricket/article/a-whopping-99-million-on-tv-india-nz-wtc-final-becomes-most-viewed-test-since-2018-report/781003">
#         <div class="img-pod">
#          <img alt="IND-NZ WTC final becomes most-viewed Test match since 2018" class="b-lazy" data-src="https://imgk.timesnownews.com/story/IND-NZ_WTC_final_becomes_most-viewed_Test_match_since_2018.jpg?tr=w-400,h-300" src="https://iks.timesnownews.com/s/v1/img/c_tnplaceholder.png?tr=w-400,h-300" title="IND-NZ WTC final becomes most-viewed Test match since 2018"/>
#         </div>
#         <h3 class="content">
#          IND-NZ WTC final becomes most-viewed Test match since 2018
#         </h3>
#        </a>
#       </div>
#       <div class="frame-two">
#        <div class="component_2 tncls_50">
#         <a class="text" href="/sports/cricket/article/everyone-is-completely-suryakumar-yadav-on-arjuna-ranatungas-second-string-indian-team-comment/781061" onclick="sendEvent('category','Top Stories','\'Everyone is completely...\': Suryakumar Yadav on Arjuna Ranatunga\'s second-string Indian team comment');">
#          Completely focused: SKY on Ranatunga's second-string comment
#         </a>
#        </div>
#        <div class="component_2 tncls_50">
# ...
#          Editorial Guidelines
#         </a>
#        </li>
#        <li>
#         <a href="https://www.timesnownews.com/info/regulatory/834" onclick="sendEvent('Footer','Footer Link – Section (Company – Regulatory)','Sports')">
#          Reference Interconnect Offers
#         </a>
#        </li>
#        <li>
#         <a href="https://www.timesnownews.com/info/terms-conditions/248" onclick="sendEvent('Footer','Footer Link – Section (Company – Terms of Use)','Sports')">
#          Terms of Use
#         </a>
#        </li>
#        <li>
#         <a href="https://www.timesnownews.com/info/privacy-policy/836" onclick="sendEvent('Footer','Footer Link – Section (Company – Privacy Policy)','Sports')">
#          Privacy Policy
#         </a>
#        </li>
#        <li>
#         <a href="https://www.timesnownews.com/info/disclaimer/37859" onclick="sendEvent('Footer','Footer Link – Section (Company – Disclaimer)','Sports')">
#          Disclaimer
#         </a>
#        </li>
#        <li>
#         <a href="https://www.timesnownews.com/info/complaint-redressal/838" onclick="sendEvent('Footer','Footer Link – Section (Company – Complaint Redressal)','Sports')">
#          Complaint Redressal
#         </a>
#        </li>
#        <li>
#         <a href="https://www.timesnownews.com/info/sitemap/53167" onclick="sendEvent('Footer','Footer Link – Section (Company – Sitemap)','Sports')">
#          Sitemap
#         </a>
#        </li>
#        <li>
#         <a href="https://www.timesnownews.com/info/feedback/52" onclick="sendEvent('Footer','Footer Link – Section (Company – Feedback)','Sports')">
#          Feedback
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="footer-menu-grid">
#       <div class="heading">
#        Watch Live TV
#       </div>
#       <ul>
#        <li>
#         <a href="https://www.timesnownews.com/live-tv" onclick="sendEvent('Footer','Footer Link – Section (Live TV – Times NOW)','Sports')">
#          Times NOW
#         </a>
#        </li>
#        <li>
#         <a href="https://www.timesnownews.com/live-tv/et-now" onclick="sendEvent('Footer','Footer Link – Section (Live TV – ET NOW)','Sports')">
#          ET NOW
#         </a>
#        </li>
#        <li>
#         <a href="https://www.timesnownews.com/live-tv/mirror-now" onclick="sendEvent('Footer','Footer Link – Section (Live TV – Mirror NOW)','Sports')">
#          Mirror NOW
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="footer-section-three">
#      <div class="footer-logo-grid">
#       <div class="logo">
#        <img alt="Times Network" src="https://iks.timesnownews.com/s/v1/img/logo/d_timesnetwork.png" title="Times Network"/>
#       </div>
#       <div class="logo" style="width: 180px;margin-top: 10px;">
#        <img alt="Times Now News" src="https://iks.timesnownews.com/s/v1/img/logo/d_timesnow_logo.png" title="Times Now News"/>
#       </div>
#       <div class="logo">
#        <img alt="etnow" src="https://iks.timesnownews.com/s/v1/img/logo/d_et_logo.png" title="etnow"/>
#       </div>
#       <div class="logo">
#        <img alt="mirrornow" src="https://iks.timesnownews.com/s/v1/img/logo/d_mrnowlogo.jpg" title="mirrornow"/>
#       </div>
#       <div class="logo">
#        <img alt="zoom" src="https://iks.timesnownews.com/s/v1/img/logo/c_zoomlogo.png" title="zoom"/>
#       </div>
#       <div class="logo">
#        <img alt="Movies Now" src="https://iks.timesnownews.com/s/v1/img/logo/d_movies_now_logo.png" title="Movies Now"/>
#       </div>
#       <div class="logo">
#        <img alt="MN+" src="https://iks.timesnownews.com/s/v1/img/logo/d_mn_plus_logo.png" title="MN+"/>
#       </div>
#       <div class="logo">
#        <img alt="MNX" src="https://iks.timesnownews.com/s/v1/img/logo/d_mnx_logo.png" title="MNX"/>
#       </div>
#       <div class="logo">
#        <img alt="Romedy Now" src="https://iks.timesnownews.com/s/v1/img/logo/d_romedynow_logo.png" title="Romedy Now"/>
#       </div>
#      </div>
#      <div class="copyright-grid">
#       © Bennett Coleman &amp; Company Limited
#      </div>
#     </div>
#    </footer>
#    <br class="spacer"/>
#   </div>
#   <div class="page-cover">
#   </div>
#   <input id="dfp_id" type="hidden" value="21806551354"/>
#   <input id="live_tv_pre_roll" name="pre-roll-ad" type="hidden" value="https://pubads.g.doubleclick.net/gampad/ads?sz=400x300&amp;iu=/21806551354/TN_English/Mweb/Video/TN_ENGL_MWEB_VID_LVTV_TimesNow_Preroll&amp;impl=s&amp;gdfp_req=1&amp;env=vp&amp;output=vast&amp;unviewed_position_start=1&amp;url=[referrer_url]&amp;description_url=[description_url]&amp;correlator=[timestamp]"/>
#   <input data-targeting='{"page":"category","section":"sports","lang":"en"}' id="page-targeting" type="hidden"/>
#   <style>
#    ._video_ad { width:100%; height:100%; background:#04144c; left:0; top:0; z-index:1; position:absolute}
#     ._ad_blocker { width:100%; display:flex;align-items: center; height:100%;flex-wrap: wrap;align-items: center;}
#     ._on_blocker { width:100%; float:left; text-align:center; color:#fff; line-height:1.3; font-weight:bold; font-size:1.115em; padding:0 10px}
#     ._continue_blocker { width:100%; float:left; text-align:center; color:#abc8ff; line-height:1; font-weight:bold; font-size:1em;padding:0 10px; margin-top:12px}
#     ._ad_blocker_inner { width:100%}
#     ._off_blocker { width:100%; float:left;display:flex;justify-content: center; margin-top:35px}
#     ._off_button { cursor:pointer;border-radius: 6px;background-color: #3564be; color:#fff; font-size:0.875em; line-height:1; padding:10px 30px}
#             .ad-blocker{position: relative; min-height:360px}
#         .category_live_tv.ad-blocker{ min-height:180px}
#         .home_live_tv.ad-blocker{ min-height:180px}
#         .video-pod.ad-blocker{min-height:480px}
#         ._p_playeid.video-pod.ad-blocker{min-height:200px}
#   </style>
#   <script>
#    function adBlockMessage(cls,msg){
#         var html ='';
#         html += '<div class="_video_ad">';
#         html += '<div class="_ad_blocker">';
#         html += '<div class="_ad_blocker_inner">';
#         html += '<div class="_on_blocker">You seems to have an ad blocker on</div>';
#         html += '<div class="_continue_blocker">Please turn it off in order to continue</div>';
#         html += '<div class="_off_blocker">';
#         html += '<div class="_off_button" onClick="gotoADBlock();">How to turn off ad blocker</div>';
#         html += '</div>';
#         html += ' </div>';
#         html += '</div>';
#         document.getElementsByClassName(cls)[0].innerHTML = '';
#         document.getElementsByClassName(cls)[0].classList.add('ad-blocker');
#         document.getElementsByClassName(cls)[0].innerHTML = html;
#     }
#
#     function gotoADBlock(){
#         window.open('/info/ad-blocker-instructions', '_blank');
#         //window.location.href ="/info/ad-blocker-instructions";
#     }
#   </script>
#   <input id="web_url" name="weburl" type="hidden" value="https://www.timesnownews.com"/>
#   <input id="personalize_ads" name="personalize_ads" type="hidden" value="0"/>
#   <script type="text/javascript">
#    var global_default_img = 'https://iks.timesnownews.com/s/v1/img/c_tnplaceholder.png';
#     var facebookAppId = "2051731518430427";
#     var webUrl = "https://www.timesnownews.com";
#     var slikeApikey = "tgbsl486web5ab8uukl9o";
#     var personalAds = 0;
#     var pubmaticOn = 1;
#     function fTrck(e, params) {
#     }
#     if((document.getElementsByTagName('html')[0].getAttribute('lang') == 'hindi' || document.getElementsByTagName('html')[0].getAttribute('lang') == 'hi') || (document.getElementsByTagName('html')[0].getAttribute('lang') == 'marathi' || document.getElementsByTagName('html')[0].getAttribute('lang') == 'mr')){
#     WebFontConfig = {
#       google: { families: [ 'Mukta:400,500,600,700,900&amp;subset=devanagari&display=swap' ]}
#     };
#     }else if(document.getElementsByTagName('html')[0].getAttribute('lang') ==  'tamil' || document.getElementsByTagName('html')[0].getAttribute('lang') == 'ta'){
#       WebFontConfig = {
#         google: { families: [ 'Noto Sans:400,700&amp;subset=devanagari&display=swap' ]}
#       };
#     }else {
#       WebFontConfig = {
#         google: {
#           families: ['Source Sans Pro:400,500,600,700,900&display=swap']
#         }
#       };
#     }
#   (function() {
#     var wf = document.createElement('script');
#     wf.src = ('https:' == document.location.protocol ? 'https' : 'http') +
#       '://ajax.googleapis.com/ajax/libs/webfont/1.5.18/webfont.js';
#     wf.type = 'text/javascript';
#     wf.async = 'true';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(wf, s);
#   })();
#   </script>
#   <div id="fb-root">
#   </div>
#   <script type="text/javascript">
#    var PWT={}; //Initialize Namespace
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         function tnLoadAds() {
#             if(typeof loadTnDfpDesktopAds === 'function') {
#                 loadTnDfpDesktopAds();
#             } else {
#                 setTimeout(tnLoadAds, 100);
#             }
#         }
#         PWT.jsLoaded = function() { //PubMatic pwt.js on load callback is used to load GPT
#             tnLoadAds();
#         };
#         (function() {
#             var purl = window.location.href;
#             var url = '//ads.pubmatic.com/AdServer/js/pwt/156537/445';
#             var profileVersionId = '';
#             if(purl.indexOf('pwtv=')>0){
#                 var regexp = /pwtv=(.*?)(&|$)/g;
#                 var matches = regexp.exec(purl);
#                 if(matches.length >= 2 && matches[1].length > 0){
#                     profileVersionId = '/'+matches[1];
#                 }
#             }
#             var wtads = document.createElement('script');
#             wtads.async = true;
#             wtads.type = 'text/javascript';
#             wtads.src = url+profileVersionId+'/pwt.js';
#             var node = document.getElementsByTagName('script')[0];
#             node.parentNode.insertBefore(wtads, node);
#         })();
#   </script>
#   <script type="text/javascript">
#    !function(a9,a,p,s,t,A,g){if(a[a9])return;function q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]};A=p.createElement(s);A.async=!0;A.src=t;g=p.getElementsByTagName(s)[0];g.parentNode.insertBefore(A,g)}("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js");
#   </script>
#   <script src="https://iks.timesnownews.com/s/v1/js/d_vendor2.3.js">
#   </script>
#   <script src="https://iks.timesnownews.com/s/v1/js/d_common_script2.1.js?v=3.1" type="text/javascript">
#   </script>
#   <script src="https://iks.timesnownews.com/s/v1/js/c_share.js" type="text/javascript">
#   </script>
#   <script src="https://iks.timesnownews.com/s/v1/js/d_category18.js?v=3.1">
#   </script>
#   <!--Taboola Code Start-->
#   <script type="text/javascript">
#    document.addEventListener("DOMContentLoaded", function(event) {
#             window._taboola = window._taboola || [];
#                  _taboola.push({flush: true});
#            });
#   </script>
#   <img height="0" src="//trc.taboola.com/timesnow-timesnow-sc/log/3/action?name=TimesNowpage_view&amp;item-url=http%3A%2F%2Fwww.timesnownews.com%2F" style="display: none;" width="0">
#    <script type="text/javascript">
#     $('.tabs .tab-points ul li a').on('click',function(e){
#            e.preventDefault();
#            $('.tabs .tab-points ul li a').removeClass('active');
#            $(this).addClass('active');
#            $('.tabs .tab-block .tab-data').removeClass('active');
#            $($(this).attr('href')).addClass('active');
#         });
#    </script>
#    <!--Taboola Code End-->
#    <script src="https://imasdk.googleapis.com/js/sdkloader/ima3.js" type="text/javascript">
#    </script>
#    <script src="https://tvid.in/sdk/loader.js" type="text/javascript">
#    </script>
#    <script>
#     var pathvars={workerStatus: false};
#     window._peq = window._peq || [];
#             window._peq.push(["init","Sports"]);
#         window._peq.push(["add-to-segment","Sports"]);
#    </script>
#    <script async="" src="https://clientcdn.pushengage.com/core/281be2c79b6e42a147e7c26e74203a33.js">
#    </script>
#    <script async="" src="https://agi-static.indiatimes.com/cms-common/ibeat.min.js">
#    </script>
#    <script>
#     if ('serviceWorker' in navigator) {
#         navigator.serviceWorker.register('/sw.js')
#             .then(function(reg) {
#             }).catch(function(err) {
#             });
#     }
#    </script>
#    <!-- GA Remarketing Start -->
#    <script type="text/javascript">
#     var google_tag_params = {};
#     /* <![CDATA[ */
#     var google_conversion_id = 853549987;
#     var google_custom_params = window.google_tag_params;
#     var google_remarketing_only = true;
#     /* ]]> */
#    </script>
#    <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
#    </script>
#    <noscript>
#     <div style="display:inline;">
#      <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/853549987/?guid=ON&amp;script=0" style="border-style:none;" width="1">
#      </img>
#     </div>
#    </noscript>
#    <!-- GA Remarketing End -->
#    <script>
#     (function(w,d,t,r,u){var f,n,i;w[u]=w[u]||[],f=function(){var o={ti:"20066064"};o.q=w[u],w[u]=new UET(o),w[u].push("pageLoad")},n=d.createElement(t),n.src=r,n.async=1,n.onload=n.onreadystatechange=function(){var s=this.readyState;s&&s!=="loaded"&&s!=="complete"||(f(),n.onload=n.onreadystatechange=null)},i=d.getElementsByTagName(t)[0],i.parentNode.insertBefore(n,i)})(window,document,"script","//bat.bing.com/bat.js","uetq");
#    </script>
#    <script type="application/ld+json">
#     {"@context":"https://schema.org","@type":"Organization","name":"Times Now","url":"https://www.timesnownews.com","logo":{"@type":"ImageObject","url":"https://iks.timesnownews.com/s/v1/img/c_siteorglogo.jpg","width":112,"height":112},"sameAs":["https://www.facebook.com/Timesnow","https://twitter.com/TIMESNOW","https://www.instagram.com/timesnow/","https://www.youtube.com/timesnow","https://en.wikipedia.org/wiki/Times_Now"]}
#    </script>
#    <script defer="defer" src="https://cdn.jsdelivr.net/gh/unib0ts/unibots@latest/timesnownews/script.js">
#    </script>
#    <script type="text/javascript">
#     loadMoreArticles();
#    </script>
#    <script type="application/ld+json">
#     {
# 	  "@context":"http://schema.org",
# 	  "@type":"ItemList",
# 	  "itemListElement":[{"@type":"ListItem","position":1,"url":"https:\/\/www.timesnownews.com\/sports\/cricket\/article\/3-eng-players-4-backroom-staff-members-test-positive-for-covid-19-ecb-to-name-new-team-for-series-vs-pak\/781060"},{"@type":"ListItem","position":2,"url":"https:\/\/www.timesnownews.com\/sports\/cricket\/article\/a-whopping-99-million-on-tv-india-nz-wtc-final-becomes-most-viewed-test-since-2018-report\/781003"},{"@type":"ListItem","position":3,"url":"https:\/\/www.timesnownews.com\/sports\/cricket\/article\/everyone-is-completely-suryakumar-yadav-on-arjuna-ranatungas-second-string-indian-team-comment\/781061"},{"@type":"ListItem","position":4,"url":"https:\/\/www.timesnownews.com\/sports\/cricket\/article\/mithali-raj-becomes-reclaims-no-1-spot-in-icc-womens-odi-player-rankings-after-stellar-show-vs-england\/781067"},{"@type":"ListItem","position":5,"url":"https:\/\/www.timesnownews.com\/sports\/cricket\/article\/we-want-to-work-under-him-and-pick-his-brain-bhuvneshwar-kumar-on-playing-under-rahul-dravid-in-sri-lanka\/780984"},{"@type":"ListItem","position":6,"url":"https:\/\/www.timesnownews.com\/sports\/football\/article\/watch-how-striker-less-spain-outmuscled-italy-4-0-in-euro-2012-final\/781027"},{"@type":"ListItem","position":7,"url":"https:\/\/www.timesnownews.com\/sports\/tennis\/article\/wimbledon-you-have-to-prove-it-again-to-yourself-that-you-can-actually-do-it-says-roger-federer\/781031"},{"@type":"ListItem","position":8,"url":"https:\/\/www.timesnownews.com\/sports\/others\/article\/australian-f1-grand-prix-cancelled-for-second-straight-year-due-to-covid\/780987"}]
# 	}
#    </script>
#   </img>
#  </body>
# </html>

# %%
h1 = soup1.findAll('h4',class_='bd-heading-text')
h2 = soup2.findAll('a',class_='gs-c-promo-heading gs-o-faux-block-link__overlay-link sp-o-link-split__anchor gel-pica-bold')
h3 = soup3.findAll('h2',class_='title')
h4 = soup4.findAll('div',class_='text')

# %%
headlines1 = []
for i in range(0,len(h1)):
    headlines1.append(h1[i].get_text())
headlines1
# Out:
# ['Why I am supporting Sania Mirza at the Tokyo Olympics',
#  'I got only 2 months to train for Tokyo Olympics, had no equipment to practice in lockdown - Pranati Nayak',
#  "Sai Praneeth can be the 'surprise package' at Tokyo Olympics —Vimal Kumar",
#  "The Olympics\xa0'A' qualification is a new start for Indian swimming believes former Olympian Shikha Tandon",
#  'Who is V Revathi – the sprinter to represent India in mixed 4x400m relay at the Tokyo Olympics',
#  '10 Indian athletes who will be seen at Tokyo Olympics aged 20 and below',
#  'List of Indian athletes with most Olympics appearances',
#  'Indian hockey team can win an Olympic medal: Assistant coach Shivendra Singh',
#  'How the Indian hockey team made it to the Olympics knockout stages after 36 years?',
#  "Malaysia and Chile to host 2023 men's and women's Jr Hockey World Cups",
#  'India could win two medals in archery at Tokyo Olympics: Compound archer Abhishek Verma',
#  'Jharkhand CM announces Rs 50 lakh cash reward for Deepika Kumari, Rs 2 crore for Olympic gold winner from state',
#  '2022 Commonwealth shooting and archery in India cancelled',
#  "5 years after Dipa Karmakar's Olympic feat, Indian gymnastics in a downward spiral",
#  'How sports in Kashmir changed after scrapping Article 370',
#  "Judging sportspersons over tweets — It's not worth the drama",
#  'What are the overrated aspects of Indian sports?',
#  'The country deserves a better class of role models',
#  'Girls in rural Jharkhand are choosing their futures through football',
#  'Leander Paes and Mahesh Bhupathi to reunite for a web series',
#  'Why I am supporting Sania Mirza at the Tokyo Olympics',
#  "Sania Mirza will use her champion's attitude to bring a medal at the Tokyo Olympics - Vishnu Vardhan",
#  'TTFI recommends Sharath Kamal for Khel Ratna',
#  "EXCLUSIVE: Resurgent paddler Sutirtha Mukherjee fulfills her mother's Olympic dream",
#  "India's veteran Table Tennis umpire Mangesh Mopkar selected to officiate at the Tokyo Olympics",
#  'Why I am supporting Bhavani Devi at the Tokyo Olympics',
#  'David Acfield- The Olympian Fencer who has over 950+ wickets in first-class cricket',
#  'Super Moms at Tokyo Olympics — Meet the mothers who will be in action at the Games']

# %%
headlines2 = []
for i in range(0,len(h2)):
    headlines2.append(h2[i].get_text())
headlines2
# Out:
# ['Seven positive Covid tests in England camp force new ODI squad for Pakistan',
#  'LiveLiveItaly v Spain semi-final build-up - plus England latest',
#  'Australian GP and MotoGP event called off because of coronavirus pandemic',
#  'Euro 2020 semi-final - can Spain do a Portugal & can Italy replace Spinazzola?',
#  "NHL goaltender Kivlenieks dies after 'fireworks malfunction' at Fourth of July party",
#  "'The opportunity to bring happiness for our fans, our nation, is very special'",
#  'Federer & Djokovic ease into quarter-finals in front of bigger crowds on Centre Court',
#  'Paqueta winner against Peru sends Brazil into Copa America final',
#  'Dragons sack prop Vaughan for Covid breaches',
#  'LiveLiveCounty Championship - day three',
#  'On the verge of greatness - can Cavendish break Tour stage win record?',
#  "Raducanu retires from last-16 match because of 'difficulty breathing'",
#  'Anderson takes 1,000th first-class wicket',
#  'Denmark’s journey through the eyes of the country',
#  "'My message to the England team - enjoy every minute of moments like this'",
#  'England focus turns to Denmark for Euro 2020 semi-final ',
#  "'I am thinking of Christian every day' - Denmark beat Czechs to reach last four",
#  'Curry set for Lions debut and Henderson to captain against Sharks',
#  'Are Glazers making amends with Man Utd fans?',
#  'What kind of manager are Crystal Palace getting in Vieira?',
#  "He's got the name, he's got the hair - now Borg junior has a Wimbledon win",
#  'Dual code winger Folau to make rugby union return',
#  "'Players treated like dirt' by Badminton England",
#  'Where and how to watch BBC World News',
#  'Premier League top stories',
#  'European football news',
#  'World Football podcasts',
#  'The best of African sport from BBC Africa',
#  'Sport calendar',
#  "Kane? Schick? Pogba? Grealish? Who will be the summer's big signings?",
#  "'Is the hard work worth it?' - Murray questions future after Wimbledon exit",
#  "'Talented trailblazer, reluctant star, hybrid of modern era' - what £73m Sancho brings to Man Utd",
#  "'I never thought battle for gender equity would be hardest' - Bujold Tokyo-bound after appeal win",
#  "'Benitez's love of Liverpool is not defined by a tribal club divide'",
#  "'Certainty out of chaos' - can Nuno get Spurs back where they think they should be?",
#  'Ten rounds, 125 answers - the bumper Euros quiz',
#  "Can you name Wales' try scorers under Pivac?",
#  "Quiz: Can you name all Anderson's Test team-mates?",
#  'Can you name England team that exited Euro 2000?',
#  "Discover: The BBC's best sports podcasts",
#  'That Peter Crouch Euros Podcast: Episode Eight',
#  'Daily Euros podcast: The semi-final countdown',
#  'Daily Euros podcast: Kane crushes Ukraine as England cruise into the last four',
#  "Sportshour podcast: Giro d'Italia Donne - Longo Borghini cycles home",
#  'Daily Euros podcast: Italy & Spain into last four, England preparing in Rome',
#  'The Sports Desk podcast: Federer, Brady, Ronaldo, Williams: the era of the age-defying athlete',
#  'The evolving role of England captain Kane',
#  "A 'mortifying' moment but a sense of tranquillity - how Southgate rebuilt England",
#  'The players matching maternity with elite cricket',
#  'How Spain’s ‘terrifying confidence’ conquered the world',
#  "The man who took a 'scaredy cat' and built a 'raging bull'",
#  'How a Man Utd legend left for Dunstable Town',
#  "Discover: The BBC's best sports podcasts",
#  'That Peter Crouch Euros Podcast: Episode Eight',
#  'Daily Euros podcast: The semi-final countdown',
#  'Daily Euros podcast: Kane crushes Ukraine as England cruise into the last four',
#  "Sportshour podcast: Giro d'Italia Donne - Longo Borghini cycles home",
#  'Daily Euros podcast: Italy & Spain into last four, England preparing in Rome',
#  'The Sports Desk podcast: Federer, Brady, Ronaldo, Williams: the era of the age-defying athlete']

# %%
headlines3 = []
for i in range(0,len(h3)):
    headlines3.append(h3[i].get_text())
headlines3
# Out:
# ['\nCristiano Ronaldo’s personal interests difficult to manage, says Maurizio Sarri\n',
#  '\nEngland name new squad to face Pakistan after COVID-19 cases, include 9 uncapped players\n',
#  '\n“It’s still this kit?”: Stuart Broad asks James Anderson as ECB identify a new squad for Pakistan series\n',
#  '\nMithali Raj reclaims No.1 spot in ICC Women’s ODI player rankings\n',
#  '\nSri Lanka cricketers to be in bubble as soon as they land back from England\n',
#  '\n2020 Tokyo Games will ‘miss’ maidens from Kerala athletics\n',
#  '\nItaly vs Spain UEFA EURO 2020 Semi-Finals Live Streaming: When and where to watch match live?\n',
#  '\nIf there is no pressure, there is no fun: Suryakumar Yadav on Lanka series\n',
#  '\n7 members of England team test positive for Covid-19, Ben Stokes to lead against Pakistan\n',
#  '\nLeander Paes- Mahesh Bhupathi set to reunite for a web series\n',
#  '\nMy job as vice-captain in SL tour is to help others’ skills and mental health: Bhuvneshwar\n',
#  '\nWomen’s Tests should be five-day contests: Meg Lanning\n',
#  '\nLongtime tormentor Italy stands in way of Spain at Euro 2020\n',
#  '\nMumbai, Pune to host 2022 women’s Asian Cup; Bhubaneswar, Ahmedabad dropped\n',
#  '\n2021 Australian F1 Grand Prix and MotoGP race cancelled\n',
#  '\nAntoine Griezmann, Ousmane Dembele apologise for video mocking hotel staff in Japan\n',
#  '\nCopa America: Argentina trusting Messi to find answer to Ospina’s Colombia\n',
#  '\nGolden oldie Federer weathers Sonego storm to reach Wimbledon quarters\n',
#  '\nBarty survives Krejcikova test to finally reach Wimbledon quarters\n',
#  '\nBrazil beat Peru 1-0 to move into Copa America final\n',
#  '\nManpreet Singh second Indian hockey capt from Mithapur to become flag bearer in Olympics\n',
#  '\nSergio Busquets and Jorginho: The enchanting invisible enforcers at Euro 2020\n',
#  '\nJames Anderson reaches 1,000 first-class wickets with career-best 7/19\n',
#  '\nIndia, England Test series set to be played in front of capacity crowd\n',
#  '\nWimbledon 2021: Coco Gauff crashes out to Angelique Kerber in last-16\n']

# %%
headlines4 = []
for i in range(0,len(h4)):
    headlines4.append(h4[i].get_text())
headlines4
# Out:
# ['Sri Lankan cricketers to enter bio-bubble soon after returning from England ahead of India series     ',
#  "KL Rahul or Virat Kohli? Aakash Chopra names India's first-choice opener for T20 World Cup 2021      ",
#  'Ben Stokes named captain as England pick nine uncapped players in new squad for series against Pakistan      ',
#  'BAR vs PLE Dream11 prediction today: Fantasy cricket tips for VTU-MU Pleven\u200b vs Barbarians\xa0match     ',
#  "India vs Sri Lanka: Hardik Pandya is bowling and it's a very good sign, says Suryakumar Yadav     ",
#  'Zimbabwe vs Bangladesh : Tamim Iqbal doubtful, Mushfiqur Rahim likely to play one-off Test      ',
#  'Hardik Pandya will have to bowl: Aakash Chopra urges all-rounder to restart bowling as T20 World Cup nears      ',
#  'Big chance for candidates to stake claim for Australia team berth, says Tim Paine     ',
#  "Asian Football Confederation Women's Asian Cup 2022 to be staged in Mumbai, Pune      ",
#  'PLO vs BAR Dream11 prediction today: Fantasy cricket tips for BSCU-MU Plovdiv vs Academic-MU Sofia     ',
#  'Odisha recommends Pramod Bhagat, para-badminton player for Rajiv Gandhi Khel Ratna Award     ',
#  "Who's in, who misses out? VVS Laxman, Irfan Pathan share their Shikhar Dhawan-led India XI for Sri Lanka ODIs     ",
#  'How Delhi Capitals stopped R Ashwin from mankading players in IPL, Shreyas Iyer reveals     ',
#  'On this day in 2019: Rohit Sharma became 1st batsman to score 5 hundreds in a single World Cup     ',
#  "ENG 2-0 SL: How Kusal Perera's team let down Arjuna Ranatunga's claim with unwanted record     ",
#  "BCCI yet to respond to Team India's demand for Gill's replacement; Shaw, Padikkal's status unclear: Report     ",
#  'Cricket South Africa hearings on racial discrimination begins, Ombudsman to submit report by end of September     ',
#  'Danish Kaneria slams Arjuna Ranatunga after his controversial comments on Shikhar Dhawan-led Team India     ',
#  '10 teams, 74 matches, 2 groups: IPL set for major overhaul in 2022 season      ',
#  'LaLiga: Atletico Madrid rope in Marcos Paulo Costa do Nascimento on 5-year contract     ',
#  '\n\r\n                     SL cricketers to enter bio-bubble after returning from ENG\n',
#  '\n\r\n                     Black Fungus: More than 3,000 cases, 122 fatalities in TN\n',
#  '\n\r\n                     Guj woman reaches UP to marry, her lover held for conversion\n',
#  '\n\r\n                     Record appointment of women Governors under Modi govt\n',
#  '\n\r\n                     HBSE Haryana Open School Result for class 10 expected soon\n',
#  '\nWATCH: When Kohli, Anushka watched Wimbledon with Tendulkars\n',
#  '\nFranchises can retain 4 players for IPL mega auction: Report\n',
#  '\nShubman Gill ruled out of entire England Test series\n',
#  '\nMS Dhoni gifts Sakshi a vintage sky blue Beetle\n',
#  "\nWATCH: Messi scores stunning free-kick in Argentina's win\n",
#  '\n\r\n                     Nifty Futs shut 25 points lower at 15,833; Bajaj Finance hits a fresh high\n',
#  '\n\r\n                     Navjot Sidhu direct attacks at Captain Amarinder Sindh policies; The Big story\n',
#  '\n\r\n                     Maharashtra: MVA government introduces three farm legislation amendment measures in Assembly\n',
#  "\n\r\n                     BJP opposes West Bengal CM's Proposal, TMC Slams BJP Double Standard\n",
#  '\n\r\n                     HC: Twitter has no legal immunity due to non-compliance with IT Rules, Centre free to take action\n']

# %%
cluster_name1 = []
for i in range(0,len(h1)):
    cluster_name1.append('Sports')
cluster_name1
# Out:
# ['Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports']

# %%
cluster_name2 = []
for i in range(0,len(h2)):
    cluster_name2.append('Sports')
cluster_name2
# Out:
# ['Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports']

# %%
cluster_name3 = []
for i in range(0,len(h3)):
    cluster_name3.append('Sports')
cluster_name3
# Out:
# ['Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports']

# %%
cluster_name4 = []
for i in range(0,len(h4)):
    cluster_name4.append('Sports')
cluster_name4
# Out:
# ['Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports',
#  'Sports']

# %%
source_1 = []
for i in range(0,len(h1)):
    source_1.append('The Bridge')
source_1
# Out:
# ['The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge',
#  'The Bridge']

# %%
source_2 = []
for i in range(0,len(h2)):
    source_2.append('BBC')
source_2
# Out:
# ['BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC',
#  'BBC']

# %%
source_3 = []
for i in range(0,len(h3)):
    source_3.append('Indian Express')
source_3
# Out:
# ['Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express',
#  'Indian Express']

# %%
source_4 = []
for i in range(0,len(h4)):
    source_4.append('Timesnow News')
source_4
# Out:
# ['Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News',
#  'Timesnow News']

# %%
news_1 = []
for i in range(0,len(h1)):
    news_1.append('India')
news_1
# Out:
# ['India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India']

# %%
news_2 = []
for i in range(0,len(h2)):
    news_2.append('India')
news_2
# Out:
# ['India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India']

# %%
news_3 = []
for i in range(0,len(h3)):
    news_3.append('Global')
news_3
# Out:
# ['Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global']

# %%
news_4 = []
for i in range(0,len(h4)):
    news_4.append('Global')
news_4
# Out:
# ['Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global',
#  'Global']

# %%
df1 = pd.DataFrame()
df2 = pd.DataFrame()
df3 = pd.DataFrame()
df4 = pd.DataFrame()

# %%
df1['Headlines'] = headlines1
df1['Cluster'] = cluster_name1
df1['Source'] = source_1
df1['News Type'] = news_1

# %%
df1
# Out:
#                                             Headlines Cluster      Source  \
# 0   Why I am supporting Sania Mirza at the Tokyo O...  Sports  The Bridge
# 1   I got only 2 months to train for Tokyo Olympic...  Sports  The Bridge
# 2   Sai Praneeth can be the 'surprise package' at ...  Sports  The Bridge
# 3   The Olympics 'A' qualification is a new start ...  Sports  The Bridge
# 4   Who is V Revathi – the sprinter to represent I...  Sports  The Bridge
# 5   10 Indian athletes who will be seen at Tokyo O...  Sports  The Bridge
# 6   List of Indian athletes with most Olympics app...  Sports  The Bridge
# 7   Indian hockey team can win an Olympic medal: A...  Sports  The Bridge
# 8   How the Indian hockey team made it to the Olym...  Sports  The Bridge
# 9   Malaysia and Chile to host 2023 men's and wome...  Sports  The Bridge
# 10  India could win two medals in archery at Tokyo...  Sports  The Bridge
# 11  Jharkhand CM announces Rs 50 lakh cash reward ...  Sports  The Bridge
# 12  2022 Commonwealth shooting and archery in Indi...  Sports  The Bridge
# 13  5 years after Dipa Karmakar's Olympic feat, In...  Sports  The Bridge
# 14  How sports in Kashmir changed after scrapping ...  Sports  The Bridge
# 15  Judging sportspersons over tweets — It's not w...  Sports  The Bridge
# 16   What are the overrated aspects of Indian sports?  Sports  The Bridge
# 17  The country deserves a better class of role mo...  Sports  The Bridge
# 18  Girls in rural Jharkhand are choosing their fu...  Sports  The Bridge
# 19  Leander Paes and Mahesh Bhupathi to reunite fo...  Sports  The Bridge
# 20  Why I am supporting Sania Mirza at the Tokyo O...  Sports  The Bridge
# 21  Sania Mirza will use her champion's attitude t...  Sports  The Bridge
# 22       TTFI recommends Sharath Kamal for Khel Ratna  Sports  The Bridge
# 23  EXCLUSIVE: Resurgent paddler Sutirtha Mukherje...  Sports  The Bridge
# 24  India's veteran Table Tennis umpire Mangesh Mo...  Sports  The Bridge
# 25  Why I am supporting Bhavani Devi at the Tokyo ...  Sports  The Bridge
# 26  David Acfield- The Olympian Fencer who has ove...  Sports  The Bridge
# 27  Super Moms at Tokyo Olympics — Meet the mother...  Sports  The Bridge
#
#    News Type
# 0      India
# 1      India
# 2      India
# 3      India
# 4      India
# 5      India
# 6      India
# 7      India
# 8      India
# 9      India
# 10     India
# 11     India
# 12     India
# 13     India
# 14     India
# 15     India
# 16     India
# 17     India
# 18     India
# 19     India
# 20     India
# 21     India
# 22     India
# 23     India
# 24     India
# 25     India
# 26     India
# 27     India

# %%
df2['Headlines'] = headlines2
df2['Cluster'] = cluster_name2
df2['Source'] = source_2
df2['News Type'] = news_2

# %%
df2
# Out:
#                                             Headlines Cluster Source News Type
# 0   Seven positive Covid tests in England camp for...  Sports    BBC     India
# 1   LiveLiveItaly v Spain semi-final build-up - pl...  Sports    BBC     India
# 2   Australian GP and MotoGP event called off beca...  Sports    BBC     India
# 3   Euro 2020 semi-final - can Spain do a Portugal...  Sports    BBC     India
# 4   NHL goaltender Kivlenieks dies after 'firework...  Sports    BBC     India
# 5   'The opportunity to bring happiness for our fa...  Sports    BBC     India
# 6   Federer & Djokovic ease into quarter-finals in...  Sports    BBC     India
# 7   Paqueta winner against Peru sends Brazil into ...  Sports    BBC     India
# 8        Dragons sack prop Vaughan for Covid breaches  Sports    BBC     India
# 9             LiveLiveCounty Championship - day three  Sports    BBC     India
# 10  On the verge of greatness - can Cavendish brea...  Sports    BBC     India
# 11  Raducanu retires from last-16 match because of...  Sports    BBC     India
# 12          Anderson takes 1,000th first-class wicket  Sports    BBC     India
# 13  Denmark’s journey through the eyes of the country  Sports    BBC     India
# 14  'My message to the England team - enjoy every ...  Sports    BBC     India
# 15  England focus turns to Denmark for Euro 2020 s...  Sports    BBC     India
# 16  'I am thinking of Christian every day' - Denma...  Sports    BBC     India
# 17  Curry set for Lions debut and Henderson to cap...  Sports    BBC     India
# 18       Are Glazers making amends with Man Utd fans?  Sports    BBC     India
# 19  What kind of manager are Crystal Palace gettin...  Sports    BBC     India
# 20  He's got the name, he's got the hair - now Bor...  Sports    BBC     India
# 21  Dual code winger Folau to make rugby union return  Sports    BBC     India
# 22   'Players treated like dirt' by Badminton England  Sports    BBC     India
# 23              Where and how to watch BBC World News  Sports    BBC     India
# 24                         Premier League top stories  Sports    BBC     India
# 25                             European football news  Sports    BBC     India
# 26                            World Football podcasts  Sports    BBC     India
# 27          The best of African sport from BBC Africa  Sports    BBC     India
# 28                                     Sport calendar  Sports    BBC     India
# 29  Kane? Schick? Pogba? Grealish? Who will be the...  Sports    BBC     India
# 30  'Is the hard work worth it?' - Murray question...  Sports    BBC     India
# 31  'Talented trailblazer, reluctant star, hybrid ...  Sports    BBC     India
# 32  'I never thought battle for gender equity woul...  Sports    BBC     India
# 33  'Benitez's love of Liverpool is not defined by...  Sports    BBC     India
# 34  'Certainty out of chaos' - can Nuno get Spurs ...  Sports    BBC     India
# 35    Ten rounds, 125 answers - the bumper Euros quiz  Sports    BBC     India
# 36       Can you name Wales' try scorers under Pivac?  Sports    BBC     India
# 37  Quiz: Can you name all Anderson's Test team-ma...  Sports    BBC     India
# 38   Can you name England team that exited Euro 2000?  Sports    BBC     India
# 39           Discover: The BBC's best sports podcasts  Sports    BBC     India
# 40     That Peter Crouch Euros Podcast: Episode Eight  Sports    BBC     India
# 41      Daily Euros podcast: The semi-final countdown  Sports    BBC     India
# 42  Daily Euros podcast: Kane crushes Ukraine as E...  Sports    BBC     India
# 43  Sportshour podcast: Giro d'Italia Donne - Long...  Sports    BBC     India
# 44  Daily Euros podcast: Italy & Spain into last f...  Sports    BBC     India
# 45  The Sports Desk podcast: Federer, Brady, Ronal...  Sports    BBC     India
# 46          The evolving role of England captain Kane  Sports    BBC     India
# 47  A 'mortifying' moment but a sense of tranquill...  Sports    BBC     India
# 48  The players matching maternity with elite cricket  Sports    BBC     India
# 49  How Spain’s ‘terrifying confidence’ conquered ...  Sports    BBC     India
# 50  The man who took a 'scaredy cat' and built a '...  Sports    BBC     India
# 51       How a Man Utd legend left for Dunstable Town  Sports    BBC     India
# 52           Discover: The BBC's best sports podcasts  Sports    BBC     India
# 53     That Peter Crouch Euros Podcast: Episode Eight  Sports    BBC     India
# 54      Daily Euros podcast: The semi-final countdown  Sports    BBC     India
# 55  Daily Euros podcast: Kane crushes Ukraine as E...  Sports    BBC     India
# 56  Sportshour podcast: Giro d'Italia Donne - Long...  Sports    BBC     India
# 57  Daily Euros podcast: Italy & Spain into last f...  Sports    BBC     India
# 58  The Sports Desk podcast: Federer, Brady, Ronal...  Sports    BBC     India

# %%
df3['Headlines'] = headlines3
df3['Cluster'] = cluster_name3
df3['Source'] = source_3
df3['News Type'] = news_3

# %%
df3
# Out:
#                                             Headlines Cluster          Source  \
# 0   \nCristiano Ronaldo’s personal interests diffi...  Sports  Indian Express
# 1   \nEngland name new squad to face Pakistan afte...  Sports  Indian Express
# 2   \n“It’s still this kit?”: Stuart Broad asks Ja...  Sports  Indian Express
# 3   \nMithali Raj reclaims No.1 spot in ICC Women’...  Sports  Indian Express
# 4   \nSri Lanka cricketers to be in bubble as soon...  Sports  Indian Express
# 5   \n2020 Tokyo Games will ‘miss’ maidens from Ke...  Sports  Indian Express
# 6   \nItaly vs Spain UEFA EURO 2020 Semi-Finals Li...  Sports  Indian Express
# 7   \nIf there is no pressure, there is no fun: Su...  Sports  Indian Express
# 8   \n7 members of England team test positive for ...  Sports  Indian Express
# 9   \nLeander Paes- Mahesh Bhupathi set to reunite...  Sports  Indian Express
# 10  \nMy job as vice-captain in SL tour is to help...  Sports  Indian Express
# 11  \nWomen’s Tests should be five-day contests: M...  Sports  Indian Express
# 12  \nLongtime tormentor Italy stands in way of Sp...  Sports  Indian Express
# 13  \nMumbai, Pune to host 2022 women’s Asian Cup;...  Sports  Indian Express
# 14  \n2021 Australian F1 Grand Prix and MotoGP rac...  Sports  Indian Express
# 15  \nAntoine Griezmann, Ousmane Dembele apologise...  Sports  Indian Express
# 16  \nCopa America: Argentina trusting Messi to fi...  Sports  Indian Express
# 17  \nGolden oldie Federer weathers Sonego storm t...  Sports  Indian Express
# 18  \nBarty survives Krejcikova test to finally re...  Sports  Indian Express
# 19  \nBrazil beat Peru 1-0 to move into Copa Ameri...  Sports  Indian Express
# 20  \nManpreet Singh second Indian hockey capt fro...  Sports  Indian Express
# 21  \nSergio Busquets and Jorginho: The enchanting...  Sports  Indian Express
# 22  \nJames Anderson reaches 1,000 first-class wic...  Sports  Indian Express
# 23  \nIndia, England Test series set to be played ...  Sports  Indian Express
# 24  \nWimbledon 2021: Coco Gauff crashes out to An...  Sports  Indian Express
#
#    News Type
# 0     Global
# 1     Global
# 2     Global
# 3     Global
# 4     Global
# 5     Global
# 6     Global
# 7     Global
# 8     Global
# 9     Global
# 10    Global
# 11    Global
# 12    Global
# 13    Global
# 14    Global
# 15    Global
# 16    Global
# 17    Global
# 18    Global
# 19    Global
# 20    Global
# 21    Global
# 22    Global
# 23    Global
# 24    Global

# %%
df4['Headlines'] = headlines4
df4['Cluster'] = cluster_name4
df4['Source'] = source_4
df4['News Type'] = news_4

# %%
df4
# Out:
#                                             Headlines Cluster         Source  \
# 0   Sri Lankan cricketers to enter bio-bubble soon...  Sports  Timesnow News
# 1   KL Rahul or Virat Kohli? Aakash Chopra names I...  Sports  Timesnow News
# 2   Ben Stokes named captain as England pick nine ...  Sports  Timesnow News
# 3   BAR vs PLE Dream11 prediction today: Fantasy c...  Sports  Timesnow News
# 4   India vs Sri Lanka: Hardik Pandya is bowling a...  Sports  Timesnow News
# 5   Zimbabwe vs Bangladesh : Tamim Iqbal doubtful,...  Sports  Timesnow News
# 6   Hardik Pandya will have to bowl: Aakash Chopra...  Sports  Timesnow News
# 7   Big chance for candidates to stake claim for A...  Sports  Timesnow News
# 8   Asian Football Confederation Women's Asian Cup...  Sports  Timesnow News
# 9   PLO vs BAR Dream11 prediction today: Fantasy c...  Sports  Timesnow News
# 10  Odisha recommends Pramod Bhagat, para-badminto...  Sports  Timesnow News
# 11  Who's in, who misses out? VVS Laxman, Irfan Pa...  Sports  Timesnow News
# 12  How Delhi Capitals stopped R Ashwin from manka...  Sports  Timesnow News
# 13  On this day in 2019: Rohit Sharma became 1st b...  Sports  Timesnow News
# 14  ENG 2-0 SL: How Kusal Perera's team let down A...  Sports  Timesnow News
# 15  BCCI yet to respond to Team India's demand for...  Sports  Timesnow News
# 16  Cricket South Africa hearings on racial discri...  Sports  Timesnow News
# 17  Danish Kaneria slams Arjuna Ranatunga after hi...  Sports  Timesnow News
# 18  10 teams, 74 matches, 2 groups: IPL set for ma...  Sports  Timesnow News
# 19  LaLiga: Atletico Madrid rope in Marcos Paulo C...  Sports  Timesnow News
# 20  \n\r\n                     SL cricketers to en...  Sports  Timesnow News
# 21  \n\r\n                     Black Fungus: More ...  Sports  Timesnow News
# 22  \n\r\n                     Guj woman reaches U...  Sports  Timesnow News
# 23  \n\r\n                     Record appointment ...  Sports  Timesnow News
# 24  \n\r\n                     HBSE Haryana Open S...  Sports  Timesnow News
# 25  \nWATCH: When Kohli, Anushka watched Wimbledon...  Sports  Timesnow News
# 26  \nFranchises can retain 4 players for IPL mega...  Sports  Timesnow News
# 27  \nShubman Gill ruled out of entire England Tes...  Sports  Timesnow News
# 28  \nMS Dhoni gifts Sakshi a vintage sky blue Bee...  Sports  Timesnow News
# 29  \nWATCH: Messi scores stunning free-kick in Ar...  Sports  Timesnow News
# 30  \n\r\n                     Nifty Futs shut 25 ...  Sports  Timesnow News
# 31  \n\r\n                     Navjot Sidhu direct...  Sports  Timesnow News
# 32  \n\r\n                     Maharashtra: MVA go...  Sports  Timesnow News
# 33  \n\r\n                     BJP opposes West Be...  Sports  Timesnow News
# 34  \n\r\n                     HC: Twitter has no ...  Sports  Timesnow News
#
#    News Type
# 0     Global
# 1     Global
# 2     Global
# 3     Global
# 4     Global
# 5     Global
# 6     Global
# 7     Global
# 8     Global
# 9     Global
# 10    Global
# 11    Global
# 12    Global
# 13    Global
# 14    Global
# 15    Global
# 16    Global
# 17    Global
# 18    Global
# 19    Global
# 20    Global
# 21    Global
# 22    Global
# 23    Global
# 24    Global
# 25    Global
# 26    Global
# 27    Global
# 28    Global
# 29    Global
# 30    Global
# 31    Global
# 32    Global
# 33    Global
# 34    Global

# %%
frames = [df1,df2,df3,df4]

# %%
result = pd.concat(frames,join='inner')
result
# Out:
#                                             Headlines Cluster         Source  \
# 0   Why I am supporting Sania Mirza at the Tokyo O...  Sports     The Bridge
# 1   I got only 2 months to train for Tokyo Olympic...  Sports     The Bridge
# 2   Sai Praneeth can be the 'surprise package' at ...  Sports     The Bridge
# 3   The Olympics 'A' qualification is a new start ...  Sports     The Bridge
# 4   Who is V Revathi – the sprinter to represent I...  Sports     The Bridge
# ..                                                ...     ...            ...
# 30  \n\r\n                     Nifty Futs shut 25 ...  Sports  Timesnow News
# 31  \n\r\n                     Navjot Sidhu direct...  Sports  Timesnow News
# 32  \n\r\n                     Maharashtra: MVA go...  Sports  Timesnow News
# 33  \n\r\n                     BJP opposes West Be...  Sports  Timesnow News
# 34  \n\r\n                     HC: Twitter has no ...  Sports  Timesnow News
#
#    News Type
# 0      India
# 1      India
# 2      India
# 3      India
# 4      India
# ..       ...
# 30    Global
# 31    Global
# 32    Global
# 33    Global
# 34    Global
#
# [147 rows x 4 columns]

# %%
result = result.reset_index()

# %%
result = result.drop('index',axis=1)
result
# Out:
#                                              Headlines Cluster         Source  \
# 0    Why I am supporting Sania Mirza at the Tokyo O...  Sports     The Bridge
# 1    I got only 2 months to train for Tokyo Olympic...  Sports     The Bridge
# 2    Sai Praneeth can be the 'surprise package' at ...  Sports     The Bridge
# 3    The Olympics 'A' qualification is a new start ...  Sports     The Bridge
# 4    Who is V Revathi – the sprinter to represent I...  Sports     The Bridge
# ..                                                 ...     ...            ...
# 142  \n\r\n                     Nifty Futs shut 25 ...  Sports  Timesnow News
# 143  \n\r\n                     Navjot Sidhu direct...  Sports  Timesnow News
# 144  \n\r\n                     Maharashtra: MVA go...  Sports  Timesnow News
# 145  \n\r\n                     BJP opposes West Be...  Sports  Timesnow News
# 146  \n\r\n                     HC: Twitter has no ...  Sports  Timesnow News
#
#     News Type
# 0       India
# 1       India
# 2       India
# 3       India
# 4       India
# ..        ...
# 142    Global
# 143    Global
# 144    Global
# 145    Global
# 146    Global
#
# [147 rows x 4 columns]

# %%
result.to_csv('Politics_News_Cluster.csv')
